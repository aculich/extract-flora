# %%
# !pip uninstall fitz PyMuPDF --yes
# !pip install PyMuPDF
#!pip install PyMuPDF==1.19.1  ## install a release later than 1.19.0
#!pip install PyMuPDF==1.18.19  ## don't install 1.19.0 because of Wrong x0/y0 values for bboxes in get_text("words"), see: https://github.com/pymupdf/PyMuPDF/issues/1328
# ## Releases of PyMuPDF as of Oct 18, 2021: 1.11.2, 1.12.5, 1.13.20, 1.14.19.post2, 1.14.20, 1.14.21, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.16.7, 1.16.8, 1.16.9, 1.16.10, 1.16.11, 1.16.12, 1.16.13, 1.16.14, 1.16.15, 1.16.16, 1.16.17, 1.16.18, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.17.6, 1.17.7, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.18.6, 1.18.7, 1.18.8, 1.18.9, 1.18.10, 1.18.11, 1.18.12, 1.18.13, 1.18.14, 1.18.15, 1.18.16, 1.18.17, 1.18.18, 1.18.19, 1.19.0
# Out:
# WARNING: Skipping fitz as it is not installed.
# Found existing installation: PyMuPDF 1.19.6
# Uninstalling PyMuPDF-1.19.6:
#   Successfully uninstalled PyMuPDF-1.19.6
# Collecting PyMuPDF
#   Using cached PyMuPDF-1.19.6-cp38-cp38-macosx_10_9_x86_64.whl (7.6 MB)
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.19.6
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !open -a Preview book-1.pdf book-2.pdf book-3.pdf

# %%
config = [
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 1.pdf",
    "name" : "book-1",
    "page_count" : 642,
    "sections" : {
      "preface" : [1, 78],
      "toponymique" : [49, 76],
      "abbrev" : [77, 78],
      "content" : [79, 607],
      "sample" : [79, 79+10],
      "index" : [617, 639]},
    },
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 2.pdf",
    "name" : "book-2",
    "page_count" : 725,
    "sections" : {
      "preface" : [1, 79],
      "abbrev" : [6, 7],
      "content" : [8, 700],
      "sample" : [8, 8+10],
      "index" : [704, 725]},
    },
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 3.pdf",
    "name" : "book-3",
    "page_count" : 588,
    "sections" : {
      "preface" : [1, 7],
      "abbrev" : [6, 7],
      "content" : [8, 554],
      "sample" : [8, 8+10],
      "index" : [556, 583],
      "familyidx" : [584, 585]},
    },
]

# %%
import sys, fitz, re
from pprint import pprint

## Purpose: this cell is a pre-processing step that will create a symlink (e.g. book-1.pdf)
##          that points to the original file, and then will create new PDF documents
##          that are excerpts of subsets of the whole book
##          as named sections such as book-1-index.pdf or book-1-abbrev.pdf
##          The file book-X-sample.pdf contains the first 10 pages of the book-1-content.pdf
##          and the sample is used to speed up development/testing later on

## https://pymupdf.readthedocs.io/en/latest/document.html#Document.delete_pages
##    In general, the performance of this method is dependent on the number of remaining pages
##    NOT on the number of deleted pages
## So, keeping fewer pages is faster, and deleting more pages at once is also faster 
def excerpt(infile, outfile, start, end):
  doc = fitz.open(infile)  # open document
  last_page = doc.page_count
  print(start, end, last_page, outfile)
  deleteme = []
  if start - 1 > 0:
    deleteme.extend(list(range(0, start - 1)))       
  if end < last_page:
    deleteme.extend(list(range(end, last_page)))
  # print(deleteme)
  doc.delete_pages(deleteme)
  doc.save(outfile, garbage=4, clean=True)

import os, os.path
for book in config:
   symlink = book["name"] + ".pdf"
   fname = book["filename"]
   if os.path.exists(book["filename"]) and not os.path.exists(symlink):
      print("Creating symlink: ", symlink, " ->", fname)
      os.symlink(book["filename"], symlink)
   for section in book["sections"]:
      #print(s)
      start, end = book["sections"][section];
      out_fname = book["name"] + "-" + section + ".pdf"
      excerpt(book["filename"], out_fname, start, end)

# !open -a Preview book-[1,2,3]-*.pdf

## Runtime of this cell is ~11m38s

# %%
# !open -a Preview book-[1,2,3]-*.pdf

# %%
# !open -a Preview book-[1,2,3]-index.pdf

# %%
# https://pymupdf.readthedocs.io/en/latest/faq/#how-to-analyze-font-characteristics

import fitz
import pprint, re

def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return ", ".join(l)

class Face:
    def __init__(self, font, size, color, flags=0):
        self.font = font
        self.size = size
        self.color = color
        self.flags = flags
        self.style = flags_decomposer(self.flags)
    def __str__(self):
        return f"Font: '{self.font}' ({self.style}), size {self.size:g}, color " + ("#%06x" % self.color)
print(Face("Times", 10.929, 0, 4))
# Out:
# Font: 'Times' (serifed, proportional), size 10.929, color #000000

# %%
import sys, fitz, re
from pprint import pprint
# fname = "book-1-sample.pdf"
fname = "book-1.pdf"
doc = fitz.open(fname)  # open document

from fitz.utils import getColor
#blue = getColor("aliceblue")

# txtpgoffset = 77
txtpgoffset = 0
# start_page = 1 + txtpgoffset
start_page = 1
#end_page = start_page + 11
#end_page = start_page + 150
#end_page = start_page + 530
end_page = doc.page_count
items = []
mode = "searching"
print(mode)
for i in range(start_page, end_page):
    page = doc[i]
    # read page text as a dictionary, suppressing extra spaces in CJK fonts
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", flags=flags)["blocks"]
    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        #annot = page.add_rect_annot(br)
        for y,l in enumerate(b["lines"]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            for z,s in enumerate(l["spans"]):  # iterate through the text spans
                if z==0 and mode == "found":
                    mode = "spanning"
                #s["style"] = flags_decomposer(s["flags"])  # readable font flags
                face = Face(s["font"], s["size"], s["color"], s["flags"])
                t = s["text"]
                ## FIXME: [83, 'N  Cystopteris  filix-fragilis  (L.) Borb. —  Polypodiumfilix-fragile  L.,  Cyst,  fragilis']
                ## FIXMECLASS: OCR Error; a spurious mark in the text preceding the genus is interpreted as a letter 'N'
                if z==0 and mode != "found" and re.search(r"Times-Bold\b", str(face)) and s["size"] > 10.0:
                        r_rect = fitz.Rect(lr)
                        r_high = fitz.Rect(s["bbox"])
                        joined = " ".join(list(map(lambda x: x["text"].strip(), l["spans"])))  ## FIXMEDESC: ideally this simplistic code would work if not for OCR Errors
                        item = joined
                        # found = re.match(r"(?P<genus>([A-Z]\w+) (?P<species>\w+)", joined)
                        # d = found.groupdict()
                        matches = re.match(r"([A-Z]\w+) (\w+)", joined)
                        warning = "Possible OCR Error"
                        if matches and len(matches.groups()) == 2:
                            found = matches.groups()
                            warning = "Normal"
                            mode = "found"
                            # item = f"""${d['genus']} ${d['species']}"""
                            item = " ".join(found)
                        else:
                            warning = "Possible OCR Error"

                        print([i, x, y, z, item, warning])
                        annot_high = page.add_highlight_annot(r_high)
                        items.append([t, r_rect, r_high, i, z,s, y,l, x,b, warning])
print(len(items))
#print(i, items[0][:3])
# Out:
# searching
# [34, 0, 0, 0, 'r', 'Possible OCR Error']
# [59, 9, 0, 0, 'J', 'Possible OCR Error']
# [77, 8, 5, 0, 'JL', 'Possible OCR Error']
# [78, 8, 0, 0, 'Lycopodium cernuum', 'Normal']
# [79, 1, 0, 0, 'Selaginella denticulata', 'Normal']
# [79, 16, 0, 0, 'Isoetes hystrix', 'Normal']
# [79, 24, 1, 0, 'Isoetes olympica', 'Normal']
# [80, 13, 0, 0, 'Equisetum maximum', 'Normal']
# [80, 18, 0, 0, 'Equisetum palustre', 'Normal']
# [80, 25, 0, 0, 'Equisetum ramosissimum', 'Normal']
# [81, 9, 0, 0, 'Ophioglossum vulgatum', 'Normal']
# [81, 11, 3, 0, 'Ophioglossum lusitanicum', 'Normal']
# [81, 21, 0, 0, 'Osmunda regalis', 'Normal']
# [82, 9, 0, 0, 'Gymnogramma leptophylla', 'Normal']
# [82, 17, 0, 0, 'Cheilanthes pteridioides', 'Normal']
# [83, 28, 0, 0, 'Âdiantum capillus-veneris I (PL III, n. 4). — 2|. Rhizome rampant à écailles', 'Possible OCR Error']
# [84, 10, 0, 0, 'Pteris longifolia', 'Normal']
# [84, 16, 0, 0, 'Pteridium aquilmum', 'Normal']
# [85, 1, 0, 0, 'Athyrium filix', 'Normal']
# [85, 12, 0, 0, 'Dryopterîs aculeata', 'Normal']
# [85, 18, 0, 0, 'Dryopteris libanotica', 'Normal']
# [86, 17, 0, 0, 'Blechnum spicant', 'Normal']
# [87, 10, 0, 0, 'Ceterack officinarum', 'Normal']
# [88, 1, 0, 0, 'Asplenium bourgaei', 'Normal']
# [88, 5, 0, 0, 'Asplenium trichomanes', 'Normal']
# [88, 10, 0, 0, 'Asplenium ruta', 'Normal']
# [88, 15, 0, 0, 'Asplenium haussknechtii', 'Normal']
# [88, 19, 0, 0, 'Asplenium adiantum', 'Normal']
# [89, 14, 0, 0, 'Phyllitis scolopendrium', 'Normal']
# [89, 21, 0, 0, 'Phyllitis hemionitis', 'Normal']
# [90, 11, 0, 0, 'Polypodium vulgare', 'Normal']
# [90, 22, 0, 0, 'Salvinia natans', 'Normal']
# [92, 9, 0, 0, 'Abies cilicica', 'Normal']
# [92, 16, 0, 0, 'Cedrus libani', 'Normal']
# [93, 8, 0, 0, 'Pinus pinea', 'Normal']
# [93, 15, 0, 0, 'Pina brutia', 'Normal']
# [93, 26, 0, 0, 'Pinus halepensis', 'Normal']
# [94, 14, 0, 0, 'Cupressus sempervirens', 'Normal']
# [95, 15, 0, 0, 'Juniperus oxycedrus', 'Normal']
# [96, 2, 0, 0, 'Juniper us', 'Normal']
# [96, 9, 1, 0, 'Juniperus fœtidissima', 'Normal']
# [96, 18, 0, 0, 'Arceuthos drupacea', 'Normal']
# [97, 20, 0, 0, 'Ephedra campylopoda', 'Normal']
# [97, 29, 0, 0, 'Ephedra alte', 'Normal']
# [98, 4, 0, 0, 'Ephedra alata', 'Normal']
# [99, 19, 0, 0, 'Typha latifolia', 'Normal']
# [100, 1, 0, 0, 'Typha australis', 'Normal']
# [100, 9, 0, 0, 'Typha laxmannii', 'Normal']
# [100, 23, 0, 0, 'Sparganium neglectum', 'Normal']
# [101, 8, 0, 0, 'Naias delilei', 'Normal']
# [101, 13, 3, 0, 'Naias graminea', 'Normal']
# [101, 20, 0, 0, 'Zostera nana', 'Normal']
# [102, 10, 0, 0, 'Cymodocea major', 'Normal']
# [102, 21, 0, 0, 'Ruppia maritima', 'Normal']
# [103, 4, 0, 0, 'Zannichellia palustris', 'Normal']
# [103, 32, 0, 0, 'Potamogeton nodosus', 'Normal']
# [104, 9, 0, 0, 'Potamogeton perfoliatus', 'Normal']
# [104, 13, 0, 0, 'Potamogeton crispus', 'Normal']
# [104, 17, 1, 0, 'Potamogeton den', 'Normal']
# [104, 23, 1, 0, 'Potamogeton trichoides', 'Normal']
# [105, 3, 0, 0, 'Potamogeton panor', 'Normal']
# [105, 9, 0, 0, 'Potamogeton pectinatus', 'Normal']
# [106, 5, 0, 0, 'Alisma Plantago', 'Normal']
# [106, 10, 0, 0, 'Alisma lanceolatum', 'Normal']
# [106, 15, 0, 0, 'Alisma gramineum', 'Normal']
# [107, 1, 0, 0, 'Echinodorus ranunculoides', 'Normal']
# [107, 6, 0, 0, 'Damasonium alisma', 'Normal']
# [107, 17, 0, 0, 'Damasonium poly', 'Normal']
# [108, 4, 0, 0, 'Butomus umbellatus', 'Normal']
# [108, 18, 0, 0, 'Hydrocharis morsus', 'Normal']
# [108, 28, 0, 0, 'Vallisneria spiralis', 'Normal']
# [111, 1, 0, 0, 'Digit aria', 'Normal']
# [111, 9, 0, 0, 'Brachiaria eruciformis', 'Normal']
# [111, 16, 0, 0, 'Brachiaria mutica', 'Normal']
# [112, 5, 0, 0, 'Paspalum distichum', 'Normal']
# [112, 12, 0, 0, 'Paspalidium geminatum', 'Normal']
# [113, 2, 0, 0, 'Echinochloa crus', 'Normal']
# [113, 9, 0, 0, 'Echinochloa colona', 'Normal']
# [113, 16, 0, 0, 'Panicum repens', 'Normal']
# [114, 21, 0, 0, 'Setaria viridis', 'Normal']
# [114, 30, 0, 0, 'Setaria lutescens', 'Normal']
# [115, 4, 0, 0, 'Setaria verticillata', 'Normal']
# [115, 17, 0, 0, 'Pennisetum setaceum', 'Normal']
# [116, 4, 0, 0, 'Pennisetumdivisum (C.C. Gmel.) Henrard— Panicum divisum Gmel.(Pl. XIV,', 'Possible OCR Error']
# [116, 12, 0, 0, 'Cenchrus ciliaris', 'Normal']
# [116, 20, 0, 0, 'Imperata cylindrica', 'Normal']
# [117, 8, 0, 0, 'Saccharum spontaneum', 'Normal']
# [117, 19, 0, 0, 'Erianthusravennae (L.) P.B.— Andropogon ravennaeh., \\l§3;Saccharumravennae', 'Possible OCR Error']
# [117, 24, 0, 0, 'Erianthus hostii', 'Normal']
# [118, 5, 0, 0, 'Hemarthria altissima', 'Normal']
# [118, 13, 0, 0, 'Phacelurus digitatus', 'Normal']
# [119, 7, 0, 0, 'Sorghumhalepense (L.) Pers. — Holcushalepensis L. (PI. XV, n. 5). — 2J.. Rhi-', 'Possible OCR Error']
# [120, 3, 0, 0, 'Chrysopogon gryllus', 'Normal']
# [120, 15, 0, 0, 'Themeda trianda', 'Normal']
# [121, 1, 0, 0, '2° Var. syriaca (Boiss.) Hackel. — Chaume plus robuste et taille plus élevée.', 'Possible OCR Error']
# [121, 12, 0, 0, 'Bothriochloa Ischaemum', 'Normal']
# [121, 19, 0, 0, 'Hyparrhenia hirta', 'Normal']
# [122, 11, 0, 0, 'Cymbopogon olivieri', 'Normal']
# [123, 3, 0, 0, 'Andropogon distachyus', 'Normal']
# [123, 14, 0, 0, 'Heteropogon con', 'Normal']
# [124, 14, 0, 0, 'Leersia hexandra', 'Normal']
# [125, 13, 0, 0, 'Phalaris brachystachys', 'Normal']
# [125, 20, 0, 0, 'Phalaris minor', 'Normal']
# [126, 1, 0, 0, 'Phalaris paradoxa', 'Normal']
# [126, 9, 1, 0, 'Phalaris bulbosa', 'Normal']
# [126, 16, 0, 0, 'Phalaris caerulescens', 'Normal']
# [127, 1, 0, 0, 'Phalaris arundinacea', 'Normal']
# [127, 10, 0, 0, 'Anthoxanthum odoratum', 'Normal']
# [128, 1, 0, 0, 'Aristida caerulescens', 'Normal']
# [128, 6, 0, 0, 'Aristida adscensionis', 'Normal']
# [128, 13, 0, 0, 'Aristida plumosa', 'Normal']
# [129, 3, 0, 0, 'Aristida lanata', 'Normal']
# [129, 20, 0, 0, 'Stipa bromoides', 'Normal']
# [129, 28, 0, 0, 'Stipa capensis', 'Normal']
# [130, 8, 0, 0, 'Stipa parviflora', 'Normal']
# [130, 12, 1, 0, 'Stipa fontanesii', 'Normal']
# [131, 3, 0, 0, 'Stipabarbata Desf', 'Normal']
# [132, 19, 0, 0, 'Oryzopsis miliacea', 'Normal']
# [133, 1, 0, 0, 'Oryzopsis holciformis', 'Normal']
# [133, 12, 0, 0, 'Oryzopsis caerulescens', 'Normal']
# [134, 5, 0, 0, 'Milium montianum', 'Normal']
# [134, 8, 0, 0, 'Milium pedicellare', 'Normal']
# [134, 15, 0, 0, 'Milium trichopodum', 'Normal']
# [135, 2, 0, 0, 'Cornucopiae alopecuroides', 'Normal']
# [135, 8, 1, 0, 'Cornucopiae cucullatum', 'Normal']
# [135, 18, 0, 0, 'Crypsis factorovskyi', 'Normal']
# [136, 14, 0, 0, 'Heleochloa schoenoides', 'Normal']
# [136, 23, 0, 0, 'Heleochloa alopecuroides', 'Normal']
# [137, 4, 2, 0, 'Heleochloa acutiglumis', 'Normal']
# [137, 12, 0, 0, 'Rhizocephalus orientali', 'Normal']
# [138, 1, 0, 0, 'Beckmannia eruciformis', 'Normal']
# [138, 20, 0, 0, 'Alopecurus gerardi', 'Normal']
# [138, 26, 0, 0, 'Alopecurus vaginatus', 'Normal']
# [139, 4, 1, 0, 'Alopecurus ventricosus', 'Normal']
# [139, 11, 0, 0, 'Alopecurus my', 'Normal']
# [139, 19, 0, 0, 'Alopecurus anthoxanthoides', 'Normal']
# [140, 23, 0, 0, 'Phleum subulatum', 'Normal']
# [141, 8, 0, 0, 'Phleum boissieri', 'Normal']
# [141, 16, 1, 0, 'Phleum arenarium', 'Normal']
# [141, 21, 0, 0, 'Phleum rrontanum', 'Normal']
# [143, 1, 0, 0, 'Agrostis semiverticillata', 'Normal']
# [143, 9, 0, 0, 'Agrostis stolonifera', 'Normal']
# [144, 3, 0, 0, 'Apera interrupta', 'Normal']
# [144, 13, 0, 0, 'Gastridium ventricosum', 'Normal']
# [144, 18, 0, 0, 'Gastridium scabrum', 'Normal']
# [145, 11, 0, 0, 'Polypogonmonspeliensis (L.) Desf.— Alopecurusmonspeliensish.(Pl. XXI, n. 9)', 'Possible OCR Error']
# [145, 17, 0, 0, 'Polypogon maritimus', 'Normal']
# [146, 3, 0, 0, 'Lagurus ovatus', 'Normal']
# [146, 10, 0, 0, 'Calamagrostis epigeios', 'Normal']
# [146, 16, 0, 0, 'Calamagrostis pseudophragmites', 'Normal']
# [147, 7, 0, 0, 'Ammophila arenaria', 'Normal']
# [147, 15, 0, 0, 'Sporobolus arenarius', 'Normal']
# [148, 20, 0, 0, 'Eragrostis tatarica', 'Normal']
# [148, 23, 0, 0, 'Eragrostis cilianensis', 'Normal']
# [149, 10, 0, 0, 'Eragrostis minor', 'Normal']
# [149, 15, 0, 0, 'Eragrostis pilosa', 'Normal']
# [149, 23, 0, 0, 'Dactyloctenium aegyptium', 'Normal']
# [150, 6, 0, 0, 'Cynodon dactylon', 'Normal']
# [151, 5, 0, 0, 'Arundo plinii', 'Normal']
# [151, 10, 0, 0, 'Arundo donax', 'Normal']
# [152, 2, 0, 0, 'Phragmites commuais', 'Normal']
# [152, 22, 0, 0, 'Boissiera pumilio', 'Normal']
# [153, 15, 0, 0, 'Holçus setosus', 'Normal']
# [154, 1, 0, 0, 'Holcus lanatus', 'Normal']
# [154, 12, 0, 0, 'Corynephorus articulaţii', 'Normal']
# [155, 1, 0, 0, 'Corynephorus deschampsioides', 'Normal']
# [155, 8, 0, 0, 'Pilgerochloablanche! (Boiss.) Eig— Ventenata blanchei Boiss. (PI. XXIV, n. 1).', 'Possible OCR Error']
# [155, 17, 0, 0, 'Gaudinopsis màcra', 'Normal']
# [156, 18, 0, 0, 'Trisetariacavanillesii (Trin.) Maire— Trisetum cavanillesiiTrm.,Tr.gaudinia-', 'Possible OCR Error']
# [156, 22, 1, 0, 'Trisetaria linearis', 'Normal']
# [157, 7, 0, 0, 'Trisetaria koelerioides', 'Normal']
# [157, 19, 0, 0, 'Trisetaria fiavescens', 'Normal']
# [158, 29, 0, 0, 'Avena sativa', 'Normal']
# [159, 10, 0, 0, 'Avena clauda', 'Normal']
# [159, 14, 1, 0, 'Avena pilosa', 'Normal']
# [159, 18, 1, 0, 'Avena sterilis', 'Normal']
# [160, 6, 1, 0, 'Àvenaalba Vahl — A. barbata Potter (PI. XXV, n. 2). — ©. Chaumes soli-', 'Possible OCR Error']
# [160, 16, 0, 0, 'A vena pratensis L. (PI. XXV, n. 3). — 2J.. Souche cespiteuse, produisant des-,', 'Possible OCR Error']
# [161, 1, 0, 0, 'Avena convoluta', 'Normal']
# [161, 15, 0, 0, 'Arrenatherum elatius', 'Normal']
# [162, 2, 0, 0, 'Arrhenatherum palaestinum', 'Normal']
# [162, 9, 0, 0, 'Arrhenatherum kotschyi', 'Normal']
# [162, 19, 0, 0, 'Lycochloa avenacea', 'Normal']
# [163, 6, 0, 0, 'Gaudinia fragilis', 'Normal']
# [163, 22, 0, 0, 'Koeleria nitidula', 'Normal']
# [164, 4, 0, 0, 'Koeleria phleoides', 'Normal']
# [165, 25, 0, 0, 'Antinoria insulari', 'Normal']
# [166, 3, 0, 0, 'Aira elegans', 'Normal']
# [166, 10, 0, 0, 'Schismus arabicus', 'Normal']
# [167, 4, 0, 0, 'Sesleria anatolica', 'Normal']
# [167, 13, 0, 0, 'Ammochloa palaestina', 'Normal']
# [168, 5, 0, 0, 'Echinaria capitata', 'Normal']
# [169, 1, 0, 0, 'Melica uniflora', 'Normal']
# [169, 3, 3, 0, 'Melica angustifolia', 'Normal']
# [169, 11, 0, 0, 'Melica cupani', 'Normal']
# [170, 1, 0, 0, 'Melica inaequiglumis', 'Normal']
# [170, 11, 1, 0, 'Melica pannosa', 'Normal']
# [170, 15, 1, 0, 'Melica ciliata', 'Normal']
# [171, 5, 0, 0, 'Molinia caemlea', 'Normal']
# [171, 11, 0, 0, 'Catabrosa aquatica', 'Normal']
# [172, 6, 0, 0, 'Colpodium humile', 'Normal']
# [172, 12, 0, 0, 'Sphenopus divaricatus', 'Normal']
# [173, 4, 0, 0, 'Cutandia philistaea', 'Normal']
# [173, 8, 0, 0, 'Cutandia maritima', 'Normal']
# [173, 14, 0, 0, 'Cutandia memphitica', 'Normal']
# [174, 1, 0, 0, 'Cutandia dichotoma', 'Normal']
# [174, 13, 1, 0, 'Cynosurus echinatus', 'Normal']
# [174, 25, 1, 0, 'Cynosurus coloratus', 'Normal']
# [175, 5, 0, 0, 'Cynosurus effusus', 'Normal']
# [175, 13, 0, 0, 'Lamarckia aurea', 'Normal']
# [176, 9, 0, 0, 'Dactylis glomerata', 'Normal']
# [177, 10, 0, 0, 'Aeluropus littoral', 'Normal']
# [178, 1, 0, 0, 'Sclerochloa dura', 'Normal']
# [179, 24, 0, 0, 'Poa chaixii', 'Normal']
# [179, 27, 0, 0, 'Poa diversifolia', 'Normal']
# [180, 5, 0, 0, 'Poa annua', 'Normal']
# [180, 12, 1, 0, 'Poa infirma', 'Normal']
# [180, 21, 0, 0, 'Poa hackeli', 'Normal']
# [181, 3, 0, 0, 'Poa pratensis', 'Normal']
# [181, 10, 0, 0, 'Poa silvicola', 'Normal']
# [181, 15, 0, 0, 'Poa trivialis', 'Normal']
# [182, 7, 0, 0, 'Poa compressa', 'Normal']
# [182, 12, 0, 0, 'Poa bulbosa', 'Normal']
# [183, 1, 0, 0, 'Poa sinaica', 'Normal']
# [183, 6, 0, 0, 'Poa timoleontis', 'Normal']
# [183, 11, 0, 0, 'Poa sterilis', 'Normal']
# [183, 14, 0, 0, 'Poa nemoralis', 'Normal']
# [184, 5, 0, 0, 'Poa persica', 'Normal']
# [185, 1, 0, 0, 'Briza maxima', 'Normal']
# [185, 7, 1, 0, 'Briza minor', 'Normal']
# [185, 13, 0, 0, 'Briza spicata', 'Normal']
# [186, 1, 0, 0, 'Glyceria plicata', 'Normal']
# [186, 17, 0, 0, 'Puccinellia rupestris', 'Normal']
# [187, 1, 0, 0, 'Puccinellia distans', 'Normal']
# [187, 6, 0, 0, 'Puccinellia convoluta', 'Normal']
# [188, 12, 0, 0, 'Festuca indigesta', 'Normal']
# [188, 17, 0, 0, 'Festuca valesiaca', 'Normal']
# [189, 1, 0, 0, 'Festuca laevis', 'Normal']
# [189, 12, 0, 0, 'Festuca pratensis', 'Normal']
# [190, 1, 0, 0, 'Festuca arundinacea', 'Normal']
# [191, 1, 0, 0, 'Vulpia myuros', 'Normal']
# [191, 12, 0, 0, 'Vulpia dertonensis', 'Normal']
# [191, 18, 0, 0, 'Vulpia ciliata', 'Normal']
# [192, 11, 0, 0, 'Vulpia hirtiglumis', 'Normal']
# [192, 17, 0, 0, 'Vulpia membranacea', 'Normal']
# [193, 1, 0, 0, 'Vulpia inops', 'Normal']
# [193, 6, 0, 0, 'Ctenopsis patens', 'Normal']
# [194, 4, 0, 0, 'Catapodium rigidum', 'Normal']
# [194, 11, 0, 0, 'Catapodium loliaceum', 'Normal']
# [195, 5, 0, 0, 'Nardurus maritimus', 'Normal']
# [195, 10, 1, 0, 'Nardurus orientalis', 'Normal']
# [197, 17, 0, 0, 'Bromus syriacus', 'Normal']
# [197, 22, 0, 0, 'Bromus bikfayensis', 'Normal']
# [198, 2, 4, 0, 'Bromus tomentellus', 'Normal']
# [198, 10, 1, 0, 'Bromus tectorum', 'Normal']
# [199, 6, 1, 0, 'Bromus sterilis', 'Normal']
# [199, 14, 0, 0, 'Bromus madritensis', 'Normal']
# [200, 8, 0, 0, 'Bromus rigidus', 'Normal']
# [200, 17, 0, 0, 'Bromus flabellatus', 'Normal']
# [201, 7, 0, 0, 'Bromus rubens', 'Normal']
# [201, 13, 0, 0, 'Bromus fasciculatus', 'Normal']
# [202, 5, 0, 0, 'Bromus scoparius', 'Normal']
# [202, 14, 1, 0, 'Bromus alopecuros', 'Normal']
# [203, 5, 0, 0, 'Brotnus lanceolatus', 'Normal']
# [204, 3, 0, 0, 'Bromus danthoniae', 'Normal']
# [204, 16, 0, 0, 'Bromus squarrosus', 'Normal']
# [205, 7, 0, 0, 'Bromus intermedius', 'Normal']
# [205, 12, 0, 0, 'Bromus palaestinus', 'Normal']
# [206, 5, 0, 0, 'Bromus brachystachys', 'Normal']
# [206, 11, 0, 0, 'Bromus arvensis', 'Normal']
# [206, 19, 0, 0, 'BromushordeaceusL. {Br. mollis L.).— Espèce européenne indiquée à tort', 'Possible OCR Error']
# [206, 21, 0, 0, 'Bromus japonicus', 'Normal']
# [207, 12, 0, 0, 'Trachynia distachya', 'Normal']
# [208, 11, 0, 0, 'Brachypodium sylvaticum', 'Normal']
# [208, 20, 1, 0, 'Brachypodium pinnatum', 'Normal']
# [209, 3, 0, 0, 'Brachypodium ramosum', 'Normal']
# [209, 25, 0, 0, 'Lolium temulentum', 'Normal']
# [210, 11, 0, 0, 'Lolium perenne', 'Normal']
# [210, 18, 0, 0, 'Lolium rigidum', 'Normal']
# [211, 1, 0, 0, 'Lolium loliaceum', 'Normal']
# [211, 4, 0, 0, 'Lolium multiflorum', 'Normal']
# [211, 15, 0, 0, 'Lolium persicum', 'Normal']
# [212, 19, 0, 0, 'Psilurus incurvus', 'Normal']
# [213, 3, 0, 0, 'Monerma cylindrica', 'Normal']
# [213, 10, 0, 0, 'Parapholis incurva', 'Normal']
# [214, 7, 0, 0, 'Henrardia persica', 'Normal']
# [215, 1, 0, 0, 'Agropyron panormitanum', 'Normal']
# [215, 11, 0, 0, 'Agropyron repens', 'Normal']
# [216, 1, 0, 0, 'Agropyron libanoticum', 'Normal']
# [216, 8, 0, 0, 'Agropyron aucheri', 'Normal']
# [217, 1, 0, 0, 'Agropyron elongatum', 'Normal']
# [217, 7, 1, 0, 'Agropyron junceum', 'Normal']
# [217, 15, 0, 0, 'Eremopyrum buonapartis', 'Normal']
# [218, 5, 0, 0, 'Eremopyrum distans', 'Normal']
# [218, 11, 0, 0, 'Secale cereale', 'Normal']
# [219, 1, 0, 0, 'Secale montanum', 'Normal']
# [219, 11, 0, 0, 'Heteranthelium piliferuxn', 'Normal']
# [220, 7, 0, 0, 'Triticum thaoudar', 'Normal']
# [220, 15, 1, 0, 'Triticum dicoccoides', 'Normal']
# [221, 1, 0, 0, 'Aegilotricum loreti', 'Normal']
# [223, 13, 0, 0, 'Aegilops ovata', 'Normal']
# [223, 20, 0, 0, 'Aegilops umbellulata', 'Normal']
# [223, 23, 0, 0, 'Aegilops triaristata', 'Normal']
# [224, 6, 0, 0, 'Aegilops columnaris', 'Normal']
# [224, 11, 0, 0, 'Aegilops biuncialis', 'Normal']
# [224, 19, 0, 0, 'Aegilops triuncialis', 'Normal']
# [225, 22, 0, 0, 'Aegilops kotschyi', 'Normal']
# [226, 10, 0, 0, 'Aegilops peregrina', 'Normal']
# [227, 17, 0, 0, 'Aegilops cylindrica', 'Normal']
# [227, 20, 0, 0, 'Aegilops caudata', 'Normal']
# [228, 3, 4, 0, 'Aegilops ventricosa', 'Normal']
# [228, 8, 0, 0, 'Aegilops crassa', 'Normal']
# [229, 5, 0, 0, 'Aegilops juvenalis', 'Normal']
# [229, 11, 0, 0, 'Aegilops squarrosa', 'Normal']
# [229, 14, 0, 0, 'Aegilops longissima', 'Normal']
# [230, 8, 0, 0, 'Aegilops ligustica', 'Normal']
# [230, 15, 0, 0, 'Aegilops speltoides', 'Normal']
# [231, 28, 0, 0, 'Hordeum spontaneum', 'Normal']
# [232, 10, 0, 0, 'Hordeum hystrix', 'Normal']
# [232, 21, 0, 0, 'Hordeum leporinum', 'Normal']
# [233, 8, 0, 0, 'Hordeum murinum', 'Normal']
# [233, 16, 0, 0, 'Hordeum bulbosum', 'Normal']
# [234, 1, 0, 0, 'Hordeum nodosum', 'Normal']
# [234, 11, 0, 0, 'Taeniatherum crinitum', 'Normal']
# [235, 5, 0, 0, 'Crithopsis delileana', 'Normal']
# [237, 11, 0, 0, 'Cyperus flavescens', 'Normal']
# [237, 16, 0, 0, 'Cyperus globosus', 'Normal']
# [237, 22, 0, 0, 'Cyperus mundtii', 'Normal']
# [238, 3, 0, 0, 'Cyperus laevigatus', 'Normal']
# [238, 9, 0, 0, 'Cyperus dîstachyos', 'Normal']
# [238, 13, 0, 0, 'Cyperus alopecuroides', 'Normal']
# [239, 1, 0, 0, 'Cyperus michelianus', 'Normal']
# [239, 5, 0, 0, 'Cyperus kalli', 'Normal']
# [240, 4, 0, 0, 'Cyperus difformis', 'Normal']
# [240, 11, 0, 0, 'Cyperus glaber', 'Normal']
# [240, 22, 0, 0, '^^ă^Cyperus longus L. (PI. XLVIII, n. 2). — ¾. Rhizome rampant, induré,', 'Possible OCR Error']
# [241, 9, 0, 0, 'Cyperus rotundus', 'Normal']
# [241, 19, 0, 0, 'Cyperus esculentus', 'Normal']
# [242, 28, 0, 0, 'Scirpus setaceus', 'Normal']
# [243, 1, 0, 0, 'Scirpus cernuus', 'Normal']
# [243, 7, 0, 0, 'Scirpus holoschoenus', 'Normal']
# [243, 26, 0, 0, 'Scirpus mucronatus', 'Normal']
# [244, 5, 0, 0, 'Scirpus lacustris', 'Normal']
# [244, 12, 0, 0, 'Scirpus littoralis', 'Normal']
# [244, 17, 0, 0, 'Scirpus tuberosus', 'Normal']
# [245, 14, 0, 0, 'Blysmus compressus', 'Normal']
# [246, 1, 0, 0, 'Fuirena pub', 'Normal']
# [246, 12, 0, 0, 'Heleocharis palustris', 'Normal']
# [246, 19, 0, 0, 'Heleocharis macrantha', 'Normal']
# [247, 14, 0, 0, 'Fimbristylis ferruginea', 'Normal']
# [247, 20, 0, 0, 'Fimbristylis bis', 'Normal']
# [247, 21, 1, 0, 'III, p. 13) (PI. L, n. 3). — (J). Plante verte ou glaucescente. Tiges fasciculées formant des touffes denses, 2-30 cm. Gaines pubescentes, limbes plans et fins pouvant', 'Possible OCR Error']
# [248, 7, 0, 0, 'Rhynchospora glauca', 'Normal']
# [248, 18, 0, 0, 'Schoenus nigricans', 'Normal']
# [249, 6, 0, 0, 'Cladium mariscus', 'Normal']
# [251, 16, 0, 0, 'Garex stenophylla', 'Normal']
# [251, 30, 0, 0, 'Carex divisa', 'Normal']
# [252, 8, 0, 0, 'Carex otrubae', 'Normal']
# [252, 14, 0, 0, 'Carexdivulsa Stokeş', 'Normal']
# [253, 3, 0, 0, 'Carex pairaei', 'Normal']
# [253, 14, 0, 0, 'Carex stellulata', 'Normal']
# [253, 21, 0, 0, 'Garex leporina', 'Normal']
# [254, 5, 0, 0, 'Carex phyllostachys', 'Normal']
# [254, 12, 0, 0, 'Carex halleriana', 'Normal']
# [254, 24, 0, 0, 'Carex pallescens', 'Normal']
# [255, 4, 0, 0, 'Carex flacca', 'Normal']
# [255, 17, 0, 0, 'Carex hispida', 'Normal']
# [256, 3, 0, 0, 'Garex gracilis', 'Normal']
# [256, 16, 0, 0, 'Carex buekii', 'Normal']
# [257, 5, 1, 0, 'Carex extensa', 'Normal']
# [257, 10, 3, 0, 'Carex pendula', 'Normal']
# [258, 1, 0, 0, 'Carex distans', 'Normal']
# [258, 9, 0, 0, 'Cartex pseudocyperus', 'Normal']
# [258, 19, 0, 0, 'Carex acutiformis', 'Normal']
# [259, 7, 0, 0, 'Carex riparia', 'Normal']
# [261, 11, 0, 0, 'Arum dioscoridis', 'Normal']
# [262, 7, 0, 0, 'Arum palaestinum', 'Normal']
# [264, 7, 0, 0, 'Arum hygrophilum', 'Normal']
# [264, 16, 0, 0, 'Arum conophalloides', 'Normal']
# [265, 8, 0, 0, 'Arum elongatum', 'Normal']
# [266, 2, 0, 0, 'Arum gratum', 'Normal']
# [266, 9, 0, 0, 'Arum italicum', 'Normal']
# [267, 13, 0, 0, 'Arisarum vulgare', 'Normal']
# [268, 2, 0, 0, 'Eminium intortum', 'Normal']
# [268, 7, 1, 0, 'Eminium spiculatum', 'Normal']
# [269, 23, 0, 0, 'Biarum bovei', 'Normal']
# [270, 1, 0, 0, 'Biarum aleppicum', 'Normal']
# [270, 8, 1, 0, 'Biarum auraniticum', 'Normal']
# [270, 18, 0, 0, 'Biarum angustatum', 'Normal']
# [271, 5, 0, 0, 'Biarum pyrami', 'Normal']
# [271, 10, 0, 0, 'Biarum russellianum', 'Normal']
# [272, 17, 0, 0, 'Lemna minor', 'Normal']
# [272, 25, 0, 0, 'Lemna gibba', 'Normal']
# [272, 28, 0, 0, 'Lemna trisulca', 'Normal']
# [273, 1, 0, 0, 'Spirodela polyrrhiza', 'Normal']
# [273, 14, 0, 0, 'Luzula forsteri', 'Normal']
# [275, 6, 0, 0, 'Juncus inflexus', 'Normal']
# [275, 19, 0, 0, 'Juncus acutus', 'Normal']
# [276, 8, 0, 0, 'Juncus maritimus', 'Normal']
# [276, 14, 0, 0, 'Juncus subulatus', 'Normal']
# [277, 2, 0, 0, 'Juncus gerardi', 'Normal']
# [277, 9, 0, 0, 'Juncus punctorius', 'Normal']
# [278, 2, 0, 0, '^-^ Juncus articulatus L. — Juncus lamprocarpus Ehrh. (PI. LXI, n. 2). —', 'Possible OCR Error']
# [278, 7, 1, 0, 'Juncus fontanesiij', 'Normal']
# [279, 1, 0, 0, 'Juncus pygmaeus', 'Normal']
# [279, 6, 0, 0, 'Juncus capitatus', 'Normal']
# [279, 13, 0, 0, 'Juncus bufonius', 'Normal']
# [280, 1, 0, 0, 'Juncus tenageia', 'Normal']
# [282, 14, 0, 0, 'Colchicum decaisnei', 'Normal']
# [283, 3, 0, 0, 'Colchicum hierosolymitanum', 'Normal']
# [283, 10, 0, 0, 'Colchicum balansae', 'Normal']
# [283, 13, 0, 0, 'Colchicun haussknechtii', 'Normal']
# [284, 1, 0, 0, 'Colchicum byzantinum', 'Normal']
# [284, 5, 0, 0, 'Colchicum tunicatum', 'Normal']
# [284, 7, 3, 0, 'Colchicum tauri', 'Normal']
# [284, 16, 0, 0, 'Colchicum fasciculare', 'Normal']
# [285, 6, 0, 0, 'Colchicum deşerţi', 'Normal']
# [285, 11, 0, 0, 'Colchicum libanoticum', 'Normal']
# [285, 16, 0, 0, 'Colchicum brachyphyllum', 'Normal']
# [286, 4, 0, 0, 'Colchicum tuviae', 'Normal']
# [286, 7, 0, 0, 'Colchicum crocifolium', 'Normal']
# [286, 12, 0, 0, 'Colchicum steveni', 'Normal']
# [287, 14, 0, 0, 'Merendera sobolifera', 'Normal']
# [288, 5, 0, 0, 'Androcymbium palaestinum', 'Normal']
# [289, 17, 0, 0, 'Asphodelus microcarpus', 'Normal']
# [289, 23, 2, 0, 'Asphodelus fistulosus', 'Normal']
# [290, 9, 0, 0, 'Asphodeline lutea', 'Normal']
# [290, 17, 0, 0, 'Asphodeline liburnica', 'Normal']
# [291, 3, 0, 0, 'Asphodeline brevicaulis', 'Normal']
# [291, 11, 1, 0, 'Asphodeline edumea', 'Normal']
# [293, 3, 0, 0, 'Asphodeline taurica', 'Normal']
# [293, 7, 1, 0, 'Asphodeline globifera', 'Normal']
# [293, 13, 1, 0, 'Asphodeline isthmocarpa', 'Normal']
# [293, 17, 1, 0, 'Asphodeline damascena', 'Normal']
# [294, 7, 0, 0, 'Eremurus spectabilis', 'Normal']
# [294, 13, 1, 0, 'Eremurus inderiensis', 'Normal']
# [295, 3, 0, 0, 'Aloe vera', 'Normal']
# [296, 29, 0, 0, 'Lloydia rubroviridis', 'Normal']
# [297, 9, 0, 0, 'Gagea anisanthos', 'Normal']
# [297, 18, 0, 0, 'Gagea arvensis', 'Normal']
# [298, 3, 0, 0, 'Gagea peduncularis', 'Normal']
# [298, 11, 1, 0, 'Gagea dubia', 'Normal']
# [299, 12, 0, 0, 'Gagea micrantha', 'Normal']
# [300, 7, 0, 0, 'Gagea minima', 'Normal']
# [300, 11, 0, 0, 'Gagea bohemica', 'Normal']
# [300, 18, 0, 0, 'Gagea reticulata', 'Normal']
# [301, 13, 0, 0, 'Gagea procera', 'Normal']
# [302, 4, 0, 0, 'Gagea circinnata', 'Normal']
# [302, 9, 0, 0, 'Gagea dayana', 'Normal']
# [302, 13, 1, 0, 'Gagea chlorantha', 'Normal']
# [303, 12, 0, 0, 'Gagea gageoides', 'Normal']
# [304, 13, 0, 0, 'Tulipa aucheriana', 'Normal']
# [305, 6, 0, 0, 'Tulipa lownei', 'Normal']
# [305, 12, 1, 0, 'Tulipa aff', 'Normal']
# [306, 3, 0, 0, 'Tulipa agenensis', 'Normal']
# [306, 10, 0, 0, 'Tulipa aleppensis', 'Normal']
# [307, 10, 0, 0, 'Tulipa praecox', 'Normal']
# [308, 9, 0, 0, 'Tulipa montana', 'Normal']
# [310, 1, 0, 0, 'Fritillaria elwesii', 'Normal']
# [310, 5, 0, 0, 'Fritillaria acmopetala', 'Normal']
# [310, 10, 0, 0, 'Fritillaria alfredae', 'Normal']
# [311, 3, 0, 0, 'Fritillaria crassifolia', 'Normal']
# [311, 16, 0, 0, 'Fritillaria pinardi', 'Normal']
# [312, 8, 0, 0, 'Fritillaria libanotica', 'Normal']
# [312, 15, 0, 0, 'Fritillaria persica', 'Normal']
# [313, 3, 0, 0, 'Lilium candidum', 'Normal']
# [314, 5, 0, 0, 'Scilla autumnalis', 'Normal']
# [314, 10, 0, 0, 'Scilla hanburyi', 'Normal']
# [314, 15, 1, 0, 'Scilla hyacinthoides', 'Normal']
# [314, 22, 0, 0, 'Scilla cilicica', 'Normal']
# [315, 8, 0, 0, 'Scillâ sibirica', 'Normal']
# [315, 12, 0, 0, 'Scilla bifolia', 'Normal']
# [315, 20, 0, 0, 'Urginea maritima', 'Normal']
# [317, 16, 0, 0, 'Ornithogalum libanoticum', 'Normal']
# [317, 22, 1, 0, 'Ornithogalum pyrenaicum', 'Normal']
# [318, 1, 0, 0, 'Ornithogalum narbonense', 'Normal']
# [318, 15, 0, 0, 'Ornithogalum densumBoiss', 'Normal']
# [318, 19, 2, 0, 'Ornithogalum fucescens', 'Normal']
# [319, 9, 0, 0, 'Ornithogalum arabicum', 'Normal']
# [319, 12, 0, 0, 'Ornithogalum billardieri', 'Normal']
# [320, 10, 0, 0, 'Ornithogalum montanum', 'Normal']
# [320, 17, 0, 0, 'Ornithogalum platyphyllum', 'Normal']
# [321, 10, 0, 0, 'Ornithogalum neurostegium', 'Normal']
# [322, 4, 3, 0, 'Ornithogalum paterfamilias', 'Normal']
# [322, 9, 0, 0, 'Ornithogalum divergens', 'Normal']
# [322, 16, 0, 0, 'Ornithogalum tenuifolium', 'Normal']
# [323, 5, 0, 0, 'Puschkinia scilloides', 'Normal']
# [323, 12, 0, 0, 'Hyacinthus orientalis', 'Normal']
# [324, 3, 0, 0, 'Hyacinthella nervosa', 'Normal']
# [325, 6, 0, 0, 'Bellevalia trifoliata', 'Normal']
# [325, 18, 0, 0, 'Bellevalia macrobotrys', 'Normal']
# [325, 25, 0, 0, 'Bellevalia longipes', 'Normal']
# [326, 5, 0, 0, 'Bellevalia ciliata', 'Normal']
# [326, 13, 0, 0, 'Bellevalia douini', 'Normal']
# [327, 6, 0, 0, 'Bellevalia palmyrensis', 'Normal']
# [327, 11, 0, 0, 'Bellevalia hermonis', 'Normal']
# [328, 1, 0, 0, 'Bellevalia densiflora', 'Normal']
# [328, 6, 0, 0, 'Bellevalia nivalis', 'Normal']
# [328, 15, 0, 0, 'Bellevalia flexuosa', 'Normal']
# [329, 6, 0, 0, 'Bellevalia Mosheovii', 'Normal']
# [330, 8, 0, 0, 'Muscari dinsmorei', 'Normal']
# [330, 14, 0, 0, 'Muscari pinardi', 'Normal']
# [330, 24, 1, 0, 'Muscari comosum', 'Normal']
# [331, 7, 0, 0, 'Muscari longipes', 'Normal']
# [332, 4, 0, 0, 'Muscari maritimum', 'Normal']
# [332, 13, 0, 0, 'Muscari racemosum', 'Normal']
# [333, 3, 0, 0, 'Muscari neglectum', 'Normal']
# [333, 13, 0, 0, 'Muscari commutatum', 'Normal']
# [334, 1, 0, 0, 'Muscari parviflorum', 'Normal']
# [339, 27, 0, 0, 'Allium sativum', 'Normal']
# [340, 3, 0, 0, 'Allium ampeloprasum', 'Normal']
# [341, 7, 0, 0, 'Allium pseudophanerantherum', 'Normal']
# [341, 10, 0, 0, 'Allium pseudocalyptratum', 'Normal']
# [342, 3, 0, 0, 'Allium calyptratum', 'Normal']
# [342, 7, 0, 0, 'Allium drusorum', 'Normal']
# [342, 10, 0, 0, 'Allium rotundum', 'Normal']
# [343, 5, 0, 0, 'Allium damascenum', 'Normal']
# [343, 7, 4, 0, 'Allium vineale', 'Normal']
# [344, 1, 0, 0, 'Allium phanerantherum', 'Normal']
# [344, 6, 0, 0, 'Allium affine', 'Normal']
# [344, 12, 0, 0, 'Allium macrochaetum', 'Normal']
# [345, 5, 0, 0, 'Allium arvense', 'Normal']
# [345, 12, 0, 0, 'Allium makmelianum', 'Normal']
# [345, 19, 0, 0, 'Allium descendens', 'Normal']
# [346, 4, 0, 0, 'Allium curtum', 'Normal']
# [346, 12, 0, 0, 'Allium emarginatum', 'Normal']
# [347, 5, 0, 0, 'Allium karyateini', 'Normal']
# [347, 14, 0, 0, 'Allium deserti', 'Normal']
# [348, 1, 0, 0, 'Allium artemisietorum', 'Normal']
# [348, 3, 3, 0, 'Allium hierochuntinum', 'Normal']
# [348, 7, 1, 0, 'Allium sannineum', 'Normal']
# [348, 9, 3, 0, 'Allium schergianum', 'Normal']
# [349, 5, 0, 0, 'Allium bassitense', 'Normal']
# [349, 9, 0, 0, 'Allium stamineum', 'Normal']
# [350, 1, 0, 0, 'Allium myrianthum', 'Normal']
# [350, 11, 0, 0, 'Allium wiedemannianum', 'Normal']
# [350, 14, 0, 0, 'Allium rupicolum', 'Normal']
# [351, 10, 0, 0, 'Allium paniculatum', 'Normal']
# [351, 16, 0, 0, 'Allium opacuxn', 'Normal']
# [352, 2, 0, 0, 'Allium chloranthum', 'Normal']
# [352, 14, 0, 0, 'Allium coppoleri', 'Normal']
# [352, 19, 1, 0, 'Allium feinbergii', 'Normal']
# [353, 5, 0, 0, 'Allium sindjarense', 'Normal']
# [353, 10, 0, 0, 'Allium azaurenum', 'Normal']
# [354, 4, 0, 0, 'Allium libani', 'Normal']
# [354, 14, 0, 0, 'Allium erdelii', 'Normal']
# [355, 4, 0, 0, 'Allium trifoliatum', 'Normal']
# [356, 5, 0, 0, 'Allium cassium', 'Normal']
# [356, 13, 0, 0, 'Allium eriophyUum', 'Normal']
# [356, 16, 0, 0, 'Allium zebdanense', 'Normal']
# [357, 3, 0, 0, 'Allium laceratum', 'Normal']
# [357, 6, 0, 0, 'Allium carmeli', 'Normal']
# [357, 11, 0, 0, 'Allium qasyunense', 'Normal']
# [357, 14, 0, 0, 'Allium neapolitanum', 'Normal']
# [358, 6, 0, 0, 'Allium schuberti', 'Normal']
# [358, 13, 0, 0, 'Allium nigrum', 'Normal']
# [359, 12, 0, 0, 'Allium chrysantherum', 'Normal']
# [359, 18, 1, 0, 'Allium lycaonicum', 'Normal']
# [360, 5, 0, 0, 'Allium orientale', 'Normal']
# [360, 11, 0, 0, 'Allium asclepiadeum', 'Normal']
# [360, 18, 0, 0, 'Allium aschersonianum', 'Normal']
# [361, 8, 0, 0, 'Allium rothii', 'Normal']
# [361, 17, 0, 0, 'Allium noëanum', 'Normal']
# [362, 5, 0, 0, 'Allium olivieri', 'Normal']
# [363, 11, 0, 0, 'Asparagus trichophyllus', 'Normal']
# [363, 17, 0, 0, 'Asparagus officinalis', 'Normal']
# [363, 21, 0, 0, 'Asparagus acutifolius', 'Normal']
# [364, 7, 0, 0, 'Asparagus aphyllus', 'Normal']
# [364, 12, 0, 0, 'Asparagus stipularis', 'Normal']
# [365, 3, 0, 0, 'Ruscus aculeatus', 'Normal']
# [365, 9, 0, 0, 'Danaë racemosa', 'Normal']
# [365, 18, 0, 0, 'Smilax aspera', 'Normal']
# [366, 15, 0, 0, 'Smilax excelsa', 'Normal']
# [367, 3, 0, 0, 'Galanthus fosteri', 'Normal']
# [367, 19, 0, 0, 'Sternbergia colchiciflora', 'Normal']
# [368, 1, 0, 0, 'Sternbergia pulchella', 'Normal']
# [368, 6, 0, 0, 'Sternbergia fischeriana', 'Normal']
# [368, 9, 0, 0, 'Sternbergia clusiana', 'Normal']
# [369, 1, 0, 0, 'Narcissus tazzetta', 'Normal']
# [369, 12, 0, 0, 'Narcissus serotinus', 'Normal']
# [370, 6, 0, 0, 'Pancratium parviflorum', 'Normal']
# [370, 12, 0, 0, 'Ixiolirion tataricum', 'Normal']
# [371, 10, 0, 0, 'Tamus communis', 'Normal']
# [371, 19, 0, 0, 'Tamus orientali', 'Normal']
# [373, 24, 0, 0, 'Crocus ochroleucus', 'Normal']
# [374, 1, 0, 0, 'Crocus kotschyanus', 'Normal']
# [374, 7, 0, 0, 'Crocus thiebauti', 'Normal']
# [374, 14, 0, 0, 'Crocus haussknechtii', 'Normal']
# [375, 5, 0, 0, 'Crocus elwesii', 'Normal']
# [375, 12, 0, 0, 'Crocus dispathaceus', 'Normal']
# [376, 1, 0, 0, 'Crocus macrobolbos', 'Normal']
# [376, 6, 0, 0, 'Crocus cancellatus', 'Normal']
# [378, 16, 0, 0, 'Crocus aleppicus', 'Normal']
# [379, 7, 0, 0, 'Crocus hyemalis', 'Normal']
# [379, 12, 0, 0, 'Crocus vitellinus', 'Normal']
# [380, 2, 0, 0, 'Crocus graveolens', 'Normal']
# [380, 23, 0, 0, 'Gladiolus segetum', 'Normal']
# [381, 11, 0, 0, 'Gladiolus imbricatus', 'Normal']
# [382, 1, 0, 0, 'Gladiolus aleppicus', 'Normal']
# [382, 11, 0, 0, 'Gynandriris sisyrinchium', 'Normal']
# [385, 34, 0, 0, 'Iris histrio', 'Normal']
# [386, 7, 0, 0, 'Iris vartani', 'Normal']
# [386, 11, 0, 0, 'Iris persica', 'Normal']
# [386, 15, 1, 0, 'Iris postii', 'Normal']
# [387, 11, 0, 0, 'Iris palaestina', 'Normal']
# [388, 1, 0, 0, 'Iris nusairiensis', 'Normal']
# [388, 7, 1, 0, 'Iris sindjarensis', 'Normal']
# [388, 13, 1, 0, 'Iris fumosa', 'Normal']
# [389, 6, 0, 0, 'Iris unguicularis', 'Normal']
# [389, 11, 0, 0, 'Iris grant', 'Normal']
# [389, 14, 0, 0, 'Iris caeruleo', 'Normal']
# [390, 5, 0, 0, 'Iris melanosticta', 'Normal']
# [390, 16, 0, 0, 'Iris ochroleuca', 'Normal']
# [391, 4, 0, 0, 'Iris mesopotamica', 'Normal']
# [391, 10, 0, 0, 'Iris albicans', 'Normal']
# [392, 9, 0, 0, 'Iris auranitica', 'Normal']
# [392, 14, 0, 0, 'Iris barnumae', 'Normal']
# [393, 8, 0, 0, 'Iris jordana', 'Normal']
# [393, 13, 0, 0, 'Iris antilibanotica', 'Normal']
# [394, 4, 0, 0, 'Iris basaltica', 'Normal']
# [394, 11, 0, 0, 'Iris bostrensis', 'Normal']
# [394, 18, 0, 0, 'Iris heylandiana', 'Normal']
# [395, 3, 0, 0, 'Iris călcarea', 'Normal']
# [395, 12, 0, 0, 'Iris cedreti', 'Normal']
# [395, 14, 0, 0, 'Iris yebrudi', 'Normal']
# [395, 16, 0, 0, 'Iris damascena', 'Normal']
# [396, 5, 0, 0, 'Iris sofarana', 'Normal']
# [396, 17, 0, 0, 'Iris lortetii', 'Normal']
# [397, 1, 0, 0, 'Iris bismarckiana', 'Normal']
# [397, 22, 0, 0, 'Romulea bulbocodium', 'Normal']
# [398, 8, 0, 0, 'Romulea nivalis', 'Normal']
# [398, 15, 0, 0, 'Romulea phoenicia', 'Normal']
# [399, 1, 0, 0, 'Romulea ramiflora', 'Normal']
# [399, 6, 0, 0, 'Romulea columnae', 'Normal']
# [400, 3, 0, 0, 'Spiranthes autumnalis', 'Normal']
# [400, 10, 0, 0, 'Limodorum abortivum', 'Normal']
# [401, 11, 0, 0, 'Cephalanthera kurdica', 'Normal']
# [401, 16, 0, 0, 'Cephalanthera rubra', 'Normal']
# [402, 2, 3, 0, 'Cephalanthera longifolia', 'Normal']
# [402, 16, 0, 0, 'Epipactis consimilis', 'Normal']
# [403, 5, 0, 0, 'Epipactis latifolia', 'Normal']
# [403, 13, 0, 0, 'Platanthera chlorantha', 'Normal']
# [404, 7, 0, 0, 'Neotinea intacta', 'Normal']
# [406, 1, 0, 0, 'Ophrys fusca', 'Normal']
# [406, 8, 0, 0, 'Ophrys iricolor', 'Normal']
# [407, 3, 0, 0, 'Ophrys lutea', 'Normal']
# [407, 10, 0, 0, 'Ophrys speculum', 'Normal']
# [407, 17, 0, 0, 'Ophrys fuciflora', 'Normal']
# [408, 5, 0, 0, 'Ophrys bornmuelleri', 'Normal']
# [408, 12, 0, 0, 'Ophrys attica', 'Normal']
# [409, 13, 0, 0, 'Ophrys scolopax', 'Normal']
# [410, 6, 0, 0, 'Ophrys apifera', 'Normal']
# [410, 11, 0, 0, 'Ophrys argolica', 'Normal']
# [411, 3, 0, 0, 'Ophrys sintenesii', 'Normal']
# [412, 37, 0, 0, 'Orchis comperiana', 'Normal']
# [413, 5, 0, 0, 'Orchis papilionacea', 'Normal']
# [413, 12, 0, 0, 'Orchis morio', 'Normal']
# [414, 10, 0, 0, 'Orchis coriophora', 'Normal']
# [414, 16, 0, 0, 'Orchis sancta', 'Normal']
# [415, 4, 0, 0, 'Orchis tridentata', 'Normal']
# [415, 13, 0, 0, 'Orchis sixnia', 'Normal']
# [416, 6, 0, 0, 'Orchis punctulata', 'Normal']
# [416, 16, 0, 0, 'Orchis punctulata', 'Normal']
# [417, 2, 1, 0, 'Orchis punctulata', 'Normal']
# [417, 5, 0, 0, 'Orchis italica', 'Normal']
# [417, 11, 0, 0, 'Orchis iberica', 'Normal']
# [418, 1, 0, 0, 'Orchis collina', 'Normal']
# [418, 11, 0, 0, 'Orchis patens', 'Normal']
# [418, 19, 0, 0, 'Orchis patens', 'Normal']
# [419, 5, 0, 0, 'Orchis anatolica', 'Normal']
# [419, 12, 0, 0, 'Orchis romana', 'Normal']
# [420, 6, 0, 0, 'Orchis laxiflora', 'Normal']
# [420, 14, 0, 0, 'Orchis holocheilos', 'Normal']
# [420, 19, 0, 0, 'Orchis maculata', 'Normal']
# [421, 10, 0, 0, 'Ânacamptis pyramidalis (L.) L.C. Rich. —• Orchis pyramidalis L., Aceras', 'Possible OCR Error']
# [422, 2, 0, 0, 'Himantoglossum caprinum', 'Normal']
# [422, 8, 1, 0, 'Himantoglossum affine', 'Normal']
# [423, 4, 0, 0, 'Serapias vomeracea', 'Normal']
# [423, 10, 1, 0, 'Serapias vomeracea', 'Normal']
# [425, 8, 0, 0, 'Salix acmophylla', 'Normal']
# [426, 14, 0, 0, 'Salix australior', 'Normal']
# [426, 20, 0, 0, 'Salix dinsmorei', 'Normal']
# [427, 11, 0, 0, 'Salix alba', 'Normal']
# [427, 21, 0, 0, 'Salix libani', 'Normal']
# [429, 1, 0, 0, 'Populus bolleana', 'Normal']
# [429, 10, 0, 0, 'Populus nigra', 'Normal']
# [429, 20, 0, 0, 'Populus tremula', 'Normal']
# [431, 10, 1, 0, 'Populus euphratica', 'Normal']
# [432, 11, 0, 0, 'Juglans regia', 'Normal']
# [432, 28, 0, 0, 'Alnus orientalis', 'Normal']
# [433, 17, 0, 0, 'Carpinus orientalis', 'Normal']
# [434, 1, 0, 0, 'Ostrya carpinifolia', 'Normal']
# [436, 14, 2, 0, 'Quercus cedrorum', 'Normal']
# [436, 16, 3, 0, 'Quercus pinnatifida', 'Normal']
# [437, 4, 0, 0, 'Quercus infectoria', 'Normal']
# [437, 16, 0, 0, 'Var. boissieri (Reut.) Nabelek — Qu. boissieri Reut., Qu. lusitanica Lam., var.', 'Possible OCR Error']
# [438, 4, 0, 0, 'Var. latifolia (Boiss.) Nabelek — Qu. syriaca Ky., Qu. tauricola Ky ?, Qu. in-', 'Possible OCR Error']
# [439, 8, 0, 0, 'Quercus microphylla', 'Normal']
# [439, 16, 0, 0, 'Quercus libani', 'Normal']
# [440, 5, 0, 0, 'Quercus brantii', 'Normal']
# [440, 9, 0, 0, 'Ssp. oophora (Ky) O. Schwarz. — Qu. oophora Ky (PI. CXVIII, n. 2). — Chêne', 'Possible OCR Error']
# [440, 16, 0, 0, 'Ssp. look (Ky) n. comb. — Qu. look Ky (PI. CXVIII, n. 3). — Cet arbre a', 'Possible OCR Error']
# [441, 8, 0, 0, 'Quercus brantii', 'Normal']
# [441, 10, 0, 0, 'Quercus brantii', 'Normal']
# [441, 12, 0, 0, 'Quercus libani', 'Normal']
# [442, 6, 0, 0, 'Quercus ithaburensis', 'Normal']
# [442, 11, 0, 0, 'Ssp. ungeri (Ky) n. com. — Qu. ungeri Ky. — Feuilles plus petites générale-', 'Possible OCR Error']
# [443, 11, 0, 0, 'Quercus cerris', 'Normal']
# [444, 12, 0, 0, 'Quercus calliprinos', 'Normal']
# [446, 2, 0, 0, 'Ulmus minor', 'Normal']
# [446, 7, 0, 0, 'Ulmus canescens', 'Normal']
# [446, 10, 0, 0, 'Ulmus glabra', 'Normal']
# [446, 16, 0, 0, 'Geltis australis', 'Normal']
# [447, 10, 0, 0, 'Celtis tournefortii', 'Normal']
# [448, 14, 0, 0, 'Ficus carica', 'Normal']
# [448, 22, 0, 0, 'Ficus sycomorus', 'Normal']
# [449, 30, 0, 0, 'Urtica urens', 'Normal']
# [450, 7, 0, 0, 'Urtica membranacea', 'Normal']
# [450, 11, 0, 0, 'Urtica pilulifera', 'Normal']
# [450, 20, 0, 0, 'Urtica dioica', 'Normal']
# [451, 4, 0, 0, 'Urtica fragilis', 'Normal']
# [452, 9, 0, 0, 'Parietaria judaica', 'Normal']
# [453, 8, 0, 0, 'Parietaria eretica', 'Normal']
# [453, 14, 0, 0, 'Parietaria lusitanica', 'Normal']
# [453, 21, 0, 0, 'Parietaria al', 'Normal']
# [454, 8, 0, 0, 'Cannabis sativa', 'Normal']
# [454, 23, 0, 0, 'Humulus lupulus', 'Normal']
# [455, 7, 0, 0, 'Osyris alba', 'Normal']
# [456, 14, 0, 0, 'Thesium arvense', 'Normal']
# [456, 21, 0, 0, 'Thesium libanoticum', 'Normal']
# [457, 1, 0, 0, 'Thesium heterophyllum', 'Normal']
# [457, 6, 0, 0, 'Thesium humile', 'Normal']
# [457, 14, 0, 0, 'Thesium bergeri', 'Normal']
# [458, 5, 0, 0, 'Cynomorium coccineum', 'Normal']
# [458, 18, 0, 0, 'Cytinus hypocistis', 'Normal']
# [459, 6, 0, 0, 'Loranthus europaeus', 'Normal']
# [459, 12, 0, 0, 'Viscum album', 'Normal']
# [460, 8, 0, 0, 'Arceuthobium oxycedri', 'Normal']
# [461, 18, 0, 0, 'Aristolochia altissima', 'Normal']
# [462, 1, 0, 0, 'Aristolochia parvifolia', 'Normal']
# [462, 8, 0, 0, 'Aristolochia billardieri', 'Normal']
# [463, 1, 0, 0, 'Aristolochia poecilantha', 'Normal']
# [463, 10, 0, 0, 'Aristolochia scabridula', 'Normal']
# [463, 18, 0, 0, 'Aristolochia maurorum', 'Normal']
# [464, 8, 0, 0, 'Aristolochia bottae', 'Normal']
# [466, 11, 0, 0, 'Rumex angustifolius', 'Normal']
# [466, 17, 0, 0, 'Rumex patientia', 'Normal']
# [467, 4, 0, 0, 'Rumex crispus', 'Normal']
# [467, 9, 0, 0, 'Rumex conglomerates', 'Normal']
# [468, 1, 0, 0, 'Rumex chalepensis', 'Normal']
# [468, 16, 0, 0, 'Rumex pulcher', 'Normal']
# [469, 22, 0, 0, 'Rumex dentatus', 'Normal']
# [470, 13, 2, 0, 'Rumex palustris', 'Normal']
# [470, 17, 0, 0, 'Rumex bucephalophorus', 'Normal']
# [471, 8, 0, 0, 'Rumex tuberosus', 'Normal']
# [472, 1, 0, 0, 'Rumex vesicarius', 'Normal']
# [472, 4, 0, 0, 'Rumex cyprius', 'Normal']
# [472, 12, 0, 0, 'Rumex acetosella', 'Normal']
# [473, 3, 0, 0, 'Bilderdykia convolvulus', 'Normal']
# [475, 1, 0, 0, 'Polygonum amphibium', 'Normal']
# [475, 6, 0, 0, 'Polygonum salicifolium', 'Normal']
# [475, 12, 0, 0, 'Polygonum hydropiper', 'Normal']
# [476, 4, 0, 0, 'Polygonum persicaria', 'Normal']
# [476, 7, 0, 0, 'Polygonum lapathifolium', 'Normal']
# [477, 1, 0, 0, 'Polygonum polycnemoides', 'Normal']
# [477, 6, 0, 0, 'Polygonum corrigioloides', 'Normal']
# [477, 10, 0, 0, 'Polygonum kitaibelianum', 'Normal']
# [478, 3, 0, 0, 'Polygonum argyrocoleum', 'Normal']
# [478, 7, 1, 0, 'Polygonum venantianum', 'Normal']
# [478, 11, 1, 0, 'Polygonum aviculare', 'Normal']
# [479, 5, 0, 0, 'Polygonum equisetiforme', 'Normal']
# [479, 12, 0, 0, 'Polygonum maritimum', 'Normal']
# [479, 16, 2, 0, 'Polygonum aleppicum', 'Normal']
# [480, 1, 2, 0, 'Polygonum cognatum', 'Normal']
# [480, 9, 0, 0, 'Polygonum setosum', 'Normal']
# [480, 11, 3, 0, 'Polygonum libani', 'Normal']
# [481, 5, 0, 0, 'Polygonum cedrorum', 'Normal']
# [481, 21, 0, 0, 'Atraphaxis spinosa', 'Normal']
# [482, 3, 1, 0, 'Atraphaxis billardieri', 'Normal']
# [482, 15, 0, 0, 'Emex spinosa', 'Normal']
# [482, 25, 0, 0, 'Oxyria digyna', 'Normal']
# [483, 8, 0, 0, 'Rheumribes L', 'Normal']
# [483, 12, 2, 0, 'Rheum palaestinum', 'Normal']
# [484, 1, 0, 0, 'Calligonum comosum', 'Normal']
# [484, 6, 0, 0, 'Calligonum tetrapterum', 'Normal']
# [484, 16, 0, 0, 'Beta vulgaris', 'Normal']
# [486, 1, 0, 0, 'Chenopodium vulvaria', 'Normal']
# [486, 7, 2, 0, 'Chenopodium album', 'Normal']
# [486, 11, 2, 0, 'Chenopodium opulifolium', 'Normal']
# [486, 17, 1, 0, 'Chenopodium murale', 'Normal']
# [487, 1, 0, 0, 'Ghenopodium urbicum', 'Normal']
# [487, 4, 0, 0, 'Chenopodium rubrum', 'Normal']
# [487, 11, 0, 0, 'Chenopodium botrys', 'Normal']
# [487, 16, 0, 0, 'Chenopodium ambrosioides', 'Normal']
# [488, 1, 2, 0, 'Chenopodium foliosum', 'Normal']
# [488, 12, 0, 0, 'Spinacia tetranda', 'Normal']
# [489, 1, 0, 0, 'Krascheninnikovia ceratoides', 'Normal']
# [489, 10, 0, 0, 'Halimione portulacoides', 'Normal']
# [490, 26, 0, 0, 'Atriplex halimus', 'Normal']
# [491, 3, 2, 0, 'Atriplex stylosa', 'Normal']
# [491, 7, 1, 0, 'Atriplex thunbergiifolia', 'Normal']
# [491, 9, 3, 0, 'Atriplex leucoclada', 'Normal']
# [491, 15, 2, 0, 'Atriplex micrantha', 'Normal']
# [492, 6, 0, 0, 'Atriplex rosea', 'Normal']
# [492, 13, 0, 0, 'Atriplex zahlensis', 'Normal']
# [493, 1, 0, 0, 'Atriplex lasiantha', 'Normal']
# [493, 13, 0, 0, 'Atriplex hastata', 'Normal']
# [493, 18, 0, 0, 'microtheca Schum., à périanthe réduit, et port rameux.', 'Possible OCR Error']
# [493, 22, 0, 0, 'Atriplex patula', 'Normal']
# [494, 18, 0, 0, 'Atriplex littoralis', 'Normal']
# [495, 5, 0, 0, 'Panderia pilosa', 'Normal']
# [495, 11, 0, 0, 'Chenolea arabica', 'Normal']
# [495, 17, 0, 0, 'Kochia scoparia', 'Normal']
# [496, 14, 0, 0, 'Bassia monticola', 'Normal']
# [496, 19, 0, 0, 'Bassia hyssopifolia', 'Normal']
# [496, 22, 0, 0, 'Bassia muricata', 'Normal']
# [497, 3, 0, 0, 'Bassia erîophora', 'Normal']
# [497, 11, 0, 0, 'Arthrocnemum glaucum', 'Normal']
# [498, 4, 0, 0, 'Salicornia europaea', 'Normal']
# [499, 3, 0, 0, 'Halopeplis amplexicaulis', 'Normal']
# [499, 9, 0, 0, 'Halocnemum strobilaceum', 'Normal']
# [499, 17, 0, 0, 'Hypocylix kerneri', 'Normal']
# [500, 7, 0, 0, 'Hypocylix sp', 'Normal']
# [501, 1, 0, 0, 'Suaeda asphaltica', 'Normal']
# [501, 4, 0, 0, 'Suaeda fruticosa', 'Normal']
# [501, 8, 0, 0, 'Suaeda altissima', 'Normal']
# [501, 12, 0, 0, 'Suaeda salsa', 'Normal']
# [501, 14, 3, 0, 'Suaeda prostrata', 'Normal']
# [502, 4, 1, 0, 'Suaeda carnosissima', 'Normal']
# [502, 10, 0, 0, 'Schanginia baccata', 'Normal']
# [503, 1, 0, 0, 'Haloxylon articulatum', 'Normal']
# [503, 10, 0, 0, 'Haloxylon salicornicum', 'Normal']
# [503, 16, 0, 0, 'Traganum nudatum', 'Normal']
# [504, 8, 0, 0, 'Seidlitzia rosmarinus', 'Normal']
# [504, 12, 1, 0, 'Seidlitzia florida', 'Normal']
# [506, 8, 0, 0, 'Salsola kali', 'Normal']
# [506, 14, 0, 0, 'Salsola volkensii', 'Normal']
# [506, 19, 0, 0, 'Salsola inermis', 'Normal']
# [507, 1, 0, 0, 'Salsola jordanicola', 'Normal']
# [507, 6, 0, 0, 'Salsola incanescens', 'Normal']
# [507, 10, 1, 0, 'Salsola autrani', 'Normal']
# [507, 18, 0, 0, 'Salsola crassa', 'Normal']
# [508, 3, 0, 0, 'Salsola subcrassa', 'Normal']
# [508, 7, 2, 0, 'Salsola zenobiae', 'Normal']
# [508, 13, 0, 0, 'Salsola tetrandra', 'Normal']
# [509, 2, 0, 0, 'Salsola postii', 'Normal']
# [509, 6, 0, 0, 'Salsola heliaramiae', 'Normal']
# [510, 1, 0, 0, 'Salsola azaurena', 'Normal']
# [510, 11, 0, 0, 'Salsola canescens', 'Normal']
# [510, 17, 0, 0, 'Salsola villosa', 'Normal']
# [511, 7, 0, 0, 'Aellenia glauca', 'Normal']
# [511, 15, 0, 0, 'Aellenia hierochuntica', 'Normal']
# [512, 6, 0, 0, 'Noaea mucronata', 'Normal']
# [512, 18, 0, 0, 'Girgensohnia oppositiflora', 'Normal']
# [513, 6, 0, 0, 'Petrosimonia brachiata', 'Normal']
# [513, 10, 0, 0, 'Anabasis haussknechtii', 'Normal']
# [513, 16, 0, 0, 'Anabasis setifera', 'Normal']
# [514, 11, 0, 0, 'Halocharis sulphurea', 'Normal']
# [514, 13, 3, 0, 'Halocharis hispida', 'Normal']
# [515, 6, 0, 0, 'Halocharis sp', 'Normal']
# [515, 12, 0, 0, 'Halimocnemis pilosa', 'Normal']
# [515, 19, 0, 0, 'Cornulaca setifera', 'Normal']
# [516, 7, 0, 0, 'Halogeton alopecuroides', 'Normal']
# [517, 26, 0, 0, 'Âmaranthus caudatus L. (PI. CL, n. 1). —• 0. Tige 30-160 cm., ordinai-', 'Possible OCR Error']
# [518, 3, 0, 0, 'Amaranthus hybridus', 'Normal']
# [519, 1, 0, 0, 'Amaranthus retroflexus', 'Normal']
# [519, 9, 0, 0, 'Amaranthus gracilis', 'Normal']
# [519, 18, 0, 0, 'Amaranthus albus', 'Normal']
# [519, 22, 0, 0, 'Amaranthus blitoides', 'Normal']
# [520, 7, 0, 0, 'Amaranthus graecizans', 'Normal']
# [520, 15, 0, 0, 'Amaranthus lividus', 'Normal']
# [521, 1, 0, 0, 'Amaranthus deflexus', 'Normal']
# [521, 7, 0, 0, 'Achyranthes aspera', 'Normal']
# [521, 15, 0, 0, 'Alternanthera sessilis', 'Normal']
# [522, 15, 0, 0, 'Thelygonum cynocrambe', 'Normal']
# [523, 3, 0, 0, 'Phytolacca americana', 'Normal']
# [523, 10, 0, 0, 'Phytolacca pruinosa', 'Normal']
# [523, 22, 0, 0, 'Boerhavia plumbaginea', 'Normal']
# [524, 16, 0, 0, 'Mesembryanthemum forskalei', 'Normal']
# [525, 1, 0, 0, 'Mesembryanthemum nodiflorum', 'Normal']
# [525, 5, 0, 0, 'Mesembryanthemum edule', 'Normal']
# [525, 12, 0, 0, 'Aizoon hispanicum', 'Normal']
# [526, 7, 0, 0, 'Glinus lotoides', 'Normal']
# [526, 15, 0, 0, 'Glinus dictamnoides', 'Normal']
# [527, 1, 0, 0, 'Portulacca oleracea', 'Normal']
# [527, 8, 0, 0, 'Montia fontana', 'Normal']
# [528, 6, 0, 0, 'Pteranthus dichotomus', 'Normal']
# [528, 21, 0, 0, 'Scleranthus orientalis', 'Normal']
# [529, 3, 0, 0, 'Scleranthus collinus', 'Normal']
# [529, 7, 0, 0, 'Habrosia spinuliflora', 'Normal']
# [529, 14, 0, 0, 'Gorrigiola littoralis', 'Normal']
# [530, 1, 0, 0, 'Telephium imperati', 'Normal']
# [530, 22, 0, 0, 'Herniaria hirsuta', 'Normal']
# [530, 30, 0, 0, 'Herniaria cinerea', 'Normal']
# [531, 5, 0, 0, 'Herniaria glabra', 'Normal']
# [531, 11, 0, 0, 'Herniaria incana', 'Normal']
# [531, 19, 0, 0, 'Herniaria arabica', 'Normal']
# [532, 4, 0, 0, 'Herniaria hemistemon', 'Normal']
# [532, 25, 0, 0, 'Paronychia chionaea', 'Normal']
# [533, 2, 0, 0, 'Paronychia kurdica', 'Normal']
# [533, 7, 0, 0, 'Paronychia macrosepala', 'Normal']
# [533, 11, 0, 0, 'Paronychia argentea', 'Normal']
# [533, 19, 0, 0, 'Paronychia arabica', 'Normal']
# [534, 2, 0, 0, 'Paronychia echinata', 'Normal']
# [534, 12, 0, 0, 'Polycarpon tetraphyllum', 'Normal']
# [535, 1, 0, 0, 'Polycarpon succulentum', 'Normal']
# [535, 5, 0, 0, 'Robbairea delileana', 'Normal']
# [536, 1, 0, 0, 'Spergularia diandra', 'Normal']
# [536, 7, 0, 0, 'Spergularia media', 'Normal']
# [536, 9, 4, 0, 'Spergularia marina', 'Normal']
# [537, 1, 0, 0, 'Spergularia bocconii', 'Normal']
# [537, 14, 0, 0, 'Spergula arvensis', 'Normal']
# [537, 19, 0, 0, 'Spergula fallax', 'Normal']
# [538, 10, 0, 0, 'Buffonia paniculata', 'Normal']
# [538, 17, 0, 0, 'Buffonia ephedrina', 'Normal']
# [539, 10, 0, 0, 'Sagina libanotica', 'Normal']
# [539, 15, 0, 0, 'Sagina apetala', 'Normal']
# [539, 20, 0, 0, 'Sagina maritima', 'Normal']
# [541, 12, 0, 0, 'Minuartia labillardieri', 'Normal']
# [541, 17, 0, 0, 'Minuartia juniperina', 'Normal']
# [541, 25, 0, 0, 'Minuartia libanotica', 'Normal']
# [542, 5, 0, 0, 'Minuartia parvulorum', 'Normal']
# [542, 11, 0, 0, 'Minuartia innominata', 'Normal']
# [543, 5, 0, 0, 'Minuartia meyeri', 'Normal']
# [543, 15, 0, 0, 'Minuartia globulosa', 'Normal']
# [543, 21, 0, 0, 'Minuartia intermedia', 'Normal']
# [544, 7, 0, 0, 'Minuartia decipiens', 'Normal']
# [544, 16, 0, 0, 'Minuartia montana', 'Normal']
# [544, 19, 0, 0, 'Minuartia mesogitana', 'Normal']
# [545, 5, 1, 0, 'Minuartia hybrid', 'Normal']
# [545, 16, 0, 0, 'Minuartia subtilis', 'Normal']
# [545, 19, 0, 0, 'Minuartia mediterranea', 'Normal']
# [546, 2, 0, 0, 'Minuartia thymifolia', 'Normal']
# [546, 5, 0, 0, 'Minuartia picta', 'Normal']
# [547, 1, 0, 0, 'Minuartia formosa', 'Normal']
# [547, 8, 0, 0, 'Minuartia hamata', 'Normal']
# [548, 18, 0, 0, 'Arenaria libanotica', 'Normal']
# [548, 24, 0, 0, 'Arenaria deflexa', 'Normal']
# [549, 5, 0, 0, 'Arenaria leptoclados', 'Normal']
# [549, 13, 0, 0, 'Arenaria serpyllifolia', 'Normal']
# [549, 18, 0, 0, 'Arenaria cassia', 'Normal']
# [550, 5, 2, 0, 'Arenaria tremula', 'Normal']
# [550, 9, 1, 0, 'Arenaria pamphylica', 'Normal']
# [551, 4, 0, 0, 'Stellaria ciliciea', 'Normal']
# [551, 10, 0, 0, 'Stellaria media', 'Normal']
# [552, 14, 0, 0, 'Holosteum umbellatum', 'Normal']
# [552, 21, 0, 0, 'Holosteum liniflorum', 'Normal']
# [553, 4, 0, 0, 'Moenchia octandra', 'Normal']
# [554, 15, 0, 0, 'Cerastium dubium', 'Normal']
# [555, 7, 0, 0, 'Cerastium cerastoides', 'Normal']
# [555, 13, 0, 0, 'Cerastium perfoliatum', 'Normal']
# [555, 16, 0, 0, 'Cerastium comatum', 'Normal']
# [555, 21, 0, 0, 'Cerastium dichotomum', 'Normal']
# [556, 6, 1, 0, 'Cerastium inflatum', 'Normal']
# [556, 12, 1, 0, 'Cerastium glomeratum', 'Normal']
# [556, 18, 1, 0, 'Cerastium brachypetalum', 'Normal']
# [557, 6, 0, 0, 'Cerastium pentandrum', 'Normal']
# [557, 17, 0, 0, 'Gerastium fragillimum', 'Normal']
# [558, 8, 0, 0, 'Agrostemma githago', 'Normal']
# [559, 3, 0, 0, 'Melandrium album', 'Normal']
# [559, 10, 0, 0, 'Melandrium eriocalycinum', 'Normal']
# [564, 21, 0, 0, 'Silène coniflora', 'Normal']
# [565, 1, 0, 0, 'Silène lydia', 'Normal']
# [565, 4, 0, 0, 'Silène conoidea', 'Normal']
# [565, 12, 0, 0, 'Silène macrodonta', 'Normal']
# [566, 1, 0, 0, 'Silène reuteriana', 'Normal']
# [566, 6, 0, 0, 'Silène muscipula', 'Normal']
# [566, 11, 0, 0, 'Silène behen', 'Normal']
# [566, 16, 0, 0, 'Silène laeta', 'Normal']
# [567, 2, 0, 0, 'Silène caeli', 'Normal']
# [567, 5, 0, 0, 'Silène eretica', 'Normal']
# [567, 8, 0, 0, 'Silène crassipes', 'Normal']
# [567, 14, 1, 0, 'Silène papillosa', 'Normal']
# [568, 4, 0, 0, 'Silène racemosa', 'Normal']
# [568, 8, 2, 0, 'Silène sibthorpiana', 'Normal']
# [568, 16, 1, 0, 'Silène gallica', 'Normal']
# [569, 1, 0, 0, 'Silène cerastoides', 'Normal']
# [569, 6, 0, 0, 'Silène setacea', 'Normal']
# [569, 13, 0, 0, 'Silène damascena', 'Normal']
# [569, 20, 0, 0, 'Silène siderophila', 'Normal']
# [570, 9, 0, 0, 'Silène palaestina', 'Normal']
# [570, 20, 0, 0, 'Silène nocturna', 'Normal']
# [570, 25, 0, 0, 'Silène apetala', 'Normal']
# [571, 5, 0, 0, 'Silène colorata', 'Normal']
# [571, 16, 0, 0, 'Silène oliveriana', 'Normal']
# [572, 1, 0, 0, 'Silène rubella', 'Normal']
# [572, 6, 0, 0, 'Silène sedoides', 'Normal']
# [572, 11, 0, 0, 'Silène fuscata', 'Normal']
# [572, 14, 0, 0, 'Silène aegyptiaca', 'Normal']
# [573, 7, 0, 0, 'Silène kotschyi', 'Normal']
# [573, 14, 0, 0, 'Silène striata', 'Normal']
# [573, 21, 0, 0, 'Silène cassia', 'Normal']
# [574, 1, 0, 0, 'Silène linearis', 'Normal']
# [574, 6, 0, 0, 'Silène juncea', 'Normal']
# [575, 1, 0, 0, 'Silène modesta', 'Normal']
# [575, 6, 0, 0, 'Silène intricata', 'Normal']
# [575, 9, 0, 0, 'Silène capitellata', 'Normal']
# [575, 14, 0, 0, 'Silène pharaaceifolia', 'Normal']
# [576, 1, 0, 0, 'Silène stenobotrys', 'Normal']
# [576, 5, 1, 0, 'Silène pruinosa', 'Normal']
# [576, 7, 3, 0, 'Silène caryophylloides', 'Normal']
# [576, 9, 3, 0, 'Silène boryi', 'Normal']
# [577, 5, 0, 0, 'Silène odontopetala', 'Normal']
# [577, 17, 0, 0, 'Silène cucubalus', 'Normal']
# [578, 5, 0, 0, 'Silène physalodes', 'Normal']
# [578, 8, 0, 0, 'Silène italica', 'Normal']
# [578, 14, 1, 0, 'Silène astartes', 'Normal']
# [579, 1, 0, 0, 'Silène amana', 'Normal']
# [579, 4, 0, 0, 'Silène confertiflora', 'Normal']
# [579, 9, 0, 0, 'Silène marschallii', 'Normal']
# [579, 12, 0, 0, 'Silène longipetala', 'Normal']
# [580, 8, 0, 0, 'Silène chlorifolia', 'Normal']
# [580, 11, 0, 0, 'Silène swertiifolia', 'Normal']
# [581, 1, 0, 0, 'Silène makmeliana', 'Normal']
# [581, 8, 0, 0, 'Silène libanotica', 'Normal']
# [581, 15, 0, 0, 'Silène grisea', 'Normal']
# [582, 6, 0, 0, 'Silène succulenta', 'Normal']
# [582, 11, 0, 0, 'Silène schlumbergeri', 'Normal']
# [582, 17, 0, 0, 'Gucubalus baccifer', 'Normal']
# [583, 12, 0, 0, 'Vaccaria pyramidata', 'Normal']
# [583, 21, 0, 0, 'Vaccaria oxyodonta', 'Normal']
# [584, 7, 0, 0, 'Vaccaria liniflora', 'Normal']
# [585, 1, 0, 0, 'Saponaria bargyliana', 'Normal']
# [585, 6, 0, 0, 'Saponaria pulvinaris', 'Normal']
# [585, 11, 0, 0, 'Saponaria tridentata', 'Normal']
# [587, 32, 0, 0, 'Gypsophila venusta', 'Normal']
# [588, 4, 0, 0, 'Gypsophila anatolica', 'Normal']
# [588, 11, 0, 0, 'Gypsophila arabica', 'Normal']
# [589, 5, 0, 0, 'Gypsophila libanotica', 'Normal']
# [589, 10, 0, 0, 'Gypsophila aucheri', 'Normal']
# [589, 15, 0, 0, 'Gypsophila pallida', 'Normal']
# [590, 1, 0, 0, 'Gypsophila damascena', 'Normal']
# [590, 5, 1, 0, 'Gypsophila ruscifolia', 'Normal']
# [590, 7, 5, 0, 'Gypsophila linearifolia', 'Normal']
# [590, 11, 1, 0, 'Gypsophila antari', 'Normal']
# [591, 6, 0, 0, 'Gypsophila heteropoda', 'Normal']
# [591, 12, 0, 0, 'Gypsophila viscosa', 'Normal']
# [592, 1, 0, 0, 'Gypsophila frankenioides', 'Normal']
# [592, 7, 0, 0, 'Gypsophila mollis', 'Normal']
# [592, 12, 0, 0, 'Gypsophila polygonoides', 'Normal']
# [593, 5, 0, 0, 'Gypsophila filicaulis', 'Normal']
# [593, 12, 0, 0, 'Gypsophila pilosa', 'Normal']
# [594, 8, 0, 0, 'Ankyropetalum gypsophiloides', 'Normal']
# [594, 13, 0, 0, 'Ankyropetalum coelesyriacum', 'Normal']
# [594, 18, 0, 0, 'Ankyropetalum arsusianum', 'Normal']
# [595, 3, 0, 0, 'Acanthophyllum kurdicum', 'Normal']
# [595, 11, 0, 0, 'Kohlrauschia velutina', 'Normal']
# [596, 5, 0, 0, 'Tunica syriaca', 'Normal']
# [596, 8, 0, 0, 'Tunica pachygona', 'Normal']
# [596, 13, 0, 0, 'Tunica arabica', 'Normal']
# [597, 1, 0, 0, 'Velezia rigida', 'Normal']
# [597, 8, 0, 0, 'Velezia fasciculata', 'Normal']
# [599, 1, 0, 0, 'Dianthus tripunctatus', 'Normal']
# [599, 4, 0, 0, 'Dianthus cyri', 'Normal']
# [599, 10, 0, 0, 'Dianthus strictus', 'Normal']
# [603, 1, 0, 0, 'Dianthus judaicus', 'Normal']
# [603, 10, 0, 0, 'Dianthus micranthus', 'Normal']
# [603, 17, 0, 0, 'Dianthus pachypetalus', 'Normal']
# [604, 3, 0, 0, 'Dianthus libanotis', 'Normal']
# [604, 10, 0, 0, 'Dianthus crinitus', 'Normal']
# [604, 15, 0, 0, 'Dianthus orientalis', 'Normal']
# [605, 19, 0, 0, 'Dianthus pendulus', 'Normal']
# [606, 1, 0, 0, 'Dianthus actinopetalus', 'Normal']
# [606, 4, 0, 0, 'Dianthus karami', 'Normal']
# [627, 44, 0, 0, 'J', 'Possible OCR Error']
# 1065

# %%
## This cell requires ~20 mins to calculate results from the first book

import math
doc = fitz.open(fname)  # open document
#subset = items[:6]
subset = items
boxes = []
for it, item in enumerate(subset):
    mode = "searching"
    if (it >= len(subset) - 1):
        break
    next_item = subset[it + 1]
    [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0] = item
    [t, rr, rh, i, z,s, y,l, x,b, warning] = [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0]
    [t1, rr1, rh1, i1, z1,s1, y1,l1, x1,b1, warning1] = next_item
    page = doc[i0]
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", flags=flags)["blocks"]
    blocks = blocks[x:]
    r_rect = rr0
    
    #print(t0)
    # if t0 == "Isoetes olympica":
    #print([int(it), len(subset), rr0, t0, "\n", t1])
    
    annot_rect = page.add_rect_annot(rr0)
    annot_rect.set_border(width=1, dashes=[1,2])
    annot_rect.update()

    
    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        #annot = page.add_rect_annot(br)
        for y,l in enumerate(b["lines"][y0:]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            s = l["spans"][0]
            #for z,s in enumerate(l["spans"]):  # iterate through the text spans
            this_line = " ".join(list(map(lambda x: x["text"], l["spans"])))
            if mode != "found":
                if re.search("Aire g", this_line):
                    mode = s["font"] + " " + str(s["size"])
                    r_rect = r_rect.include_rect(lr)
                    #print(str((x, y, s["size"], s["font"])) + "FOUND: " + this_line)
                elif lr.intersects(rr1):                    
                    mode = "found"
                    #print(str((x, y, s["size"], s["font"])) + "FOUND: " + this_line)
                else:
                    if mode != "searching":
                        (font, size) = mode.split(" ")
                        isize = round(math.ceil(float(size)))
                        if s["size"] >= float(isize):
                            mode = "found"
                    if mode != "found":
                        r_rect = r_rect.include_rect(lr)
                        # if y >= y0:
                        #     r_rect = r_rect.include_rect(lr)
                    
    r_high = rh0
    annot_rect = page.add_rect_annot(r_rect)
    annot_high = page.add_highlight_annot(r_high)
    # boxes.append([t0, start_page + it, r_rect, item]) . ## FIXME: thinking it should be i0 not start_page + it
    boxes.append([t0, i0, r_rect, item])


# print(boxes[0])
print(len(boxes))

#doc.delete_pages(end_page, doc.page_count - 1)
#doc.delete_pages(0, start_page - 1)
marked_epithet_fname = "marked-pages-" + doc.name
doc.save(marked_epithet_fname, garbage=4, clean=True)
#!open -a Preview marked-pages-book-1-sample.pdf
# !open -a Preview marked-pages-book-1.pdf
# Out:
# 1064

# %%
import pprint
pp = pprint.PrettyPrinter(compact=True)

import math
doc = fitz.open(fname)  # open document
results = {}
for it, thing in enumerate(boxes):
    mode = "searching"
    #print(thing)
    [name, pageno, rrr, item] = thing
    page = doc[pageno]
    [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0] = item
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", clip=rr0, flags=flags)["blocks"]    


    print(pageno - txtpgoffset, i0, t0)
    results[t0] = {}
    results[t0]["name"] = t0
    results[t0]["name_rects"] = [rr0]
    results[t0]["pdf_page"] = pageno
    results[t0]["book_page"] = pageno - txtpgoffset
    key = "Extra"
    mode = "searching"
    margins = [[(math.ceil(l["bbox"][0]), l["spans"][0]["text"].split(" ")[0]) for l in filter(lambda bl: bl.get("spans"), b["lines"])] for b in blocks]
    margins = [m for n in margins for m in n]
    targets = list(map(lambda n: n[0], filter(lambda m: m[1] in ["L.", "S.", "Aire"] , margins))) or [blocks[0]["lines"][0]["bbox"][0]]
    margins_max = max(targets or margins)
    margins_min = min(list(map(lambda n: n[0], margins)))

    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        for y,l in enumerate(b["lines"][y0:]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            xloc = min(margins_max, math.ceil(lr.x0))
            this_line = re.sub(r"\s+", " ", " ".join(list(map(lambda x: x["text"].strip(), l["spans"])))).strip()
            # matches = re.match("^(?P<label>L\.|S\.|Aire g\w+\.|Not\w+\.|Fleurs|Fructif\.|Fructific|Floraison\w+)\s", this_line)
            #### FIXME: Phyllitis scolopendrium (L.) Newm. —Asplenium scolopendrium L., Scolopendrium
            #### FIXME: Juniper
            matches = re.match("^(?P<label>" + t0 + "|.*?)(\s|$)", this_line)
            if matches:
                d = matches.groupdict()
                if margins_max - xloc < 5:
                    key = d["label"]
                    if ' ' in key:
                        key = "Description"
                    elif key not in ["Description", "L.", "S.", "Aire"]:
                        key = "Extra"
                    elif key in ["Description", "L.", "S.", "Aire"]:
                        pass
                    else:
                        print("UNHANDLED: " + key)
                        key = "Extra"
                frag = results[t0].get(key) or ""
                results[t0][key] = " ".join([frag.strip(), this_line.strip()]).strip()
                key_rects = key + "_rects"
                if not results[t0].get(key_rects):
                    results[t0][key_rects] = []    
                results[t0][key_rects].append(lr)
                #print([x, y, xloc, mode, this_line])
            else:
                print(["ERROR:", x, y, xloc, mode, this_line])
    # pp.pprint(results[t0])
    print()
    #break
                    
    # r_high = rh0
    # annot_rect = page.add_rect_annot(r_rect)
    # annot_high = page.add_highlight_annot(r_high)
    # boxes.append([t0, r_rect, item])
# Out:
# 34 34 r
#
# 59 59 J
#
# 77 77 JL
#
# 78 78 Lycopodium cernuum
#
# 79 79 Selaginella denticulata
#
# 79 79 Isoetes hystrix
#
# 79 79 Isoetes olympica
#
# 80 80 Equisetum maximum
#
# 80 80 Equisetum palustre
#
# 80 80 Equisetum ramosissimum
#
# 81 81 Ophioglossum vulgatum
#
# 81 81 Ophioglossum lusitanicum
#
# 81 81 Osmunda regalis
#
# 82 82 Gymnogramma leptophylla
#
# 82 82 Cheilanthes
#
# 83 83 Âdiantum capillus-veneris
#
# 84 84 Pteris longifolia
#
# 84 84 Pteridium aquilmum
#
# 85 85 Athyrium
#
# 85 85 Dryopterîs aculeata
#
# 85 85 Dryopteris
#
# 86 86 Blechnum
#
# 87 87 Ceterack officinarum
#
# 88 88 Asplenium bourgaei
#
# 88 88 Asplenium
#
# 88 88 Asplenium ruta-muraria
#
# 88 88 Asplenium
#
# 88 88 Asplenium
#
# 89 89 Phyllitis scolopendrium
#
# 89 89 Phyllitis hemionitis
#
# 90 90 Polypodium vulgare L.
#
# 90 90 Salvinia natans
#
# 92 92 Abies cilicica
#
# 92 92 Cedrus libani
#
# 93 93 Pinus pinea
#
# 93 93 Pina
#
# 93 93 Pinus halepensis
#
# 94 94 Cupressus sempervirens
#
# 95 95 Juniperus oxycedrus
#
# 96 96 Juniper
#
# 96 96 Juniperus
#
# 96 96 Arceuthos drupacea
#
# 97 97 Ephedra campylopoda
#
# 97 97 Ephedra alte
#
# 98 98 Ephedra alata
#
# 99 99 Typha
#
# 100 100 Typha
#
# 100 100 Typha laxmannii
#
# 100 100 Sparganium neglectum
#
# 101 101 Naias
#
# 101 101 Naias graminea
#
# 101 101 Zostera nana
#
# 102 102 Cymodocea major
#
# 102 102 Ruppia maritima L.,
#
# 103 103 Zannichellia
#
# 103 103 Potamogeton nodosus
#
# 104 104 Potamogeton
#
# 104 104 Potamogeton crispus
#
# 104 104 Potamogeton
#
# 104 104 Potamogeton
#
# 105 105 Potamogeton
#
# 105 105 Potamogeton
#
# 106 106 Alisma
#
# 106 106 Alisma lanceolatum
#
# 106 106 Alisma gramineum
#
# 107 107 Echinodorus
#
# 107 107 Damasonium alisma
#
# 107 107 Damasonium
#
# 108 108 Butomus
#
# 108 108 Hydrocharis morsus-ranae
#
# 108 108 Vallisneria spiralis
#
# 111 111 Digit aria
#
# 111 111 Brachiaria eruciformis
#
# 111 111 Brachiaria mutica
#
# 112 112 Paspalum
#
# 112 112 Paspalidium geminatum
#
# 113 113 Echinochloa crus-gallii
#
# 113 113 Echinochloa colona
#
# 113 113 Panicum repens
#
# 114 114 Setaria viridis
#
# 114 114 Setaria lutescens
#
# 115 115 Setaria verticillata
#
# 115 115 Pennisetum
#
# 116 116 Pennisetumdivisum
#
# 116 116 Cenchrus ciliaris
#
# 116 116 Imperata cylindrica
#
# 117 117 Saccharum spontaneum
#
# 117 117 Erianthusravennae
#
# 117 117 Erianthus hostii
#
# 118 118 Hemarthria altissima
#
# 118 118 Phacelurus digitatus
#
# 119 119 Sorghumhalepense
#
# 120 120 Chrysopogon gryllus
#
# 120 120 Themeda
#
# 121 121 2°
#
# 121 121 Bothriochloa Ischaemum
#
# 121 121 Hyparrhenia
#
# 122 122 Cymbopogon
#
# 123 123 Andropogon
#
# 123 123 Heteropogon
#
# 124 124 Leersia
#
# 125 125 Phalaris brachystachys
#
# 125 125 Phalaris minor
#
# 126 126 Phalaris paradoxa
#
# 126 126 Phalaris bulbosa T.,
#
# 126 126 Phalaris caerulescens
#
# 127 127 Phalaris
#
# 127 127 Anthoxanthum odoratum
#
# 128 128 Aristida caerulescens
#
# 128 128 Aristida adscensionis L.,
#
# 128 128 Aristida plumosa
#
# 129 129 Aristida lanata
#
# 129 129 Stipa bromoides
#
# 129 129 Stipa capensis
#
# 130 130 Stipa parviflora
#
# 130 130 Stipa
#
# 131 131 Stipabarbata
#
# 132 132 Oryzopsis
#
# 133 133 Oryzopsis holciformis
#
# 133 133 Oryzopsis caerulescens
#
# 134 134 Milium
#
# 134 134 Milium pedicellare
#
# 134 134 Milium
#
# 135 135 Cornucopiae alopecuroides
#
# 135 135 Cornucopiae
#
# 135 135 Crypsis factorovskyi
#
# 136 136 Heleochloa
#
# 136 136 Heleochloa alopecuroides
#
# 137 137 Heleochloa acutiglumis
#
# 137 137 Rhizocephalus
#
# 138 138 Beckmannia eruciformis
#
# 138 138 Alopecurus gerardi
#
# 138 138 Alopecurus vaginatus
#
# 139 139 Alopecurus ventricosus
#
# 139 139 Alopecurus
#
# 139 139 Alopecurus anthoxanthoides
#
# 140 140 Phleum subulatum
#
# 141 141 Phleum
#
# 141 141 Phleum
#
# 141 141 Phleum
#
# 143 143 Agrostis
#
# 143 143 Agrostis stolonifera
#
# 144 144 Apera
#
# 144 144 Gastridium
#
# 144 144 Gastridium scabrum
#
# 145 145 Polypogonmonspeliensis
#
# 145 145 Polypogon maritimus
#
# 146 146 Lagurus ovatus
#
# 146 146 Calamagrostis epigeios
#
# 146 146 Calamagrostis pseudophragmites
#
# 147 147 Ammophila
#
# 147 147 Sporobolus arenarius
#
# 148 148 Eragrostis tatarica
#
# 148 148 Eragrostis cilianensis
#
# 149 149 Eragrostis
#
# 149 149 Eragrostis pilosa
#
# 149 149 Dactyloctenium aegyptium
#
# 150 150 Cynodon dactylon
#
# 151 151 Arundo plinii
#
# 151 151 Arundo donax
#
# 152 152 Phragmites
#
# 152 152 Boissiera pumilio
#
# 153 153 Holçus
#
# 154 154 Holcus lanatus
#
# 154 154 Corynephorus articulaţii s
#
# 155 155 Corynephorus
#
# 155 155 Pilgerochloablanche!
#
# 155 155 Gaudinopsis
#
# 156 156 Trisetariacavanillesii
#
# 156 156 Trisetaria linearis
#
# 157 157 Trisetaria koelerioides
#
# 157 157 Trisetaria fiavescens
#
# 158 158 Avena sativa L.,
#
# 159 159 Avena clauda
#
# 159 159 Avena
#
# 159 159 Avena
#
# 160 160 Àvenaalba
#
# 160 160 A
#
# 161 161 Avena convoluta
#
# 161 161 Arrenatherum elatius
#
# 162 162 Arrhenatherum palaestinum
#
# 162 162 Arrhenatherum kotschyi
#
# 162 162 Lycochloa avenacea
#
# 163 163 Gaudinia fragilis
#
# 163 163 Koeleria nitidula
#
# 164 164 Koeleria phleoides
#
# 165 165 Antinoria insulari s
#
# 166 166 Aira elegans
#
# 166 166 Schismus
#
# 167 167 Sesleria anatolica
#
# 167 167 Ammochloa
#
# 168 168 Echinaria
#
# 169 169 Melica uniflora Retz
#
# 169 169 Melica angustifolia
#
# 169 169 Melica cupani
#
# 170 170 Melica inaequiglumis
#
# 170 170 Melica pannosa
#
# 170 170 Melica ciliata L.,
#
# 171 171 Molinia
#
# 171 171 Catabrosa aquatica
#
# 172 172 Colpodium humile
#
# 172 172 Sphenopus
#
# 173 173 Cutandia philistaea
#
# 173 173 Cutandia maritima
#
# 173 173 Cutandia memphitica
#
# 174 174 Cutandia dichotoma
#
# 174 174 Cynosurus echinatus
#
# 174 174 Cynosurus coloratus
#
# 175 175 Cynosurus
#
# 175 175 Lamarckia aurea
#
# 176 176 Dactylis glomerata
#
# 177 177 Aeluropus littoral!s
#
# 178 178 Sclerochloa
#
# 179 179 Poa
#
# 179 179 Poa
#
# 180 180 Poa annua
#
# 180 180 Poa infirma
#
# 180 180 Poa hackeli
#
# 181 181 Poa pratensis
#
# 181 181 Poa silvicola
#
# 181 181 Poa trivialis
#
# 182 182 Poa compressa
#
# 182 182 Poa bulbosa
#
# 183 183 Poa sinaica
#
# 183 183 Poa
#
# 183 183 Poa sterilis
#
# 183 183 Poa nemoralis
#
# 184 184 Poa persica
#
# 185 185 Briza maxima
#
# 185 185 Briza minor
#
# 185 185 Briza spicata
#
# 186 186 Glyceria plicata
#
# 186 186 Puccinellia rupestris
#
# 187 187 Puccinellia distans
#
# 187 187 Puccinellia convoluta
#
# 188 188 Festuca indigesta
#
# 188 188 Festuca valesiaca
#
# 189 189 Festuca
#
# 189 189 Festuca
#
# 190 190 Festuca
#
# 191 191 Vulpia
#
# 191 191 Vulpia dertonensis
#
# 191 191 Vulpia ciliata
#
# 192 192 Vulpia hirtiglumis
#
# 192 192 Vulpia membranacea
#
# 193 193 Vulpia inops
#
# 193 193 Ctenopsis patens
#
# 194 194 Catapodium
#
# 194 194 Catapodium loliaceum
#
# 195 195 Nardurus maritimus
#
# 195 195 Nardurus orientalis
#
# 197 197 Bromus syriacus
#
# 197 197 Bromus bikfayensis
#
# 198 198 Bromus tomentellus
#
# 198 198 Bromus
#
# 199 199 Bromus
#
# 199 199 Bromus madritensis
#
# 200 200 Bromus rigidus
#
# 200 200 Bromus flabellatus
#
# 201 201 Bromus rubens
#
# 201 201 Bromus fasciculatus
#
# 202 202 Bromus
#
# 202 202 Bromus alopecuros
#
# 203 203 Brotnus lanceolatus
#
# 204 204 Bromus danthoniae
#
# 204 204 Bromus squarrosus
#
# 205 205 Bromus intermedius
#
# 205 205 Bromus
#
# 206 206 Bromus brachystachys
#
# 206 206 Bromus arvensis
#
# 206 206 BromushordeaceusL.
#
# 206 206 Bromus japonicus
#
# 207 207 Trachynia distachya
#
# 208 208 Brachypodium sylvaticum
#
# 208 208 Brachypodium pinnatum
#
# 209 209 Brachypodium ramosum
#
# 209 209 Lolium
#
# 210 210 Lolium
#
# 210 210 Lolium rigidum
#
# 211 211 Lolium loliaceum
#
# 211 211 Lolium
#
# 211 211 Lolium persicum
#
# 212 212 Psilurus incurvus
#
# 213 213 Monerma cylindrica
#
# 213 213 Parapholis
#
# 214 214 Henrardia
#
# 215 215 Agropyron panormitanum
#
# 215 215 Agropyron repens
#
# 216 216 Agropyron
#
# 216 216 Agropyron
#
# 217 217 Agropyron elongatum
#
# 217 217 Agropyron junceum (L.) P.
#
# 217 217 Eremopyrum buonapartis
#
# 218 218 Eremopyrum distans
#
# 218 218 Secale cereale
#
# 219 219 Secale montanum
#
# 219 219 Heteranthelium
#
# 220 220 Triticum thaoudar
#
# 220 220 Triticum dicoccoides
#
# 221 221 Aegilotricum loreti
#
# 223 223 Aegilops ovata
#
# 223 223 Aegilops
#
# 223 223 Aegilops triaristata
#
# 224 224 Aegilops
#
# 224 224 Aegilops biuncialis
#
# 224 224 Aegilops
#
# 225 225 Aegilops
#
# 226 226 Aegilops
#
# 227 227 Aegilops cylindrica
#
# 227 227 Aegilops caudata
#
# 228 228 Aegilops ventricosa
#
# 228 228 Aegilops crassa
#
# 229 229 Aegilops
#
# 229 229 Aegilops squarrosa
#
# 229 229 Aegilops longissima
#
# 230 230 Aegilops ligustica
#
# 230 230 Aegilops speltoides
#
# 231 231 Hordeum spontaneum
#
# 232 232 Hordeum
#
# 232 232 Hordeum
#
# 233 233 Hordeum murinum
#
# 233 233 Hordeum bulbosum
#
# 234 234 Hordeum nodosum
#
# 234 234 Taeniatherum crinitum
#
# 235 235 Crithopsis delileana
#
# 237 237 Cyperus flavescens
#
# 237 237 Cyperus globosus
#
# 237 237 Cyperus
#
# 238 238 Cyperus laevigatus
#
# 238 238 Cyperus
#
# 238 238 Cyperus alopecuroides
#
# 239 239 Cyperus
#
# 239 239 Cyperus kalli
#
# 240 240 Cyperus
#
# 240 240 Cyperus glaber
#
# 240 240 ^^ă^Cyperus
#
# 241 241 Cyperus
#
# 241 241 Cyperus esculentus
#
# 242 242 Scirpus
#
# 243 243 Scirpus cernuus
#
# 243 243 Scirpus holoschoenus
#
# 243 243 Scirpus mucronatus
#
# 244 244 Scirpus
#
# 244 244 Scirpus littoralis
#
# 244 244 Scirpus tuberosus
#
# 245 245 Blysmus
#
# 246 246 Fuirena
#
# 246 246 Heleocharis
#
# 246 246 Heleocharis macrantha
#
# 247 247 Fimbristylis ferruginea
#
# 247 247 Fimbristylis bis-umbellata
#
# 247 247 III,
#
# 248 248 Rhynchospora
#
# 248 248 Schoenus
#
# 249 249 Cladium mariscus
#
# 251 251 Garex stenophylla
#
# 251 251 Carex divisa
#
# 252 252 Carex otrubae
#
# 252 252 Carexdivulsa
#
# 253 253 Carex pairaei
#
# 253 253 Carex stellulata
#
# 253 253 Garex
#
# 254 254 Carex
#
# 254 254 Carex
#
# 254 254 Carex pallescens
#
# 255 255 Carex flacca
#
# 255 255 Carex
#
# 256 256 Garex
#
# 256 256 Carex buekii
#
# 257 257 Carex extensa
#
# 257 257 Carex
#
# 258 258 Carex distans
#
# 258 258 Cartex pseudocyperus
#
# 258 258 Carex acutiformis
#
# 259 259 Carex riparia
#
# 261 261 Arum
#
# 262 262 Arum palaestinum
#
# 264 264 Arum hygrophilum
#
# 264 264 Arum conophalloides
#
# 265 265 Arum elongatum
#
# 266 266 Arum gratum
#
# 266 266 Arum italicum
#
# 267 267 Arisarum
#
# 268 268 Eminium intortum
#
# 268 268 Eminium spiculatum
#
# 269 269 Biarum bovei
#
# 270 270 Biarum aleppicum
#
# 270 270 Biarum auraniticum
#
# 270 270 Biarum angustatum
#
# 271 271 Biarum
#
# 271 271 Biarum russellianum
#
# 272 272 Lemna minor
#
# 272 272 Lemna gibba
#
# 272 272 Lemna trisulca
#
# 273 273 Spirodela polyrrhiza
#
# 273 273 Luzula forsteri
#
# 275 275 Juncus inflexus
#
# 275 275 Juncus acutus
#
# 276 276 Juncus maritimus
#
# 276 276 Juncus subulatus
#
# 277 277 Juncus gerardi
#
# 277 277 Juncus punctorius
#
# 278 278 ^-^
#
# 278 278 Juncus
#
# 279 279 Juncus
#
# 279 279 Juncus capitatus
#
# 279 279 Juncus bufonius
#
# 280 280 Juncus tenageia
#
# 282 282 Colchicum
#
# 283 283 Colchicum hierosolymitanum
#
# 283 283 Colchicum balansae
#
# 283 283 Colchicun haussknechtii
#
# 284 284 Colchicum byzantinum
#
# 284 284 Colchicum tunicatum
#
# 284 284 Colchicum tauri
#
# 284 284 Colchicum
#
# 285 285 Colchicum
#
# 285 285 Colchicum libanoticum
#
# 285 285 Colchicum brachyphyllum
#
# 286 286 Colchicum
#
# 286 286 Colchicum
#
# 286 286 Colchicum steveni
#
# 287 287 Merendera
#
# 288 288 Androcymbium palaestinum
#
# 289 289 Asphodelus microcarpus
#
# 289 289 Asphodelus fistulosus
#
# 290 290 Asphodeline lutea
#
# 290 290 Asphodeline liburnica
#
# 291 291 Asphodeline brevicaulis
#
# 291 291 Asphodeline edumea
#
# 293 293 Asphodeline
#
# 293 293 Asphodeline
#
# 293 293 Asphodeline isthmocarpa
#
# 293 293 Asphodeline damascena
#
# 294 294 Eremurus
#
# 294 294 Eremurus inderiensis
#
# 295 295 Aloe vera
#
# 296 296 Lloydia
#
# 297 297 Gagea
#
# 297 297 Gagea arvensis
#
# 298 298 Gagea peduncularis
#
# 298 298 Gagea dubia
#
# 299 299 Gagea
#
# 300 300 Gagea minima
#
# 300 300 Gagea bohemica
#
# 300 300 Gagea reticulata
#
# 301 301 Gagea procera
#
# 302 302 Gagea circinnata
#
# 302 302 Gagea dayana
#
# 302 302 Gagea chlorantha
#
# 303 303 Gagea
#
# 304 304 Tulipa
#
# 305 305 Tulipa lownei
#
# 305 305 Tulipa
#
# 306 306 Tulipa agenensis
#
# 306 306 Tulipa aleppensis
#
# 307 307 Tulipa praecox
#
# 308 308 Tulipa montana
#
# 310 310 Fritillaria
#
# 310 310 Fritillaria acmopetala
#
# 310 310 Fritillaria alfredae
#
# 311 311 Fritillaria
#
# 311 311 Fritillaria pinardi
#
# 312 312 Fritillaria libanotica
#
# 312 312 Fritillaria
#
# 313 313 Lilium
#
# 314 314 Scilla autumnalis
#
# 314 314 Scilla
#
# 314 314 Scilla
#
# 314 314 Scilla cilicica
#
# 315 315 Scillâ
#
# 315 315 Scilla bifolia
#
# 315 315 Urginea maritima
#
# 317 317 Ornithogalum
#
# 317 317 Ornithogalum pyrenaicum
#
# 318 318 Ornithogalum narbonense
#
# 318 318 Ornithogalum
#
# 318 318 Ornithogalum fucescens
#
# 319 319 Ornithogalum
#
# 319 319 Ornithogalum billardieri
#
# 320 320 Ornithogalum
#
# 320 320 Ornithogalum
#
# 321 321 Ornithogalum
#
# 322 322 Ornithogalum
#
# 322 322 Ornithogalum
#
# 322 322 Ornithogalum tenuifolium
#
# 323 323 Puschkinia
#
# 323 323 Hyacinthus
#
# 324 324 Hyacinthella
#
# 325 325 Bellevalia trifoliata
#
# 325 325 Bellevalia macrobotrys
#
# 325 325 Bellevalia longipes
#
# 326 326 Bellevalia ciliata
#
# 326 326 Bellevalia douini
#
# 327 327 Bellevalia
#
# 327 327 Bellevalia
#
# 328 328 Bellevalia
#
# 328 328 Bellevalia nivalis
#
# 328 328 Bellevalia flexuosa
#
# 329 329 Bellevalia
#
# 330 330 Muscari
#
# 330 330 Muscari pinardi
#
# 330 330 Muscari
#
# 331 331 Muscari longipes
#
# 332 332 Muscari maritimum
#
# 332 332 Muscari racemosum
#
# 333 333 Muscari neglectum
#
# 333 333 Muscari commutatum
#
# 334 334 Muscari parviflorum
#
# 339 339 Allium sativum
#
# 340 340 Allium ampeloprasum
#
# 341 341 Allium
#
# 341 341 Allium pseudocalyptratum
#
# 342 342 Allium calyptratum
#
# 342 342 Allium drusorum
#
# 342 342 Allium rotundum
#
# 343 343 Allium
#
# 343 343 Allium vineale
#
# 344 344 Allium phanerantherum
#
# 344 344 Allium affine
#
# 344 344 Allium
#
# 345 345 Allium arvense
#
# 345 345 Allium
#
# 345 345 Allium descendens
#
# 346 346 Allium curtum
#
# 346 346 Allium emarginatum
#
# 347 347 Allium
#
# 347 347 Allium
#
# 348 348 Allium artemisietorum
#
# 348 348 Allium
#
# 348 348 Allium
#
# 348 348 Allium
#
# 349 349 Allium
#
# 349 349 Allium
#
# 350 350 Allium myrianthum
#
# 350 350 Allium
#
# 350 350 Allium
#
# 351 351 Allium paniculatum I
#
# 351 351 Allium
#
# 352 352 Allium
#
# 352 352 Allium coppoleri
#
# 352 352 Allium feinbergii
#
# 353 353 Allium
#
# 353 353 Allium azaurenum
#
# 354 354 Allium
#
# 354 354 Allium erdelii
#
# 355 355 Allium trifoliatum
#
# 356 356 Allium cassium
#
# 356 356 Allium
#
# 356 356 Allium
#
# 357 357 Allium laceratum
#
# 357 357 Allium
#
# 357 357 Allium qasyunense
#
# 357 357 Allium neapolitanum
#
# 358 358 Allium schuberti
#
# 358 358 Allium nigrum
#
# 359 359 Allium chrysantherum
#
# 359 359 Allium
#
# 360 360 Allium orientale
#
# 360 360 Allium asclepiadeum
#
# 360 360 Allium
#
# 361 361 Allium
#
# 361 361 Allium
#
# 362 362 Allium
#
# 363 363 Asparagus trichophyllus
#
# 363 363 Asparagus officinalis
#
# 363 363 Asparagus acutifolius
#
# 364 364 Asparagus
#
# 364 364 Asparagus stipularis
#
# 365 365 Ruscus aculeatus
#
# 365 365 Danaë racemosa
#
# 365 365 Smilax
#
# 366 366 Smilax
#
# 367 367 Galanthus
#
# 367 367 Sternbergia colchiciflora
#
# 368 368 Sternbergia pulchella
#
# 368 368 Sternbergia fischeriana
#
# 368 368 Sternbergia clusiana
#
# 369 369 Narcissus tazzetta
#
# 369 369 Narcissus serotinus
#
# 370 370 Pancratium parviflorum
#
# 370 370 Ixiolirion tataricum
#
# 371 371 Tamus
#
# 371 371 Tamus
#
# 373 373 Crocus
#
# 374 374 Crocus
#
# 374 374 Crocus
#
# 374 374 Crocus
#
# 375 375 Crocus
#
# 375 375 Crocus dispathaceus
#
# 376 376 Crocus
#
# 376 376 Crocus cancellatus
#
# 378 378 Crocus aleppicus
#
# 379 379 Crocus hyemalis
#
# 379 379 Crocus vitellinus
#
# 380 380 Crocus graveolens
#
# 380 380 Gladiolus segetum
#
# 381 381 Gladiolus imbricatus
#
# 382 382 Gladiolus aleppicus
#
# 382 382 Gynandriris sisyrinchium
#
# 385 385 Iris
#
# 386 386 Iris vartani
#
# 386 386 Iris persica
#
# 386 386 Iris postii
#
# 387 387 Iris palaestina
#
# 388 388 Iris nusairiensis
#
# 388 388 Iris sindjarensis
#
# 388 388 Iris fumosa
#
# 389 389 Iris unguicularis
#
# 389 389 Iris
#
# 389 389 Iris
#
# 390 390 Iris melanosticta
#
# 390 390 Iris
#
# 391 391 Iris
#
# 391 391 Iris
#
# 392 392 Iris auranitica
#
# 392 392 Iris barnumae
#
# 393 393 Iris
#
# 393 393 Iris antilibanotica
#
# 394 394 Iris basaltica
#
# 394 394 Iris bostrensis
#
# 394 394 Iris heylandiana
#
# 395 395 Iris
#
# 395 395 Iris cedreti
#
# 395 395 Iris yebrudi
#
# 395 395 Iris damascena
#
# 396 396 Iris sofarana
#
# 396 396 Iris
#
# 397 397 Iris
#
# 397 397 Romulea bulbocodium
#
# 398 398 Romulea nivalis
#
# 398 398 Romulea phoenicia
#
# 399 399 Romulea
#
# 399 399 Romulea
#
# 400 400 Spiranthes autumnalis
#
# 400 400 Limodorum
#
# 401 401 Cephalanthera
#
# 401 401 Cephalanthera rubra
#
# 402 402 Cephalanthera
#
# 402 402 Epipactis consimilis
#
# 403 403 Epipactis latifolia
#
# 403 403 Platanthera
#
# 404 404 Neotinea intacta
#
# 406 406 Ophrys
#
# 406 406 Ophrys iricolor
#
# 407 407 Ophrys
#
# 407 407 Ophrys speculum
#
# 407 407 Ophrys
#
# 408 408 Ophrys
#
# 408 408 Ophrys attica
#
# 409 409 Ophrys scolopax
#
# 410 410 Ophrys apifera
#
# 410 410 Ophrys argolica
#
# 411 411 Ophrys sintenesii
#
# 412 412 Orchis comperiana
#
# 413 413 Orchis papilionacea
#
# 413 413 Orchis morio L.
#
# 414 414 Orchis coriophora L.
#
# 414 414 Orchis sancta
#
# 415 415 Orchis tridentata
#
# 415 415 Orchis sixnia
#
# 416 416 Orchis punctulata
#
# 416 416 Orchis punctulata
#
# 417 417 Orchis punctulata
#
# 417 417 Orchis italica
#
# 417 417 Orchis iberica
#
# 418 418 Orchis collina
#
# 418 418 Orchis patens
#
# 418 418 Orchis patens X anatolica.
#
# 419 419 Orchis anatolica
#
# 419 419 Orchis romana
#
# 420 420 Orchis
#
# 420 420 Orchis holocheilos
#
# 420 420 Orchis maculata
#
# 421 421 Ânacamptis pyramidalis
#
# 422 422 Himantoglossum
#
# 422 422 Himantoglossum affine
#
# 423 423 Serapias
#
# 423 423 Serapias vomeracea X Orchis
#
# 425 425 Salix acmophylla
#
# 426 426 Salix australior
#
# 426 426 Salix dinsmorei
#
# 427 427 Salix alba L.,
#
# 427 427 Salix libani
#
# 429 429 Populus bolleana
#
# 429 429 Populus nigra
#
# 429 429 Populus
#
# 431 431 Populus
#
# 432 432 Juglans
#
# 432 432 Alnus
#
# 433 433 Carpinus
#
# 434 434 Ostrya carpinifolia
#
# 436 436 Quercus cedrorum
#
# 436 436 Quercus pinnatifida
#
# 437 437 Quercus infectoria
#
# 437 437 Var. boissieri
#
# 438 438 Var. latifolia
#
# 439 439 Quercus microphylla
#
# 439 439 Quercus libani
#
# 440 440 Quercus brantii
#
# 440 440 Ssp.
#
# 440 440 Ssp.
#
# 441 441 Quercus brantii
#
# 441 441 Quercus brantii
#
# 441 441 Quercus libani
#
# 442 442 Quercus
#
# 442 442 Ssp. ungeri
#
# 443 443 Quercus cerris
#
# 444 444 Quercus
#
# 446 446 Ulmus
#
# 446 446 Ulmus canescens
#
# 446 446 Ulmus glabra
#
# 446 446 Geltis
#
# 447 447 Celtis tournefortii
#
# 448 448 Ficus carica
#
# 448 448 Ficus
#
# 449 449 Urtica urens
#
# 450 450 Urtica membranacea
#
# 450 450 Urtica pilulifera
#
# 450 450 Urtica dioica
#
# 451 451 Urtica fragilis
#
# 452 452 Parietaria judaica
#
# 453 453 Parietaria eretica
#
# 453 453 Parietaria lusitanica
#
# 453 453 Parietaria
#
# 454 454 Cannabis sativa
#
# 454 454 Humulus
#
# 455 455 Osyris alba
#
# 456 456 Thesium arvense
#
# 456 456 Thesium
#
# 457 457 Thesium heterophyllum
#
# 457 457 Thesium humile
#
# 457 457 Thesium bergeri
#
# 458 458 Cynomorium
#
# 458 458 Cytinus hypocistis
#
# 459 459 Loranthus europaeus
#
# 459 459 Viscum
#
# 460 460 Arceuthobium
#
# 461 461 Aristolochia altissima
#
# 462 462 Aristolochia
#
# 462 462 Aristolochia
#
# 463 463 Aristolochia poecilantha
#
# 463 463 Aristolochia
#
# 463 463 Aristolochia
#
# 464 464 Aristolochia
#
# 466 466 Rumex
#
# 466 466 Rumex
#
# 467 467 Rumex crispus
#
# 467 467 Rumex conglomerates
#
# 468 468 Rumex
#
# 468 468 Rumex pulcher
#
# 469 469 Rumex
#
# 470 470 Rumex
#
# 470 470 Rumex
#
# 471 471 Rumex
#
# 472 472 Rumex vesicarius
#
# 472 472 Rumex cyprius
#
# 472 472 Rumex
#
# 473 473 Bilderdykia convolvulus
#
# 475 475 Polygonum
#
# 475 475 Polygonum salicifolium
#
# 475 475 Polygonum hydropiper
#
# 476 476 Polygonum
#
# 476 476 Polygonum
#
# 477 477 Polygonum polycnemoides
#
# 477 477 Polygonum corrigioloides
#
# 477 477 Polygonum kitaibelianum
#
# 478 478 Polygonum
#
# 478 478 Polygonum
#
# 478 478 Polygonum aviculare
#
# 479 479 Polygonum equisetiforme
#
# 479 479 Polygonum maritimum
#
# 479 479 Polygonum aleppicum
#
# 480 480 Polygonum cognatum
#
# 480 480 Polygonum setosum
#
# 480 480 Polygonum libani
#
# 481 481 Polygonum
#
# 481 481 Atraphaxis
#
# 482 482 Atraphaxis billardieri
#
# 482 482 Emex
#
# 482 482 Oxyria
#
# 483 483 Rheumribes
#
# 483 483 Rheum palaestinum
#
# 484 484 Calligonum
#
# 484 484 Calligonum tetrapterum
#
# 484 484 Beta vulgaris L.
#
# 486 486 Chenopodium vulvaria
#
# 486 486 Chenopodium album
#
# 486 486 Chenopodium opulifolium
#
# 486 486 Chenopodium murale
#
# 487 487 Ghenopodium
#
# 487 487 Chenopodium rubrum
#
# 487 487 Chenopodium botrys
#
# 487 487 Chenopodium ambrosioides
#
# 488 488 Chenopodium
#
# 488 488 Spinacia tetranda
#
# 489 489 Krascheninnikovia ceratoides
#
# 489 489 Halimione portulacoides
#
# 490 490 Atriplex
#
# 491 491 Atriplex stylosa
#
# 491 491 Atriplex thunbergiifolia
#
# 491 491 Atriplex leucoclada
#
# 491 491 Atriplex micrantha
#
# 492 492 Atriplex rosea
#
# 492 492 Atriplex
#
# 493 493 Atriplex
#
# 493 493 Atriplex hastata
#
# 493 493 microtheca
#
# 493 493 Atriplex patula
#
# 494 494 Atriplex littoralis
#
# 495 495 Panderia pilosa
#
# 495 495 Chenolea
#
# 495 495 Kochia scoparia
#
# 496 496 Bassia
#
# 496 496 Bassia hyssopifolia
#
# 496 496 Bassia muricata
#
# 497 497 Bassia
#
# 497 497 Arthrocnemum
#
# 498 498 Salicornia europaea
#
# 499 499 Halopeplis amplexicaulis
#
# 499 499 Halocnemum strobilaceum
#
# 499 499 Hypocylix kerneri
#
# 500 500 Hypocylix
#
# 501 501 Suaeda
#
# 501 501 Suaeda fruticosa
#
# 501 501 Suaeda altissima
#
# 501 501 Suaeda
#
# 501 501 Suaeda prostrata
#
# 502 502 Suaeda
#
# 502 502 Schanginia
#
# 503 503 Haloxylon
#
# 503 503 Haloxylon salicornicum
#
# 503 503 Traganum nudatum
#
# 504 504 Seidlitzia rosmarinus
#
# 504 504 Seidlitzia florida
#
# 506 506 Salsola kali
#
# 506 506 Salsola volkensii
#
# 506 506 Salsola inermis
#
# 507 507 Salsola jordanicola
#
# 507 507 Salsola incanescens
#
# 507 507 Salsola autrani
#
# 507 507 Salsola crassa
#
# 508 508 Salsola subcrassa
#
# 508 508 Salsola zenobiae
#
# 508 508 Salsola tetrandra
#
# 509 509 Salsola postii
#
# 509 509 Salsola heliaramiae
#
# 510 510 Salsola azaurena
#
# 510 510 Salsola canescens
#
# 510 510 Salsola villosa
#
# 511 511 Aellenia glauca
#
# 511 511 Aellenia
#
# 512 512 Noaea mucronata
#
# 512 512 Girgensohnia
#
# 513 513 Petrosimonia
#
# 513 513 Anabasis
#
# 513 513 Anabasis setifera
#
# 514 514 Halocharis
#
# 514 514 Halocharis
#
# 515 515 Halocharis
#
# 515 515 Halimocnemis
#
# 515 515 Cornulaca setifera
#
# 516 516 Halogeton
#
# 517 517 Âmaranthus
#
# 518 518 Amaranthus hybridus
#
# 519 519 Amaranthus
#
# 519 519 Amaranthus gracilis
#
# 519 519 Amaranthus
#
# 519 519 Amaranthus
#
# 520 520 Amaranthus
#
# 520 520 Amaranthus lividus
#
# 521 521 Amaranthus deflexus
#
# 521 521 Achyranthes
#
# 521 521 Alternanthera
#
# 522 522 Thelygonum cynocrambe
#
# 523 523 Phytolacca americana
#
# 523 523 Phytolacca
#
# 523 523 Boerhavia
#
# 524 524 Mesembryanthemum
#
# 525 525 Mesembryanthemum nodiflorum
#
# 525 525 Mesembryanthemum
#
# 525 525 Aizoon hispanicum
#
# 526 526 Glinus lotoides
#
# 526 526 Glinus dictamnoides
#
# 527 527 Portulacca
#
# 527 527 Montia fontana L.
#
# 528 528 Pteranthus
#
# 528 528 Scleranthus
#
# 529 529 Scleranthus
#
# 529 529 Habrosia spinuliflora
#
# 529 529 Gorrigiola
#
# 530 530 Telephium
#
# 530 530 Herniaria hirsuta
#
# 530 530 Herniaria cinerea
#
# 531 531 Herniaria glabra L.
#
# 531 531 Herniaria incana
#
# 531 531 Herniaria arabica
#
# 532 532 Herniaria hemistemon
#
# 532 532 Paronychia chionaea
#
# 533 533 Paronychia kurdica
#
# 533 533 Paronychia
#
# 533 533 Paronychia argentea
#
# 533 533 Paronychia arabica
#
# 534 534 Paronychia echinata
#
# 534 534 Polycarpon tetraphyllum
#
# 535 535 Polycarpon
#
# 535 535 Robbairea delileana
#
# 536 536 Spergularia diandra
#
# 536 536 Spergularia media
#
# 536 536 Spergularia marina
#
# 537 537 Spergularia
#
# 537 537 Spergula arvensis
#
# 537 537 Spergula fallax
#
# 538 538 Buffonia
#
# 538 538 Buffonia ephedrina
#
# 539 539 Sagina libanotica
#
# 539 539 Sagina apetala
#
# 539 539 Sagina maritima
#
# 541 541 Minuartia labillardieri
#
# 541 541 Minuartia juniperina
#
# 541 541 Minuartia libanotica
#
# 542 542 Minuartia parvulorum
#
# 542 542 Minuartia innominata
#
# 543 543 Minuartia
#
# 543 543 Minuartia
#
# 543 543 Minuartia intermedia
#
# 544 544 Minuartia decipiens
#
# 544 544 Minuartia montana
#
# 544 544 Minuartia mesogitana
#
# 545 545 Minuartia
#
# 545 545 Minuartia subtilis
#
# 545 545 Minuartia
#
# 546 546 Minuartia
#
# 546 546 Minuartia picta
#
# 547 547 Minuartia
#
# 547 547 Minuartia
#
# 548 548 Arenaria libanotica
#
# 548 548 Arenaria deflexa
#
# 549 549 Arenaria leptoclados
#
# 549 549 Arenaria serpyllifolia
#
# 549 549 Arenaria cassia
#
# 550 550 Arenaria tremula
#
# 550 550 Arenaria pamphylica
#
# 551 551 Stellaria
#
# 551 551 Stellaria media
#
# 552 552 Holosteum
#
# 552 552 Holosteum liniflorum
#
# 553 553 Moenchia
#
# 554 554 Cerastium dubium
#
# 555 555 Cerastium cerastoides
#
# 555 555 Cerastium perfoliatum
#
# 555 555 Cerastium comatum
#
# 555 555 Cerastium dichotomum
#
# 556 556 Cerastium
#
# 556 556 Cerastium glomeratum
#
# 556 556 Cerastium brachypetalum
#
# 557 557 Cerastium
#
# 557 557 Gerastium
#
# 558 558 Agrostemma githago
#
# 559 559 Melandrium
#
# 559 559 Melandrium eriocalycinum
#
# 564 564 Silène coniflora
#
# 565 565 Silène lydia
#
# 565 565 Silène
#
# 565 565 Silène
#
# 566 566 Silène
#
# 566 566 Silène
#
# 566 566 Silène
#
# 566 566 Silène
#
# 567 567 Silène caeli-rosa
#
# 567 567 Silène eretica
#
# 567 567 Silène
#
# 567 567 Silène
#
# 568 568 Silène racemosa
#
# 568 568 Silène
#
# 568 568 Silène
#
# 569 569 Silène
#
# 569 569 Silène
#
# 569 569 Silène
#
# 569 569 Silène
#
# 570 570 Silène
#
# 570 570 Silène
#
# 570 570 Silène
#
# 571 571 Silène
#
# 571 571 Silène
#
# 572 572 Silène
#
# 572 572 Silène sedoides
#
# 572 572 Silène
#
# 572 572 Silène
#
# 573 573 Silène kotschyi
#
# 573 573 Silène
#
# 573 573 Silène
#
# 574 574 Silène
#
# 574 574 Silène
#
# 575 575 Silène
#
# 575 575 Silène
#
# 575 575 Silène
#
# 575 575 Silène pharaaceifolia
#
# 576 576 Silène
#
# 576 576 Silène
#
# 576 576 Silène caryophylloides
#
# 576 576 Silène
#
# 577 577 Silène
#
# 577 577 Silène
#
# 578 578 Silène
#
# 578 578 Silène
#
# 578 578 Silène
#
# 579 579 Silène amana
#
# 579 579 Silène
#
# 579 579 Silène marschallii
#
# 579 579 Silène
#
# 580 580 Silène
#
# 580 580 Silène
#
# 581 581 Silène
#
# 581 581 Silène
#
# 581 581 Silène
#
# 582 582 Silène
#
# 582 582 Silène
#
# 582 582 Gucubalus
#
# 583 583 Vaccaria pyramidata
#
# 583 583 Vaccaria oxyodonta
#
# 584 584 Vaccaria
#
# 585 585 Saponaria bargyliana
#
# 585 585 Saponaria pulvinaris
#
# 585 585 Saponaria tridentata
#
# 587 587 Gypsophila
#
# 588 588 Gypsophila
#
# 588 588 Gypsophila arabica
#
# 589 589 Gypsophila
#
# 589 589 Gypsophila aucheri
#
# 589 589 Gypsophila pallida
#
# 590 590 Gypsophila damascena
#
# 590 590 Gypsophila ruscifolia
#
# 590 590 Gypsophila linearifolia
#
# 590 590 Gypsophila antari
#
# 591 591 Gypsophila
#
# 591 591 Gypsophila viscosa
#
# 592 592 Gypsophila
#
# 592 592 Gypsophila mollis
#
# 592 592 Gypsophila polygonoides
#
# 593 593 Gypsophila
#
# 593 593 Gypsophila pilosa
#
# 594 594 Ankyropetalum
#
# 594 594 Ankyropetalum coelesyriacum
#
# 594 594 Ankyropetalum arsusianum
#
# 595 595 Acanthophyllum kurdicum
#
# 595 595 Kohlrauschia velutina
#
# 596 596 Tunica syriaca
#
# 596 596 Tunica pachygona
#
# 596 596 Tunica arabica
#
# 597 597 Velezia rigida
#
# 597 597 Velezia fasciculata
#
# 599 599 Dianthus
#
# 599 599 Dianthus cyri
#
# 599 599 Dianthus strictus
#
# 603 603 Dianthus judaicus
#
# 603 603 Dianthus
#
# 603 603 Dianthus pachypetalus
#
# 604 604 Dianthus
#
# 604 604 Dianthus crinitus
#
# 604 604 Dianthus
#
# 605 605 Dianthus
#
# 606 606 Dianthus actinopetalus
#
# 606 606 Dianthus

# %%
from tqdm import tqdm
import math
# marked_fname = "marked-pages-book-1-sample.pdf"
marked_fname = "marked-pages-book-1.pdf"
#doc = fitz.open(fname)  # open document
doc = fitz.open(marked_fname)  # open document
print(len(results))

from fitz.utils import getColorList
cl = getColorList()
from fitz.utils import getColor

pink = getColor("lightpink")
green = getColor("aquamarine")
blue = getColor("lightskyblue")
gray = getColor("whitesmoke")
yellowish = getColor("antiquewhite")
fills= [pink, green, blue, gray, yellowish]

fc = {"L.":pink, "S.":blue, "Aire":green, "Description":gray, "Extra":yellowish}
for it, name in enumerate(tqdm(results.keys())):
    item = results[name]
    #print(item)
    #print(item["Description"])
    book_page = item["book_page"]
    pdf_page = item["pdf_page"]
    print([it, name, book_page, pdf_page])
    page = doc[book_page - 1]
    for k in filter(lambda x: not re.search(r"_page|_rect", x), item.keys()):
        rects = item[k + "_rects"]
        for r in rects:
            #print(k, r)
            
            if not page.rect.intersects(r):
                print(["ERROR: ", k, r])
            else:
                # #annot = page.add_highlight_annot(fitz.Rect(r))
                # annot_rect = page.add_rect_annot(fitz.Rect(r))
                # #annot_rect.set_colors(stroke=(0,1,0))
                # annot_rect.set_border(width=1, dashes=[1,2])
                # annot_rect.update()

                if k in ["L.", "S.", "Aire", "Description", "Extra"]:
                    print(["HIGHL: ", fc[k], k, r])
                    annot = page.add_highlight_annot(fitz.Rect(r))
                    annot.set_colors(stroke=fc[k])
                    annot.update()
                    #annot_rect = page.add_rect_annot(fitz.Rect(r))
                    #annot_rect.set_colors(stroke=green)
                    #annot_rect.set_border() #(width=1, dashes=[1,2])
                    #annot_rect.update()
                    #annot_rect.update(fill_color=red)


# doc.delete_pages(end_page, doc.page_count - 1)
# doc.delete_pages(0, start_page - 1)
doc_fname = "results-" + doc.name
doc.save(doc_fname, garbage=4, clean=True)
print(doc_fname)
# !open -a Preview results-marked-pages-book-1-sample.pdf
# !open -a Preview results-marked-pages-book-1.pdf
# Out:
#   2%|▏         | 14/862 [00:00<00:06, 138.46it/s]
# 862
# [0, 'r', 34, 34]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.200000762939453, -15.452678680419922, 30.185924530029297, 19.162628173828125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(259.9200134277344, 48.01697540283203, 346.7517395019531, 62.690975189208984)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(515.729736328125, 48.01697540283203, 555.8638305664062, 62.690975189208984)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(76.08000183105469, 76.53803253173828, 556.5704956054688, 95.21402740478516)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(48.720001220703125, 91.89801788330078, 256.58343505859375, 110.57401275634766)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(76.08000183105469, 111.81800079345703, 556.623046875, 130.49400329589844)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(49.20000076293945, 127.41797637939453, 556.8067626953125, 146.09397888183594)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(49.20000076293945, 143.01800537109375, 557.0657348632812, 161.6940155029297)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(76.08000183105469, 163.177978515625, 556.8696899414062, 181.85398864746094)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(48.959999084472656, 178.53802490234375, 557.43896484375, 197.2140350341797)]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [1, 'J', 59, 59]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(204.9600067138672, 209.43914794921875, 210.4595489501953, 224.66998291015625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.560001373291016, 224.52059936523438, 404.3040771484375, 237.5937957763672)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.440000534057617, 234.12060546875, 404.6605224609375, 247.1938018798828)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.68000030517578, 243.72061157226562, 60.10196304321289, 256.7938232421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(376.5589599609375, 243.72061157226562, 379.8223571777344, 256.7938232421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.479999542236328, 253.32061767578125, 87.4440689086914, 267.6678161621094)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(93.26875305175781, 253.32061767578125, 403.7171630859375, 267.6678161621094)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.560001373291016, 264.81597900390625, 79.77384948730469, 275.48797607421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.479999542236328, 272.5205993652344, 404.78472900390625, 285.59381103515625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.79999923706055, 282.12060546875, 404.8617248535156, 295.1938171386719)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.479999542236328, 291.7206115722656, 404.548828125, 304.7938232421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.560001373291016, 301.32061767578125, 175.1820831298828, 314.3938293457031)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.719999313354492, 310.92059326171875, 404.92608642578125, 323.9938049316406)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.79999923706055, 320.5205993652344, 404.3844299316406, 333.59381103515625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.479999542236328, 330.12060546875, 404.9262390136719, 343.1938171386719)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(46.79999923706055, 339.7206115722656, 174.46058654785156, 352.7938232421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.479999542236328, 349.32061767578125, 102.6443862915039, 362.3938293457031)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(110.48838806152344, 349.32061767578125, 384.22076416015625, 362.3938293457031)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.239999771118164, 358.92059326171875, 282.223388671875, 371.9938049316406)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.239999771118164, 368.5205993652344, 378.224853515625, 381.59381103515625)]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [2, 'JL', 77, 77]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.040000915527344, 429.4300231933594, 64.20848846435547, 442.77001953125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 439.0299987792969, 58.839996337890625, 452.3699951171875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 448.9630126953125, 48.72816467285156, 460.968994140625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.040000915527344, 458.8030090332031, 46.57548522949219, 470.8089904785156)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 469.2181091308594, 44.280338287353516, 479.887451171875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 477.52301025390625, 40.23395919799805, 489.52899169921875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 487.60302734375, 45.249298095703125, 499.6090087890625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 496.9630126953125, 43.73106002807617, 508.968994140625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 506.322998046875, 57.040199279785156, 518.3289794921875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.040000915527344, 515.9230346679688, 53.09760284423828, 527.9290161132812)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 526.338134765625, 51.17036437988281, 537.0074462890625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 535.1229858398438, 55.49325180053711, 547.1289672851562)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 544.1499633789062, 75.70565032958984, 557.489990234375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 555.3781127929688, 44.432228088378906, 566.0474243164062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 563.6829833984375, 66.97187805175781, 575.68896484375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 573.2830200195312, 54.100887298583984, 585.2890014648438)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 583.1229858398438, 66.77938079833984, 595.1289672851562)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 431.2077941894531, 148.59231567382812, 441.07940673828125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 440.0707092285156, 164.48936462402344, 450.8760986328125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 450.4078063964844, 127.16405487060547, 460.2794189453125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 459.27069091796875, 172.413818359375, 470.0760803222656)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.87999725341797, 470.0877990722656, 146.6795654296875, 479.95941162109375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 478.470703125, 164.0076141357422, 489.2760925292969)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 488.55072021484375, 152.7261505126953, 499.3561096191406)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 498.16778564453125, 144.03981018066406, 508.0393981933594)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 508.0077819824219, 138.99952697753906, 517.87939453125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.16000366210938, 515.6830444335938, 219.955810546875, 527.6890258789062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.63999938964844, 526.230712890625, 181.5283660888672, 537.0361328125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.87999725341797, 536.6436767578125, 165.0718994140625, 546.1151123046875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(97.19999694824219, 545.4307250976562, 196.4110565185547, 556.2361450195312)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 555.2706909179688, 173.84573364257812, 566.0761108398438)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 564.3906860351562, 197.847412109375, 575.1961059570312)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 573.99072265625, 172.65048217773438, 584.796142578125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(98.4000015258789, 584.3278198242188, 148.11978149414062, 594.1994018554688)]
# [3, 'Lycopodium cernuum', 78, 78]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(37.439998626708984, 302.656982421875, 402.1425476074219, 317.9909973144531)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(16.079999923706055, 314.177001953125, 401.6612548828125, 328.85101318359375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(15.84000015258789, 325.6969909667969, 401.57476806640625, 340.3710021972656)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(16.079999923706055, 337.21697998046875, 401.5955505371094, 363.4110107421875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(16.079999923706055, 360.2569885253906, 229.6329345703125, 374.9309997558594)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(38.400001525878906, 375.9499816894531, 266.6247253417969, 389.28997802734375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(38.400001525878906, 391.7900085449219, 401.5687561035156, 405.1300048828125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(15.84000015258789, 401.3899841308594, 401.5044250488281, 414.72998046875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(15.359999656677246, 410.9900207519531, 401.3779296875, 424.33001708984375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(15.84000015258789, 420.5899963378906, 401.49951171875, 433.92999267578125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(15.600000381469727, 430.19000244140625, 401.5040588378906, 443.5299987792969)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(38.15999984741211, 442.9100036621094, 401.8051452636719, 456.25)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(14.640000343322754, 452.75, 295.1842956542969, 466.0899963378906)]
# [4, 'Selaginella denticulata', 79, 79]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(64.80000305175781, 53.17700958251953, 427.4947509765625, 68.5110092163086)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.47999954223633, 64.69702911376953, 427.3425598144531, 102.4110107421875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.720001220703125, 99.25702667236328, 427.0232849121094, 113.9310302734375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.47999954223633, 110.77698516845703, 177.17547607421875, 125.45098876953125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(64.55999755859375, 125.26998901367188, 427.32476806640625, 138.6099853515625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(42.47999954223633, 134.87002563476562, 338.14263916015625, 148.21002197265625)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(65.04000091552734, 146.6300048828125, 427.10760498046875, 159.97000122070312)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.0, 156.23001098632812, 426.6591491699219, 169.57000732421875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.720001220703125, 165.82998657226562, 287.9794006347656, 179.16998291015625)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(64.80000305175781, 175.67001342773438, 281.23681640625, 189.010009765625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(63.84000015258789, 187.19000244140625, 300.6985168457031, 200.52999877929688)]
# [5, 'Isoetes hystrix', 79, 79]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(61.91999816894531, 342.3769836425781, 425.1159973144531, 357.71099853515625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 353.8970031738281, 425.4226379394531, 368.5710144042969)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 365.4169921875, 424.819580078125, 380.09100341796875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.31999969482422, 376.9369812011719, 425.0955505371094, 391.6109924316406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 388.4570007324219, 424.8651428222656, 403.1310119628906)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 399.97698974609375, 366.4353332519531, 414.6510009765625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(62.880001068115234, 414.7099914550781, 287.2635192871094, 428.04998779296875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(62.400001525878906, 466.7900085449219, 424.34161376953125, 480.1300048828125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 476.3899841308594, 424.36346435546875, 499.33001708984375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 495.5899963378906, 424.4288330078125, 508.92999267578125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 505.1899719238281, 244.30467224121094, 518.5299682617188)]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(62.63999938964844, 426.4700012207031, 424.91302490234375, 439.80999755859375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(40.08000183105469, 436.07000732421875, 262.54290771484375, 449.4100036621094)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(62.880001068115234, 445.6700134277344, 424.84674072265625, 459.010009765625)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(39.84000015258789, 454.4255065917969, 152.21109008789062, 468.6099853515625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(61.68000030517578, 516.949951171875, 424.0526428222656, 530.2899780273438)]
# [6, 'Isoetes olympica', 79, 79]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(61.20000076293945, 530.0570068359375, 424.1019287109375, 545.3909912109375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(39.36000061035156, 553.0969848632812, 423.81964111328125, 567.77099609375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(39.119998931884766, 564.6170043945312, 339.4117431640625, 579.291015625)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(57.599998474121094, 589.6699829101562, 349.6617736816406, 603.010009765625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(57.119998931884766, 600.7099609375, 211.4234161376953, 614.0499877929688)]
# [7, 'Equisetum maximum', 80, 80]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.599998474121094, 281.656982421875, 409.3381652832031, 296.9909973144531)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(25.200000762939453, 293.177001953125, 409.49658203125, 307.85101318359375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.239999771118164, 304.6969909667969, 409.0162658691406, 330.8909912109375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.0, 327.73699951171875, 132.05357360839844, 342.4110107421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(42.0, 343.19000244140625, 228.94476318359375, 356.5299987792969)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.0, 355.9100036621094, 409.1746520996094, 369.25)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(24.239999771118164, 365.510009765625, 408.9761657714844, 378.8500061035156)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(24.959999084472656, 375.1100158691406, 95.26384735107422, 388.45001220703125)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(42.47999954223633, 387.8299865722656, 223.1834259033203, 401.16998291015625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(41.7599983215332, 400.7900085449219, 316.3052062988281, 414.1300048828125)]
# [8, 'Equisetum palustre', 80, 80]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.36000061035156, 420.61700439453125, 409.38525390625, 435.9510192871094)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.760000228881836, 432.1369934082031, 409.50244140625, 446.8110046386719)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.760000228881836, 443.656982421875, 409.255126953125, 458.33099365234375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.0, 455.177001953125, 368.9320068359375, 469.85101318359375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(42.0, 470.3899841308594, 408.696533203125, 483.72998046875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(24.0, 479.9900207519531, 62.71009063720703, 493.33001708984375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.0, 492.7099914550781, 409.303955078125, 506.04998779296875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(24.0, 502.3099670410156, 244.5421142578125, 515.6499633789062)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(41.7599983215332, 515.0299682617188, 227.5091094970703, 528.3699951171875)]
# [9, 'Equisetum ramosissimum', 80, 80]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.36000061035156, 534.6170043945312, 409.2551574707031, 549.9509887695312)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 546.136962890625, 408.8975524902344, 560.8109741210938)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 557.656982421875, 409.1033020019531, 572.3309936523438)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 569.177001953125, 409.27667236328125, 583.8510131835938)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.760000228881836, 580.697021484375, 409.176025390625, 595.3710327148438)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.760000228881836, 592.2169799804688, 85.7330322265625, 606.8909912109375)]
# [10, 'Ophioglossum vulgatum', 81, 81]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(67.19999694824219, 220.81698608398438, 430.1445007324219, 236.1510009765625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(44.880001068115234, 232.57699584960938, 430.22161865234375, 259.0110168457031)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.599998474121094, 256.09698486328125, 429.8126220703125, 270.77099609375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.119998931884766, 267.85699462890625, 309.8916015625, 282.531005859375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(63.36000061035156, 281.6300048828125, 219.82275390625, 294.9700012207031)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(63.599998474121094, 293.1499938964844, 311.74835205078125, 306.489990234375)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(62.880001068115234, 305.1499938964844, 341.97979736328125, 318.489990234375)]
# [11, 'Ophioglossum lusitanicum', 81, 81]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(44.400001525878906, 536.177001953125, 428.9349060058594, 550.8510131835938)]
# [12, 'Osmunda regalis', 81, 81]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(66.23999786376953, 490.09698486328125, 429.0200500488281, 505.4309997558594)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.36000061035156, 501.61700439453125, 429.4241027832031, 516.291015625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(44.63999938964844, 513.136962890625, 429.25140380859375, 527.8109741210938)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(44.15999984741211, 524.656982421875, 429.19586181640625, 539.3309936523438)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(44.400001525878906, 536.177001953125, 428.9349060058594, 550.8510131835938)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(62.15999984741211, 550.6699829101562, 269.98492431640625, 564.010009765625)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(62.63999938964844, 562.4299926757812, 429.1668395996094, 575.77001953125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(45.36000061035156, 572.0299682617188, 428.6544189453125, 585.3699951171875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(44.63999938964844, 581.6299438476562, 337.4257507324219, 594.969970703125)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(62.15999984741211, 593.1499633789062, 428.7875061035156, 606.489990234375)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(44.15999984741211, 603.22998046875, 180.9423370361328, 616.5700073242188)]
# [13, 'Gymnogramma leptophylla', 82, 82]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.47999954223633, 230.13699340820312, 405.3917541503906, 245.47100830078125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.639999389648438, 241.89700317382812, 405.02227783203125, 256.5710144042969)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.639999389648438, 253.656982421875, 404.7809143066406, 268.33099365234375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.15999984741211, 265.4169921875, 404.7818603515625, 280.09100341796875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.639999389648438, 277.177001953125, 404.7808532714844, 303.6109924316406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.399999618530273, 300.6969909667969, 278.4513854980469, 315.3710021972656)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(38.63999938964844, 313.510009765625, 217.1815185546875, 326.8500061035156)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(38.400001525878906, 326.7099914550781, 404.1763610839844, 340.04998779296875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(20.639999389648438, 336.07000732421875, 92.85861206054688, 349.4100036621094)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(38.63999938964844, 348.30999755859375, 173.74232482910156, 361.6499938964844)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(38.15999984741211, 360.07000732421875, 404.5470886230469, 373.4100036621094)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(20.15999984741211, 369.6700134277344, 404.1453857421875, 383.010009765625)]
# [14, 'Cheilanthes', 82, 82]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(41.7599983215332, 425.2569885253906, 404.4852294921875, 440.59100341796875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(20.8799991607666, 437.0169982910156, 403.9891052246094, 451.6910095214844)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.440000534057617, 448.7769775390625, 403.7442321777344, 475.21099853515625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.68000030517578, 472.2969970703125, 403.82373046875, 486.97100830078125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.440000534057617, 484.0570068359375, 403.82342529296875, 498.73101806640625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.200000762939453, 495.8169860839844, 287.3335876464844, 510.4909973144531)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(37.91999816894531, 509.5899963378906, 191.4945831298828, 522.9299926757812)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(37.68000030517578, 521.1099853515625, 403.4494323730469, 534.4500122070312)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(19.440000534057617, 530.7099609375, 258.2250061035156, 544.0499877929688)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(37.68000030517578, 542.469970703125, 403.2101135253906, 555.8099975585938)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(19.68000030517578, 552.0699462890625, 191.49111938476562, 565.4099731445312)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(36.959999084472656, 564.0699462890625, 337.9063415527344, 577.4099731445312)]
# [15, 'Âdiantum capillus-veneris', 83, 83]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(65.27999877929688, 586.697021484375, 429.2643737792969, 602.031005859375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(43.91999816894531, 598.4569702148438, 428.9449157714844, 613.1309814453125)]
# [16, 'Pteris longifolia', 84, 84]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.599998474121094, 198.57699584960938, 408.30218505859375, 213.9110107421875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.0, 210.33700561523438, 408.46063232421875, 225.01101684570312)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.0, 222.09698486328125, 408.0194091796875, 248.531005859375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.239999771118164, 245.61700439453125, 408.01263427734375, 260.291015625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(24.0, 257.3769836425781, 309.6536560058594, 272.0509948730469)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(42.2400016784668, 270.9100036621094, 276.9424133300781, 284.25)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.2400016784668, 282.42999267578125, 408.4949645996094, 295.7699890136719)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(24.239999771118164, 292.0299987792969, 216.49600219726562, 305.3699951171875)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(41.7599983215332, 304.0299987792969, 323.986572265625, 317.3699951171875)]
# [17, 'Pteridium aquilmum', 84, 84]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(45.36000061035156, 359.61700439453125, 408.29425048828125, 374.9510192871094)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.760000228881836, 371.3769836425781, 408.21600341796875, 386.0509948730469)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 383.1369934082031, 408.5417175292969, 409.57098388671875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 406.656982421875, 408.50238037109375, 421.33099365234375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 418.4169921875, 408.26348876953125, 433.09100341796875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(23.520000457763672, 430.177001953125, 292.8515625, 444.85101318359375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(41.7599983215332, 443.7099914550781, 373.18402099609375, 457.04998779296875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.0, 455.4700012207031, 408.4931335449219, 468.80999755859375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(23.760000228881836, 465.07000732421875, 408.46484375, 478.4100036621094)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(42.2400016784668, 476.8299865722656, 201.1033172607422, 490.16998291015625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(40.79999923706055, 488.8299865722656, 153.5847930908203, 502.16998291015625)]
# [18, 'Athyrium', 85, 85]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(58.560001373291016, 48.147621154785156, 421.3424072265625, 63.20281982421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(37.68000030517578, 60.147621154785156, 420.7310485839844, 74.55481719970703)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 71.90763092041016, 421.18328857421875, 86.31482696533203)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.720001220703125, 83.6675796508789, 421.264404296875, 98.07477569580078)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.720001220703125, 95.4275894165039, 421.2665710449219, 109.83478546142578)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.720001220703125, 107.1875991821289, 421.0224914550781, 121.59479522705078)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.47999954223633, 118.9476089477539, 326.6954040527344, 133.3548126220703)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(54.720001220703125, 132.1475830078125, 210.22625732421875, 146.55479431152344)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(58.08000183105469, 184.70758056640625, 420.7895812988281, 199.1147918701172)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.0, 196.46759033203125, 420.85919189453125, 210.8748016357422)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.0, 208.22760009765625, 420.7912292480469, 222.6348114013672)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.0, 219.98757934570312, 235.97682189941406, 234.39479064941406)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(54.2400016784668, 233.6676025390625, 337.9674377441406, 248.07481384277344)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(336.7200012207031, 245.64404296875, 420.6604309082031, 257.6487121582031)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(54.2400016784668, 257.88299560546875, 420.3487548828125, 269.88897705078125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.0, 267.4830017089844, 156.4202880859375, 279.4889831542969)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(319.67999267578125, 277.0830078125, 420.4049072265625, 289.0889892578125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(54.2400016784668, 144.86758422851562, 371.25982666015625, 159.27479553222656)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(54.2400016784668, 157.82760620117188, 421.10498046875, 172.2348175048828)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(36.47999954223633, 167.6676025390625, 98.14575958251953, 182.07481384277344)]
# [19, 'Dryopterîs aculeata', 85, 85]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(57.36000061035156, 295.8276062011719, 420.92779541015625, 310.8828125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(36.0, 307.58758544921875, 420.7884216308594, 321.9947814941406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(35.52000045776367, 319.34759521484375, 420.25677490234375, 345.5148010253906)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(36.0, 342.8675842285156, 420.54754638671875, 357.2747802734375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(35.52000045776367, 354.6275939941406, 420.7762756347656, 369.0347900390625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(57.36000061035156, 371.4275817871094, 420.7242736816406, 386.277587890625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 384.2027893066406, 420.8441162109375, 398.03759765625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.52000045776367, 394.9476013183594, 336.6856384277344, 409.35479736328125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(53.52000045776367, 408.6275939941406, 198.9468231201172, 423.0347900390625)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(53.7599983215332, 421.34759521484375, 369.18695068359375, 435.7763977050781)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(53.52000045776367, 435.0827941894531, 420.87567138671875, 448.9176025390625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(35.52000045776367, 444.92279052734375, 119.91618347167969, 458.7575988769531)]
# [20, 'Dryopteris', 85, 85]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(57.36000061035156, 465.0504150390625, 420.1060485839844, 478.9176025390625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.279998779296875, 476.5704345703125, 420.5262451171875, 490.4376220703125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.2400016784668, 488.1227722167969, 420.5536804199219, 501.95758056640625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(34.79999923706055, 499.6427917480469, 420.0829772949219, 513.4776000976562)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(34.79999923706055, 510.1476135253906, 420.50299072265625, 536.0747680664062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(34.560001373291016, 533.1876220703125, 420.3164367675781, 559.1148071289062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(34.79999923706055, 556.2276000976562, 420.2960205078125, 570.634765625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(35.040000915527344, 567.7476196289062, 420.5591735839844, 582.15478515625)]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [21, 'Blechnum', 86, 86]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.720001220703125, 585.5369873046875, 400.5043029785156, 600.8709716796875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(15.119999885559082, 597.2969970703125, 400.70318603515625, 611.9710083007812)]
# [22, 'Ceterack officinarum', 87, 87]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(58.31999969482422, 240.33700561523438, 420.6257629394531, 255.6710205078125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(37.439998626708984, 252.09698486328125, 420.55841064453125, 266.77099609375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(36.720001220703125, 263.85699462890625, 188.66014099121094, 278.531005859375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(199.92039489746094, 263.85699462890625, 420.69635009765625, 278.531005859375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.2400016784668, 275.61700439453125, 420.796875, 290.291015625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.2400016784668, 287.3769836425781, 420.5445251464844, 302.0509948730469)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.47999954223633, 299.1369934082031, 420.6225280761719, 313.8110046386719)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.2400016784668, 310.8970031738281, 420.6214599609375, 325.5710144042969)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.0, 322.656982421875, 109.73321533203125, 337.33099365234375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(54.47999954223633, 337.0030212402344, 243.31842041015625, 349.0090026855469)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(54.47999954223633, 349.0030212402344, 420.0164489746094, 361.0090026855469)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(36.959999084472656, 358.6029968261719, 350.1138916015625, 370.6089782714844)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(54.47999954223633, 370.3630065917969, 419.95361328125, 382.3689880371094)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(36.0, 379.9630126953125, 223.39537048339844, 391.968994140625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(53.7599983215332, 391.7230224609375, 419.49786376953125, 403.72900390625)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(36.0, 401.56298828125, 79.35309600830078, 413.5689697265625)]
# [23, 'Asplenium bourgaei', 88, 88]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.0, 51.29700469970703, 408.0754089355469, 66.6310043334961)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.639999389648438, 62.81702423095703, 404.61956787109375, 77.49102783203125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.399999618530273, 74.33698272705078, 404.94378662109375, 89.010986328125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.399999618530273, 85.85700225830078, 405.26116943359375, 100.531005859375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.15999984741211, 97.37702178955078, 404.9612731933594, 112.051025390625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(20.15999984741211, 108.89698028564453, 104.21299743652344, 123.57098388671875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(38.400001525878906, 123.14999389648438, 124.30329132080078, 136.489990234375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(37.91999816894531, 158.67001342773438, 403.4246826171875, 172.010009765625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.920000076293945, 169.32298278808594, 201.92120361328125, 181.32899475097656)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(38.15999984741211, 135.14999389648438, 290.86138916015625, 148.489990234375)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(37.91999816894531, 146.91000366210938, 275.9843444824219, 160.25)]
# [24, 'Asplenium', 88, 88]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(40.31999969482422, 552.5640258789062, 403.57257080078125, 569.2919921875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(19.920000076293945, 565.3770141601562, 403.207763671875, 580.051025390625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.719999313354492, 577.136962890625, 403.5162353515625, 603.5709838867188)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.959999084472656, 600.656982421875, 403.58343505859375, 615.3309936523438)]
# [25, 'Asplenium ruta-muraria', 88, 88]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.040000915527344, 299.9369812011719, 403.8209533691406, 315.27099609375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(19.440000534057617, 311.9369812011719, 403.4526062011719, 326.6109924316406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(18.959999084472656, 323.9369812011719, 403.81866455078125, 362.6109924316406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(18.959999084472656, 359.9369812011719, 403.22119140625, 374.6109924316406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(18.959999084472656, 371.9369812011719, 277.97412109375, 386.6109924316406)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(37.20000076293945, 384.9900207519531, 258.7005615234375, 398.33001708984375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(37.439998626708984, 397.9499816894531, 403.59521484375, 411.28997802734375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(19.440000534057617, 407.5500183105469, 403.4896545410156, 420.8900146484375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(19.440000534057617, 417.1499938964844, 262.54046630859375, 430.489990234375)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(37.439998626708984, 429.8699951171875, 156.7023162841797, 443.2099914550781)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(37.20000076293945, 442.8299865722656, 403.66436767578125, 456.16998291015625)]
# [26, 'Phyllitis scolopendrium', 89, 89]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(63.119998931884766, 275.0973815917969, 438.6167907714844, 286.9732971191406)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.0, 287.1663818359375, 425.6222229003906, 298.7333068847656)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.7599983215332, 298.9263916015625, 425.480712890625, 310.4933166503906)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.52000045776367, 310.6864013671875, 425.862548828125, 322.2532958984375)]
# ...
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(60.47999954223633, 118.62997436523438, 236.38299560546875, 131.969970703125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(60.47999954223633, 130.14999389648438, 427.0691223144531, 143.489990234375)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.959999084472656, 139.75, 427.6359558105469, 153.08999633789062)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(42.2400016784668, 149.35000610351562, 423.615478515625, 172.29000854492188)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(60.47999954223633, 170.70999145507812, 427.4004821777344, 184.04998779296875)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(42.47999954223633, 180.30999755859375, 426.9358215332031, 193.64999389648438)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(42.0, 189.91000366210938, 426.46136474609375, 203.25)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(59.7599983215332, 201.67001342773438, 286.3047180175781, 215.010009765625)]
# [854, 'Velezia fasciculata', 597, 597]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(63.119998931884766, 220.0570068359375, 426.5261535644531, 235.39102172851562)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(42.2400016784668, 232.0570068359375, 426.3036193847656, 246.73101806640625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.7599983215332, 244.0570068359375, 426.3079833984375, 258.73101806640625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.7599983215332, 256.0570068359375, 426.53448486328125, 282.73101806640625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(59.279998779296875, 281.1100158691406, 426.22357177734375, 294.45001220703125)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(59.040000915527344, 294.30999755859375, 425.1838684082031, 307.6499938964844)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(41.52000045776367, 303.9100036621094, 212.86549377441406, 317.25)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(59.279998779296875, 316.6300048828125, 259.1807556152344, 329.9700012207031)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(59.040000915527344, 329.5899963378906, 166.06399536132812, 342.92999267578125)]
# [855, 'Dianthus', 606, 606]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(41.279998779296875, 152.7769775390625, 402.6900634765625, 168.11099243164062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(18.959999084472656, 164.2969970703125, 403.2625427246094, 178.97100830078125)]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [856, 'Dianthus cyri', 599, 599]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(63.119998931884766, 195.577392578125, 426.3634338378906, 207.4532928466797)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.279998779296875, 207.8863983154297, 426.1087341308594, 243.4532928466797)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.279998779296875, 243.8863983154297, 425.96710205078125, 255.4532928466797)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(41.040000915527344, 255.8863983154297, 425.8678894042969, 267.45330810546875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(59.040000915527344, 267.88641357421875, 177.86068725585938, 279.45330810546875)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(59.040000915527344, 280.84637451171875, 425.89581298828125, 292.4132995605469)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(40.79999923706055, 290.6864013671875, 82.58100891113281, 302.2532958984375)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(58.79999923706055, 303.4063720703125, 151.70054626464844, 314.9732971191406)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(58.560001373291016, 315.88641357421875, 421.1397399902344, 327.45330810546875)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(40.79999923706055, 325.72637939453125, 311.7778625488281, 337.2933044433594)]
# [857, 'Dianthus strictus', 599, 599]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(62.400001525878906, 342.6973876953125, 425.6291198730469, 354.57330322265625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 354.52642822265625, 425.62896728515625, 366.09332275390625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 366.04638671875, 425.3868713378906, 377.6133117675781)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.31999969482422, 377.56640625, 425.0104675292969, 389.1333312988281)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 389.08636474609375, 425.043701171875, 400.6532897949219)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 400.60638427734375, 425.0147399902344, 412.1733093261719)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 412.12640380859375, 425.1075744628906, 423.6933288574219)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 423.6463623046875, 425.1474304199219, 435.2132873535156)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 435.1663818359375, 424.8734130859375, 458.2533264160156)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 458.2064208984375, 425.1460266113281, 469.7733154296875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.31999969482422, 469.72637939453125, 424.7690124511719, 481.2933044433594)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 481.24639892578125, 424.90496826171875, 492.8133239746094)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(39.84000015258789, 492.76641845703125, 424.3162841796875, 504.33331298828125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(39.84000015258789, 504.286376953125, 424.67022705078125, 515.853271484375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.08000183105469, 515.806396484375, 249.94920349121094, 527.373291015625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(57.84000015258789, 532.3663940429688, 233.30340576171875, 543.9332885742188)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(58.08000183105469, 541.7263793945312, 424.07177734375, 553.2932739257812)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 552.7954711914062, 425.8373718261719, 562.2578735351562)]
# 100%|██████████| 862/862 [00:06<00:00, 129.32it/s]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.84000015258789, 560.4463500976562, 424.0772399902344, 572.0132446289062)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 569.806396484375, 431.3534240722656, 581.373291015625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.84000015258789, 579.1663818359375, 424.0456237792969, 590.7332763671875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(38.400001525878906, 588.5263671875, 424.1494140625, 600.09326171875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(39.599998474121094, 597.8864135742188, 424.3891296386719, 609.4533081054688)]
# [858, 'Dianthus judaicus', 603, 603]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(55.91999816894531, 42.05701446533203, 418.85345458984375, 57.391014099121094)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(35.7599983215332, 53.57697296142578, 418.62677001953125, 68.2509765625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.560001373291016, 65.09699249267578, 418.7008361816406, 91.291015625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(35.040000915527344, 88.13697052001953, 418.569091796875, 102.81097412109375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.79999923706055, 99.65699005126953, 418.7813720703125, 114.33099365234375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.560001373291016, 111.17700958251953, 418.84967041015625, 125.85101318359375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.79999923706055, 122.6969985961914, 418.93890380859375, 137.37100219726562)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.560001373291016, 134.21697998046875, 418.87628173828125, 148.8909912109375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.79999923706055, 145.73699951171875, 418.8677062988281, 160.4110107421875)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.79999923706055, 157.25698852539062, 419.009033203125, 171.93099975585938)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.560001373291016, 168.7769775390625, 260.2130126953125, 183.45098876953125)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(55.68000030517578, 187.97698974609375, 343.734619140625, 203.31100463867188)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(52.31999969482422, 201.26998901367188, 222.46115112304688, 214.6099853515625)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(52.08000183105469, 276.82830810546875, 132.9723358154297, 288.7008972167969)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(52.31999969482422, 213.26998901367188, 419.0234069824219, 226.6099853515625)]
# ['HIGHL: ', (1.0, 0.7137254901960784, 0.7568627450980392), 'L.', Rect(34.31999969482422, 222.6300048828125, 144.22142028808594, 235.97000122070312)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(52.560001373291016, 234.3900146484375, 418.62109375, 247.73001098632812)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(35.040000915527344, 243.989990234375, 419.1515808105469, 257.3299865722656)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(34.08000183105469, 253.58999633789062, 418.81982421875, 266.92999267578125)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(32.880001068115234, 263.19000244140625, 392.1453857421875, 276.5299987792969)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(52.560001373291016, 288.6300048828125, 419.1888427734375, 301.9700012207031)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(34.31999969482422, 298.2300109863281, 284.8609313964844, 311.57000732421875)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(52.08000183105469, 310.95001220703125, 257.5020446777344, 324.2900085449219)]
# [859, 'Dianthus pachypetalus', 603, 603]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(55.439998626708984, 555.89697265625, 419.3346862792969, 571.23095703125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.31999969482422, 567.656982421875, 419.66778564453125, 594.0910034179688)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(34.08000183105469, 591.177001953125, 419.3454895019531, 605.8510131835938)]
# [860, 'Dianthus crinitus', 604, 604]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(44.400001525878906, 331.85699462890625, 406.6378479003906, 347.1910095214844)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(22.31999969482422, 343.61700439453125, 406.4736633300781, 358.291015625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(22.079999923706055, 355.3769836425781, 406.3812561035156, 370.0509948730469)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(22.31999969482422, 367.1369934082031, 406.6133117675781, 381.8110046386719)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(21.84000015258789, 378.89697265625, 402.6933288574219, 405.33099365234375)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(40.08000183105469, 408.2699890136719, 118.5489273071289, 421.6099853515625)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(39.84000015258789, 420.0299987792969, 113.74342346191406, 433.3699951171875)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(39.84000015258789, 431.5500183105469, 355.42437744140625, 444.8900146484375)]
# [861, 'Dianthus actinopetalus', 606, 606]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(40.560001373291016, 40.93701934814453, 404.2367248535156, 56.271018981933594)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(18.719999313354492, 52.69702911376953, 404.2113037109375, 79.1309814453125)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(19.200000762939453, 76.21698760986328, 403.9794921875, 90.8909912109375)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(19.440000534057617, 87.97699737548828, 403.9896240234375, 102.6510009765625)]
# ['HIGHL: ', (0.9607843137254902, 0.9607843137254902, 0.9607843137254902), 'Description', Rect(19.440000534057617, 99.73700714111328, 329.5763854980469, 114.4110107421875)]
# ['HIGHL: ', (0.9803921568627451, 0.9215686274509803, 0.8431372549019608), 'Extra', Rect(36.959999084472656, 113.26998901367188, 180.9446258544922, 126.6099853515625)]
# ['HIGHL: ', (0.5294117647058824, 0.807843137254902, 0.9803921568627451), 'S.', Rect(37.439998626708984, 126.08300018310547, 169.11328125, 138.08900451660156)]
# ['HIGHL: ', (0.4980392156862745, 1.0, 0.8313725490196079), 'Aire', Rect(37.20000076293945, 136.30999755859375, 216.46231079101562, 149.64999389648438)]
# results-marked-pages-book-1.pdf

# %%
import pandas as pd

df = pd.DataFrame.from_dict(results.values()).fillna('')
df = df[df.columns.drop(list(df.filter(regex='_rects')))]
df.to_csv("book-1.csv", index=False)
df
# Out:
#                         name  pdf_page  book_page  \
# 0                          r        34         34
# 1                          J        59         59
# 2                         JL        77         77
# 3         Lycopodium cernuum        78         78
# 4    Selaginella denticulata        79         79
# ..                       ...       ...        ...
# 857        Dianthus strictus       599        599
# 858        Dianthus judaicus       603        603
# 859    Dianthus pachypetalus       603        603
# 860        Dianthus crinitus       604        604
# 861   Dianthus actinopetalus       606        606
#
#                                                  Extra  \
# 0    r INTRODUCTION XXXVII Occupant des aires très ...
# 1    J Lettre alternant dans la transcription de mo...
# 2    Nab, N Nahal Nik Np Ol P Pb Pr Reese Russ Sam ...
# 3    Fructification de novembre à mars. Sur grès tr...
# 4    Végétation active de novembre à avril. Fructif...
# ..                                                 ...
# 857  Floraison: mai-décembre. CC. tous terrains. Le...
# 858  Var. auraniticus (Post.) n. comb. — Calice 3 c...
# 859
# 860                               Floraison: mai-juin.
# 861              Floraison: été. Rochers et murailles.
#
#                                            Description  \
# 0
# 1
# 2
# 3    Lycopodium cernuum L. var. capillaceum Willd (...
# 4    Selaginella denticulata (L.) Link — Lycopodium...
# ..                                                 ...
# 857  Dianthus strictus Banks et Sol. (non Sibth. et...
# 858  Dianthus judaicus Boiss. — D. pattens Sibth. e...
# 859  Dianthus pachypetalus Stapf— D. floribundus Bo...
# 860  Dianthus crinitus Smith (PI. CLXXXV, n. 4). — ...
# 861  Dianthus actinopetalus Fenzl (PI. CLXXXVI, n. ...
#
#                                                     L.  \
# 0
# 1
# 2
# 3    L. Mi. Entre Nahr es Safa et 'Aïn Qa'a, 1942 e...
# 4    L. Ct. et ML, Ce. Saïda (Bl), Beyrouth et envi...
# ..                                                 ...
# 857
# 858  L. Sy. Baalbeck (Wall). St. Qamou'at Hermel (P...
# 859
# 860
# 861
#
#                                                   Aire  \
# 0
# 1
# 2
# 3    Aire géogr. —- Régions tropicales et subtropic...
# 4    Aire géogr. —• Tour de la Méditerranée. Madère...
# ..                                                 ...
# 857
# 858  Aire géogr. — Turquie sud, Syrie, Liban, Pales...
# 859
# 860  Aire géogr. — Turquie, Géorgie, Iran, Bélouchi...
# 861       Aire géogr. — Ile de Cos, Turquie, Antioche.
#
#                                                     S.
# 0
# 1
# 2
# 3
# 4    S. Non signalée. Présence presque certaine, Ct...
# ..                                                 ...
# 857
# 858  S. A.L. Ouadi-el-Qarn (Sam, Mt, Pb), Zebdani, ...
# 859
# 860                                 S. St. Zélaf (Pb).
# 861                  S. Est de Lattaquié : Bdama (JL).
#
# [862 rows x 8 columns]
