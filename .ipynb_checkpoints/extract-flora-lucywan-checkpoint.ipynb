# %%
# !pip install pyresparser fitz PyMuPDF pypdf2 >/dev/null
# Out:
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !ln -sf "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE.pdf" document.pdf #alias

# %%
import fitz
document = 'document.pdf'
filename = document
search_term = "the"
pdf_document = fitz.open(filename)

# %%
doc = pdf_document
dir(doc)
# Out:
# ['FontInfos',
#  'FormFonts',
#  'Graftmaps',
#  'PDFCatalog',
#  'PDFTrailer',
#  'ShownPages',
#  '__class__',
#  '__contains__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  '_addFormFont',
#  '_delToC',
#  '_delXmlMetadata',
#  '_deleteObject',
#  '_deletePage',
#  '_do_links',
#  '_dropOutline',
#  '_embeddedFileAdd',
#  '_embeddedFileDel',
#  '_embeddedFileGet',
#  '_embeddedFileIndex',
#  '_embeddedFileInfo',
#  '_embeddedFileNames',
#  '_embeddedFileUpd',
#  '_forget_page',
#  '_getCharWidths',
#  '_getMetadata',
#  '_getNewXref',
#  '_getOLRootNumber',
#  '_getPDFfileid',
#  '_getPDFroot',
#  '_getPageInfo',
#  '_getPageObjNumber',
#  '_getPageXref',
#  '_getTrailerString',
#  '_getXmlMetadataXref',
#  '_getXrefLength',
#  '_getXrefStream',
#  '_getXrefStreamRaw',
#  '_getXrefString',
#  '_graft_id',
#  '_hasXrefOldStyle',
#  '_hasXrefStream',
#  '_loadOutline',
#  '_make_page_map',
#  '_move_copy_page',
#  '_newPage',
#  '_outline',
#  '_page_refs',
#  '_remove_links_to',
#  '_reset_page_refs',
#  '_setMetadata',
#  '_updateObject',
#  '_updateStream',
#  'authenticate',
#  'can_save_incrementally',
#  'chapterCount',
#  'chapterPageCount',
#  'close',
#  'convertToPDF',
#  'copyPage',
#  'deletePage',
#  'deletePageRange',
#  'embeddedFileAdd',
#  'embeddedFileCount',
#  'embeddedFileDel',
#  'embeddedFileGet',
#  'embeddedFileInfo',
#  'embeddedFileNames',
#  'embeddedFileUpd',
#  'extractFont',
#  'extractImage',
#  'findBookmark',
#  'fullcopyPage',
#  'getCharWidths',
#  'getPageFontList',
#  'getPageImageList',
#  'getPagePixmap',
#  'getPageText',
#  'getPageXObjectList',
#  'getSigFlags',
#  'getToC',
#  'get_pdf_object',
#  'initData',
#  'insertPDF',
#  'insertPage',
#  'isClosed',
#  'isDirty',
#  'isEncrypted',
#  'isFormPDF',
#  'isPDF',
#  'isReflowable',
#  'isStream',
#  'language',
#  'lastLocation',
#  'layout',
#  'loadPage',
#  'location_from_page_number',
#  'makeBookmark',
#  'metadata',
#  'metadataXML',
#  'movePage',
#  'name',
#  'needsPass',
#  'newPage',
#  'nextLocation',
#  'outline',
#  'pageCount',
#  'page_number_from_location',
#  'pages',
#  'permissions',
#  'previousLocation',
#  'reload_page',
#  'resolveLink',
#  'save',
#  'saveIncr',
#  'scrub',
#  'searchPageFor',
#  'select',
#  'setLanguage',
#  'setMetadata',
#  'setToC',
#  'stream',
#  'this',
#  'thisown',
#  'updateObject',
#  'updateStream',
#  'write',
#  'xrefLength',
#  'xrefObject',
#  'xrefStream',
#  'xrefStreamRaw']

# %%
doc.getToC()
# Out:
# [[1, 'Abreviations', 77]]

# %%
doc.searchPageFor(528, 'Pteranthus')
# Out:
# [Rect(37.68000030517578, 99.17700958251953, 113.67733764648438, 113.85101318359375),
#  Rect(37.91999816894531, 164.3159942626953, 94.519287109375, 179.55099487304688)]

# %%
# https://pymupdf.readthedocs.io/en/latest/faq/#how-to-analyze-font-characteristics

import fitz
import pprint, re

def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return ", ".join(l)


doc = fitz.open("document.pdf")
page = doc[528]

# %%
#header = 'Family	Genus	epithet	author	syn.	Plate	description	Floraison from	Floraison to	Floraison notes	L.	S.	Aire géogr.	Notes'
header = 'Family	GenusDescription	Genus	epithet	author	syn.	Plate	description	Floraison	L.	S.	Aire géogr.	Notes'
columns = header.split('	')
columns
# Out:
# ['Family',
#  'GenusDescription',
#  'Genus',
#  'epithet',
#  'author',
#  'syn.',
#  'Plate',
#  'description',
#  'Floraison',
#  'L.',
#  'S.',
#  'Aire géogr.',
#  'Notes']

# %%
class Face:
    def __init__(self, font, size, color, flags=0):
        self.font = font
        self.size = size
        self.color = color
        self.flags = flags
        self.style = flags_decomposer(self.flags)
    def __str__(self):
        return f"Font: '{self.font}' ({self.style}), size {self.size:g}, color " + ("#%06x" % self.color)

def isfamily(t, fp):
    font = "Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000"
    if  re.match('^[A-Z]+$', t) or str(font) == fp:
        return True

    
#general Genus description
def isGenGenus(t, fp):
    font = "Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000"
    if re.match('[A-Z]+\s[A-Z][a-z]*\.\s\—\s[A-Z]([a-z]|\s|,|[a-zàâçéèêëîïôûùüÿñæœ .-])+', t) or str(font) == fp:
        #print(f'''Text: {t}\n{fp}\n\n''')
        return True
    
#continuation of general Genus description
def isGenGenusContinued(t, fp, prevText):
    #'Times-Roman' (serifed, proportional), size 11, color #000000
#     print("fon", fp)
#     print("text", t)
    font = "Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000"
    #re.match('([A-Z][a-z]|\s|,|[a-zàâçéèêëîïôûùüÿñæœ .-])+', t)  
#     print("prev",prevText)
    if font != str(fp) and prevText:
        #print(f'''Text: {t}\n{fp}\n\n''')
        return False
    return True

def prevHasPeriod(t):
    return re.match('.*(\.)$', t)
    
def isGenus(t, fp):
    font = "Font: 'Times-Bold' (serifed, proportional, bold), size 10.9449, color #000000"
    font2 = "Font: 'Times-Bold' (serifed, proportional, bold), size 11, color #000000"
    if (re.match('[A-Z][a-z]+', t) or re.match('[A-Z][a-z]+\s[a-z]+', t)) and (font == str(fp) or font2 == str(fp)):
        return True
    
def isEpithet(t, fp):
    font = "Font: 'Times-Bold' (serifed, proportional, bold), size 11, color #000000"
    font2 = "Font: 'Times-Bold' (serifed, proportional, bold), size 10.9449, color #000000"
    if re.match('\s[a-z]+', t) or (str(font) == fp or str(font2) == fp):
        #print(f'''Text: {t}\n{fp}\n\n''')
        return True
    
def isAuthor(t, fp):
    font = "Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000"
    if str(font) == fp:
        #print(f'''Text: {t}\n{fp}\n\n''')
        return True

def isFlori(t, fp):
    return re.match('Floraison:.*', t)

def isL(t,fp):
    return re.match('L\..*', t)

def isS(t, fp):
    return re.match('S\..*', t)

def isGeo(t, fp):
    return re.match('Aire géogr\. —.*', t)

data = {}


p = (doc[x] for x in range(516,604))
p = (doc[x] for x in range(527,604))
p
# Out:
# <generator object <genexpr> at 0x7fcc763929d0>

# %%
#aaron was in the middle of working on this and it has an error we know about
# import re

# def floraison(doc, pagenum=0, block_start=0):
#     for page in next(p):
#         blocks = page.getText("dict", flags=11)["blocks"]
#         for x,b in enumerate(blocks[block_start:]):  # iterate through the text blocks
#             for y,l in enumerate(b["lines"]):  # iterate through the text lines
#                 for z,s in enumerate(l["spans"]):  # iterate through the text spans
#                     s["style"] = flags_decomposer(s["flags"])  # readable font flags
#                     face = Face(s["font"], s["size"], s["color"], s["flags"])
#                     if re.match("Floraison", s["text"]):
#                         yield (page.number, x, y, z, s["text"])

# p = (doc[x] for x in range(516,540))
# next(floraison(doc, x))

# %%
p = (doc[x] for x in range(527,604))
p
# Out:
# <generator object <genexpr> at 0x7fcc76606f50>

# %%
page.number
# Out:
# 529

# %%
#             if isfamily(s["text"], face) and len(l["spans"]) == 1:
#                 item['Family'] = s["text"]
#                 print(x, len(blocks), y, z, s["text"], face)
#                 break
#             if not item['Family']:
#                 break
#             if s['font'] == 'Times-Bold':
#                 item['Genus'], *item['epithet'] = s["text"].split(' ')
#                 item['epithet'] = item['epithet'][0] if item['epithet'] else l["spans"][1]["text"]
#                 currsize = s['size']
#                 print(x, len(blocks), y, len(b["lines"]), z, s["text"], face)
#                 from pprint import pprint
#                 print(x, len(blocks), y, z, pprint(item))
#                 print(); print(); 
#                 break
#             elif item['Genus'] and (not item['author']) and (s['font'] == 'Times-Roman'):
#                 item['author'] = s["text"]
#                 print(x, len(blocks), y, len(b["lines"]), z, s["text"], face)
#                 print(item)
#                 break

# %%
import pandas as pd

# %%
frame = pd.DataFrame(columns = ['text', 'font', 'size', 'style', 'color', 'flags'])

# %%
item = dict.fromkeys(columns)

# %%
#ignore
#simplify
item = dict.fromkeys(columns)
p = (doc[x] for x in range(528,604))
page = next(p)
# read page text as a dictionary, suppressing extra spaces in CJK fonts
blocks = page.getText("dict", flags=11)["blocks"]
onGenGenus = False
onGenus = False
for x,b in enumerate(blocks): # iterate through the text blocks
    for y,l in enumerate(b["lines"]):  # iterate through the text lines
        for z,s in enumerate(l["spans"]):  # iterate through the text spans
            s["style"] = flags_decomposer(s["flags"])  # readable font flags
            face = Face(s["font"], s["size"], s["color"], s["flags"])
            #creating a data frame for analyzed
#             values = [s['text'],s['font'], s['size'], s['style'], s['color'], s['flags']]
#             columns = ['text', 'font', 'size', 'style', 'color', 'flags']
#             zipped = zip(columns, values)
#             a_dictionary = dict(zipped)
#             frame = frame.append(a_dictionary,ignore_index=True)
#             print(frame)
#             print(s['text'], "***",s['font'], "***", s['size'], "***", s['style'], "***", s['color'], "***", s['flags'],"********************************************************\n")
            
            if onGenGenus:
                
                #re.match('.*(\.)$', s['text'])
                if isGenGenusContinued(s["text"], face, prevPeriod):
                    item['GenusDescription'] += s["text"]
                    prevPeriod = prevHasPeriod(s["text"])
                    item['GenusDescription'] += s["text"]
#                     print("description")
#                     print(x, len(blocks), y, z, s["text"], face)
                else:
                    onGenGenus = False
#                 if z + 1 < len(l["spans"]) and l['spans'][z+1]['font'] == 'Times-Bold':
#                     #write more
#                     print(x, len(blocks), y, z, s["text"], face)

#                 print("description")
#                 print(item['GenusDescription'])

            if isfamily(s["text"], face) and len(l["spans"]) == 1:
                item['Family'] = s["text"]
                print("family")
                print(x, len(blocks), y, z, s["text"], face)
#             elif isfamily(s["text"], face) and len(l["spans"]) == 1:
#                 item['Family'] = s["text"]
#                 print(x, len(blocks), y, z, s["text"], face)
#                 break

            elif isGenGenus(s["text"], face):
                item['GenusDescription'] = s["text"]
                onGenGenus = True
                if not re.match('.*(\.)$', s['text']):
                    prevPeriod = False
                else:
                    prevPeriod = True
            elif not item['Genus'] and isGenus(s["text"], face):
                if re.match(".*\s.*", s["text"]):
                    item['Genus'] = s["text"].split()[0]
                    item['epithet'] = s["text"].split()[1]
                else:
                    item['Genus'] = s["text"]
                    onGenus = True
                print(s["text"])
            elif onGenus:
                item['epithet'] = s["text"]
                onGenus = False
#             elif s['font'] == 'Times-Bold' and not item['Genus'] and not item['epithet'] and re.match("[A-Z].+\s.+", s["text"]):
#                 item['Genus'], *item['epithet'] = s["text"].split(' ')
#                 item['epithet'] = item['epithet'][0] if item['epithet'] else l["spans"][1]["text"]
#                 currsize = s['size']
# #                print(x, len(blocks), y, z, s["text"], font_properties)
#                 print("both")
#                 print(x, len(blocks), y, len(b["lines"]), z, s["text"], face)
#             elif isGenus(s["text"], face) and not item['Genus'] and re.match("[A-Z].+", s["text"]):
#                 item['Genus'] = s["text"]
#                 print("genus")
#                 print(x, len(blocks), y, z, s["text"], face)
#             elif isEpithet(s["text"], face) and item['Genus'] and not item['epithet'] and re.match("\s.*", s["text"]):
#                 item['epithet'] = s["text"]
#                 print("epithet")
#                 print(x, len(blocks), y, z, s["text"], face)
print(item)
# Out:
# Pteranthus
# {'Family': None, 'GenusDescription': 'SCLERANTHUS L. — Herbes de petite taille, à feuilles linéaires-sétacées.Calice à tube urcéolé, à la fin durci. 5 sépales mutiques. Pétales filiformes, parfoisCalice à tube urcéolé, à la fin durci. 5 sépales mutiques. Pétales filiformes, parfoisavortés. Étamines 5. Ovaire libre. Styles 2, distincts.avortés. Étamines 5. Ovaire libre. Styles 2, distincts.', 'Genus': 'Pteranthus', 'epithet': ' dichotomus', 'author': None, 'syn.': None, 'Plate': None, 'description': None, 'Floraison': None, 'L.': None, 'S.': None, 'Aire géogr.': None, 'Notes': None}

# %%
#print info
arr2 = []

# read page text as a dictionary, suppressing extra spaces in CJK fonts

for page in (doc[x] for x in range(528,604)):
    blocks = page.getText("dict", flags=11)["blocks"]
    onGenGenus = False
    onGenus = False
    for x,b in enumerate(blocks): # iterate through the text blocks
        for y,l in enumerate(b["lines"]):  # iterate through the text lines
            for z,s in enumerate(l["spans"]):  # iterate through the text spans
                s["style"] = flags_decomposer(s["flags"])  # readable font flags
                face = Face(s["font"], s["size"], s["color"], s["flags"])
                arr2.append([s["text"], Face(s["font"], s["size"], s["color"], s["flags"]), page])
                #creating a data frame for analyze

# %%
block_frame = pd.DataFrame(arr2)

# %%
block_frame.to_csv("blocks4.csv")

# %%
import numpy as np

# %%
columns = ['Family',
 'GenusDescription',
 'Genus',
 'epithet',
 'author',
 'syn.',
 'Plate',
 'description',
 'FloraisonStart',
 'FloraisonEnd',
 'FloraisonNotes',
 'L.',
 'S.',
 'Aire géogr.',
 'Notes']

# %%
frame = pd.DataFrame(columns = columns)

# %%
frame.loc[len(frame)] = 0

# %%
frame
# Out:
#   Family GenusDescription Genus epithet author syn. Plate description  \
# 0      0                0     0       0      0    0     0           0
#
#   FloraisonStart FloraisonEnd FloraisonNotes L. S. Aire géogr. Notes
# 0              0            0              0  0  0           0     0

# %%
frame.loc[len(frame)] = 0

# %%
#curr cell
#genus description
frame = pd.DataFrame(columns = columns)
arr = []
#528,605
for page in (doc[x] for x in range(450,605)):
    # page = next(p)
    # read page text as a dictionary, suppressing extra spaces in CJK fonts
    blocks = page.getText("dict", flags=11)["blocks"]
    onGenGenus = False
    floriCount = 0
    onGenus = False
    onL = False
    onS = False
    for x,b in enumerate(blocks): # iterate through the text blocks
        for y,l in enumerate(b["lines"]):  # iterate through the text lines
            for z,s in enumerate(l["spans"]):  # iterate through the text spans
                s["style"] = flags_decomposer(s["flags"])  # readable font flags
                face = Face(s["font"], s["size"], s["color"], s["flags"])
                #creating a data frame for analyzed
    #             values = [s['text'],s['font'], s['size'], s['style'], s['color'], s['flags']]
    #             columns = ['text', 'font', 'size', 'style', 'color', 'flags']
    #             zipped = zip(columns, values)
    #             a_dictionary = dict(zipped)
    #             frame = frame.append(a_dictionary,ignore_index=True)
    #             print(frame)
    #             print(s['text'], "***",s['font'], "***", s['size'], "***", s['style'], "***", s['color'], "***", s['flags'],"********************************************************\n")
                print(onS)
                print(s['text'])
                if onGenGenus:

                    #re.match('.*(\.)$', s['text'])
                    if isGenGenusContinued(s["text"], face, prevPeriod):
#                         arr[-1][0] += s["text"]
                        frame.iloc[-1]['GenusDescription'] += s["text"]
                        item['GenusDescription'] += s["text"]
                        prevPeriod = prevHasPeriod(s["text"])
                        item['GenusDescription'] += s["text"]
                        print("description")
                        print(x, len(blocks), y, z, s["text"], face)
                    else:
                        onGenGenus = False
    #                 if z + 1 < len(l["spans"]) and l['spans'][z+1]['font'] == 'Times-Bold':
    #                     #write more
    #                     print(x, len(blocks), y, z, s["text"], face)


                if isfamily(s["text"], face) and len(l["spans"]) == 1:
                    item['Family'] = s["text"]
                    print("family")
                    print(x, len(blocks), y, z, s["text"], face)
    #             elif isfamily(s["text"], face) and len(l["spans"]) == 1:
    #                 item['Family'] = s["text"]
    #                 print(x, len(blocks), y, z, s["text"], face)
    #                 break

                elif isGenGenus(s["text"], face):
                    item['GenusDescription'] = s["text"]
                    onGenGenus = True
                    if not re.match('.*(\.)$', s['text']):
                        prevPeriod = False
                    else:
                        prevPeriod = True
                    print("description")
                    print(x, len(blocks), y, z, s["text"], face)
#                     arr.append([s['text'], page])
                    frame.loc[len(frame)] = 0
                    frame.iloc[-1]['GenusDescription'] = s["text"]
                elif isGenus(s["text"], face):
                    frame.loc[len(frame)] = 0
                    if re.match(".*\s.*", s["text"]):
#                         arr.append(["genus", s["text"].split()[0], s["text"].split()[1], page])
                        frame.iloc[-1]['Genus'] = s["text"].split()[0]
                        frame.iloc[-1]['epithet'] = s["text"].split()[1]
                    else:
#                         arr.append(["genus", s["text"].split()[0], 0, page])
                        frame.iloc[-1]['Genus'] = s["text"].split()[0]
                        onGenus = True
                    print(s["text"])
                elif onGenus:
#                     arr[-1][2] = s["text"]
                    frame.iloc[-1]['epithet'] = s["text"]
                    onGenus = False
                elif floriCount:
                    if isL(s["text"], face) or isS(s["text"], face):
                        floriCount = 0
#                     else:
#                         frame.iloc[-1]['Floraison'] += s["text"]
                    else:
                        lis = s["text"].split()
                        print(lis)
                        if floriCount == 1:
                            if "-" in lis[0]:
                                months = lis[0].split("-")
                                print("m",months)
                                frame.iloc[-1]['FloraisonStart'] = months[0]
                                frame.iloc[-1]['FloraisonEnd'] = months[1]
                                lis = lis[1:]
                            floriCount += 1
                            if lis:
                                frame.iloc[-1]['FloraisonNotes'] = lis[0]
                                lis = lis[1:]
                                floriCount += 1
                        else:
                            frame.iloc[-1]['FloraisonNotes'] = lis[0]
                            lis = lis[1:]
                            floriCount += 1
                elif isFlori(s["text"], face):
                    lis = s["text"].split()[1:]
                    print("l", lis)
                    floriCount += 1
                    if lis:
                        if "-" in lis[0]:
                            months = lis[0].split("-")
                            print("m",months)
                            frame.iloc[-1]['FloraisonStart'] = months[0]
                            frame.iloc[-1]['FloraisonEnd'] = months[1]
                            lis = lis[1:]
                        floriCount += 1
                    if lis:
                        frame.iloc[-1]['FloraisonNotes'] = lis[0]
                        lis = lis[1:]
                        floriCount += 1
#                 elif onL:
#                     if isL(s["text"], face) or isS(s["text"], face) or isGeo(s["text"], face):
#                         onL = False
#                     else:
#                         frame.iloc[-1]['L.'] += s["text"]
#                 elif onS:
#                     if isL(s["text"], face) or isS(s["text"], face) or isGeo(s["text"], face):
#                         onS = False
#                     else:
#                         print(frame[-3:-1])
#                         print("hi", s['text'])
#                         frame.iloc[-1]['S.'] += s["text"]
#                 elif isL(s["text"], face):
#                     frame.iloc[-1]['L.'] = s["text"]
#                     onL = True
#                 elif isS(s["text"], face):
#                     frame.iloc[-1]['S.'] = s["text"]
#                     onS = True
                    
                    
                    
# print(item)
# print(arr)
frame
# Out:
# False
# NOUVELLE FLORE
# False
# 451
# False
# Sous-famille des
# False
#  PARONYCHIOIDEAE
# False
# Feuilles habituellement stipulées. Sépales libres ou faiblement concrescents.
# False
# Corolle le plus souvent absente.
# False
# PTERANTHUS Forsk. — Herbe annuelle, charnue, à feuilles opposées, fas-
# description
# 4 28 0 0 PTERANTHUS Forsk. — Herbe annuelle, charnue, à feuilles opposées, fas- Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# ciculifères, ce qui les rend pseudo-verticillées. Cymes
# description
# 5 28 0 0 ciculifères, ce qui les rend pseudo-verticillées. Cymes Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
#  biflores
# description
# 5 28 0 1  biflores Font: 'Times-Roman' (serifed, proportional), size 11, color #000000
# False
#  portés par un pédon-
# description
# 5 28 0 2  portés par un pédon- Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# cule commun accrescent, large, oblong, aplati et tombant avec lui. Fleurs sessiles,
# description
# 5 28 1 0 cule commun accrescent, large, oblong, aplati et tombant avec lui. Fleurs sessiles, Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# latérales. Calice 4-partite à sépales oblongs-linéaires, prolongés par un appendice
# description
# 5 28 2 0 latérales. Calice 4-partite à sépales oblongs-linéaires, prolongés par un appendice Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# vertical scarieux-marginé. 4 étamines. Pas de corolle.
# description
# 5 28 3 0 vertical scarieux-marginé. 4 étamines. Pas de corolle. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Pteranthus
# Pteranthus
# False
#  dichotomus
# False
#  Forsk. —
# False
#  P. echinatus
# False
#  Desf.
# False
#  (PI.
# False
#  CLV, n. 1). —
# False
# 0. Tige très rameuse à la base, couchée ou ascendante, 10-40 cm. triangulaires,
# False
# plus ou moins dentées, opposées et fasciculifères, les feuilles des fascicules plus courtes
# False
# et plus fines. Pédoncules floraux aux aisselles des feuilles supérieures, papilleux,
# False
# hirsutes, d'abord cylindriques, mais se développant rapidement en une sorte de
# False
# raquette ovale, atténuée à la base. Fleurs sessiles, à 4 sépales, prolongés par un
# False
# appendice scarieux, lui-même terminé par une courte épine, et entourées de rameaux
# False
# stériles armés de plusieurs épines, les égalant sans les dépasser.
# False
# Floraison: mars-mai. Régions arides.
# l ['mars-mai.', 'Régions', 'arides.']
# m ['mars', 'mai.']
# False
# S.
# False
#
# False
# St.
# False
#  Palmyre
# False
#  (Sam, Mt, Pb), Palmyre à Arak,
# False
#  Bir-al-'Alaniyé
# False
#  (Pb),
# False
#  Jabal-et-Tenf
# False
#  (Bb).
# False
# Sud.
# False
#  Hammé
# False
#  (Pb).
# False
# Aire géogr. —• Afrique du Nord,
# False
#  Egypte,
# False
#  Ethiopie,
# False
#  Chypre, Palestine sud,
# False
#  TransJordanie,
# False
#  Syrie,
# False
# Iraq, Iran, Géorgie.
# False
# SCLERANTHUS L. — Herbes de petite taille, à feuilles linéaires-sétacées.
# description
# 12 28 0 0 SCLERANTHUS L. — Herbes de petite taille, à feuilles linéaires-sétacées. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Calice à tube urcéolé, à la fin durci. 5 sépales mutiques. Pétales filiformes, parfois
# description
# 13 28 0 0 Calice à tube urcéolé, à la fin durci. 5 sépales mutiques. Pétales filiformes, parfois Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# avortés. Étamines 5. Ovaire libre. Styles 2, distincts.
# description
# 13 28 1 0 avortés. Étamines 5. Ovaire libre. Styles 2, distincts. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Calice de très petite taille, 2 mm. seulement à sépales courts et un peu marginés
# False
# S.
# False
#  collinus
# False
#  Hornung
# False
# Calice de 4 mm. ou davantage à sépales verts, égalant ou dépassant la longueur du tube
# False
# Sépales tous droits
# False
#
# False
# S.
# False
#  annuus
# False
#  L.
# False
# Sépales tous fortement courbés et uncinés
# False
#
# False
# S.
# False
#  uncinatus
# False
#  Schur.
# False
# Sépales les uns droits les autres recourbés, sur les mêmes fruits
# False
# S. orientalis
# False
#  Rôssler.
# False
# Scleranthus
# Scleranthus
# False
#  orientalis
# False
#  Rôssler,
# False
#  Phyton, Vol. 7, pp. 206-224, 1957
# False
#  (PI.
# False
# CLIV,
# False
#  n. 8). — ®. Plante annuelle, 1,3 à 20 cm. de haut, non glanduleuse. Tiges
# False
# décombantes, ascendantes ou dressées au sommet, à pilosité uniforme.
# False
#  Entrenceuds
# False
# longs de 0,5 à 4 cm. de long. Feuilles opposées
# False
#
# False
# à
# False
#  5 cm. de long, subulées, poilues
# False
# vers la base et brièvement connées par leurs gaines. Glomérules de l'inflorescence
# False
# en
# False
#  cyme
# False
#  rameuse ou très courte. Fleurs plus ou moins sessiles. Tépales 5, lancéolés,
# False
# aigus, étroitement marginés seulement vers la base, les uns rectilignes, les autres
# False
# uncinés-recourbés
# False
#  sur le même fruit. Étamines 5 à 2. Staminodes présents. Ovaire
# False
# à 2 stigmates, enfermé dans le réceptacle induré. Faux fruit, mûr, mesurant 3,2 à
# False
# 5,3 mm. Tépales étalés ou dressés ou connivents.
# False
# Floraison: mars-juin. Grès et terrains non calcaires, légèrement hygrophile.
# l ['mars-juin.', 'Grès', 'et', 'terrains', 'non', 'calcaires,', 'légèrement', 'hygrophile.']
# m ['mars', 'juin.']
# False
# L.
# False
#
# False
# Mi.
# False
#  Bikfaya, Mayrouba (Mt),
# False
#  Neba'-l-Bata,
# False
#  au-dessus de
# False
#  Jbail
# False
#  (Bl).
# False
#  Mm.
# False
#  Khan Sannine,
# False
# Falougha (Mt), Col de
# False
#  Zahlé
# False
#  (Bl, Th, Mt, Pb).
# False
#  Ve.
# False
#  Jabal-ech-Cha'arra
# False
#  (Mt).
# False
# S.
# False
#
# False
# Mi.
# False
#  'Aïn
# False
#  Halakim (Har).
# False
#  A.L.
# False
#  Jabal
# False
#  Gharbi (Pr).
# False
# Aire géogr. —
# False
#  Erythrée,
# False
#  Ethiopie,
# False
#  Liban, Syrie, Caucase, Iraq, Iran.
# False
# 452
# False
# NOUVELLE FLORE
# False
# Les indications des Flores précédentes de Syrie et Liban pour
# False
#  Se.
# False
#  annuus
# False
#  doivent
# False
# certainement être rapportées à cette espèce.
# False
#  Sel. uncinatus,
# False
#  présent dans les montagnes
# False
# de Turquie, n'est pas connu de notre région.
# False
# Scleranthus
# Scleranthus
# False
#  collinus
# False
#  Horn. —
# False
#  Sel.
# False
#  verticillatus
# False
#  Tausch
# False
#  (PI.
# False
#  CLIV,
# False
#  n. 9). —
# False
# ®. Plante de très petite taille, 3-10 cm. Calice mesurant seulement 2 mm. Sépales
# False
# plus nettement marginés que dans l'espèce précédente.
# False
# Floraison:
# l []
# False
#  mars-mai.
# ['mars-mai.']
# m ['mars', 'mai.']
# False
#  Régions boisées.
# ['Régions', 'boisées.']
# False
# S.
# False
#  Mm.
# False
#  Slenfé (Sam).
# False
# Aire géogr. — Europe moyenne et méridionale, Turquie,
# False
#  Amanus.
# False
# HABROSIA
# False
#  Fenzl.
# False
#  — Plante annuelle, très petite, à faciès de
# False
#  Minuartia.
# False
# Calice à 5 sépales brièvement soudés à la base, longuement aristés, gibbeux à la
# False
# base de la partie dorsale. Pétales 5,
# False
#  ovés-spatulés.
# False
#  Étamines
# False
#  5 à filets très courts.
# False
# Styles 2, libres. Capsule indéhiscente. Graines globuleuses.
# False
# Habrosia spinuliflora
# Habrosia spinuliflora
# False
#  (Ser.)
# False
#  Fenzl —
# False
#  Arenaria
# False
#  spinuliflora
# False
#  Ser.
# False
#  (PI.
# False
#  CLV,
# False
#  n. 2).
# False
# — ®. Plante petite, 5-10 cm. Tige fine, glabre, rameuse, à rameaux dressés-étalés,
# False
# Rameaux fins, sétacés. Feuilles opposées, connées à la base, membraneuses, sétacées-
# False
# uninerviées. Pédicelles bien plus longs que le calice, à la fin étalés. Bractées briève-
# False
# ment lancéolées, herbacées, à marge membraneuse. Sépales du calice oblongs, ca-
# False
# rénés, uninerves, prolongés par une arête égale à leur longueur, le tout ne dépassant
# False
# pas 2 mm. Pétales blancs, 3 fois plus courts que les sépales.
# False
# Floraison: mars-avril. Régions subarides et arides.
# l ['mars-avril.', 'Régions', 'subarides', 'et', 'arides.']
# m ['mars', 'avril.']
# False
# L.
# False
#  Sy.
# False
#  Baalbeck (P, Mt).
# False
# S.
# False
#  Sy.
# False
#  Alep
# False
#  (Rousseau,
# False
#  Ky,
# False
#  Auch, Hkn, JL, Mt), Dana (P), Ouroum-es-Soughra à Terib
# False
# (Sam), Khan Cheikhoun à Ma'arrat-en-No'man (Sam), Jab. Sema'ane (Har).
# False
#  H.J.
# False
#  Jab. 'Abd-
# False
# el-'Aziz
# False
#  (Hd-Mz), bords du Tigre vers le Pont Romain (Mt).
# False
#  Dam.
# False
#  Jab. Qasyoun
# False
#  (Gaill,
# False
#  Sam, Pb).
# False
# A.L.
# False
#  Mnine à
# False
#  Saïdnaya
# False
#  (Sam), Ma'loula (Pb).
# False
#  St.
# False
#  Jab. Dmeir (Pb), Qaryatein (Mt), Sud de
# False
# Qaryatein (Pb),
# False
#  Palmyre
# False
#  (Mt), Jab.
# False
#  Bilas
# False
#  (Bl).
# False
# Aire géogr. — Mésopotamie, Kurdistan, Syrie, Liban, Aintab.
# False
# CORRIGIOLA L. — Herbes annuelles ou vivaces à feuilles un peu charnues
# description
# 12 19 0 0 CORRIGIOLA L. — Herbes annuelles ou vivaces à feuilles un peu charnues Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# et stipules scarieuses. Calice persistant, à 5 sépales obtus, à marge claire et mince.
# description
# 13 19 0 0 et stipules scarieuses. Calice persistant, à 5 sépales obtus, à marge claire et mince. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# 5 pétales arrondis égalant le calice. 5 étamines insérées sur la marge d'un disque très
# description
# 13 19 1 0 5 pétales arrondis égalant le calice. 5 étamines insérées sur la marge d'un disque très Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# petit. Styles 3, très courts. Fruit crustacé, inclus dans le calice.
# description
# 13 19 2 0 petit. Styles 3, très courts. Fruit crustacé, inclus dans le calice. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Gorrigiola
# Gorrigiola
# False
#  littoralis
# False
#  L.
# False
#  (PI.
# False
#  CLV, n. 3). —
# False
#  ©
# False
#  ou
# False
#  ¾.
# False
#  Plante verte ou
# False
# un peu glaucescente, pluricaule, de taille très variable. Tiges couchées, 10 à 40 cm.,
# False
# ténues ou relativement épaisses. Feuilles
# False
#  linéaires-lancéolées,
# False
#  pouvant atteindre
# False
# 3 cm., à stipules scarieuses, semi-sagittées, obtuses. Fleurs en corymbe dense, assez
# False
# longuement
# False
#  pédoncule,
# False
#  au sommet des tiges et des rameaux. Pédicelles plus courts
# False
# que la fleur, à bractée scarieuse hyaline. Sépales
# False
#  ovés-oblongs,
# False
#  très obtus, verts à
# False
# large bordure blanche ou
# False
#  blanc-rosé.
# False
#  Pétales blancs.
# False
# Floraison: mars-mai. Lieux sablonneux humides. Rare et fugace.
# l ['mars-mai.', 'Lieux', 'sablonneux', 'humides.', 'Rare', 'et', 'fugace.']
# m ['mars', 'mai.']
# False
# L.
# False
#  Ct.
# False
#  Beyrouth (Pr, Vt), Bouchriyé (Mt), sous Beit
# False
#  Méri
# False
#  (Np).
# False
# Aire géogr. — Europe, Afrique du Nord, Turquie, Liban, Palestine.
# False
# TELEPHIUM L. — Herbes un peu charnues, à feuilles alternes, stipulées.
# description
# 17 19 0 0 TELEPHIUM L. — Herbes un peu charnues, à feuilles alternes, stipulées. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Calice à 5 sépales. Corolle à 5 pétales, 5 étamines. 3 styles. Capsule à 3-4 valves.
# description
# 18 19 0 0 Calice à 5 sépales. Corolle à 5 pétales, 5 étamines. 3 styles. Capsule à 3-4 valves. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# NOUVELLE FLORE
# False
# 453
# False
# Telephium
# Telephium
# False
#  imperati L.,
# False
#  var.
# False
#  orientale
# False
#  Boiss.
# False
#  (PI.
# False
#  CLVI,
# False
#  n. 9). — Plante
# False
# un peu ligneuse au collet, mais à tiges toutes herbacées, couchées, allongées, pouvant
# False
# atteindre 40 cm. ou plus. Feuilles très brièvement stipulées, alternes (oblongues-
# False
# spatulées obtuses dans la
# False
#  forme-type,
# False
#  oblongues-lancéolées
# False
#  subaiguëes dans la var.).
# False
# Sépales
# False
#  oblongs-linéaires,
# False
#  obtus, un peu carénés, à marge membraneuse. Pétales
# False
# oblongs égalant les sépales. Capsule pyramidale, triangulaire au sommet, luisante,
# False
# brun-clair, dépassant (dans la var.) d'un tiers le calice.
# False
# Floraison:
# l []
# False
#  juin-juillet.
# ['juin-juillet.']
# m ['juin', 'juillet.']
# False
#  Montagnes sur
# ['Montagnes', 'sur']
# False
#  sols
# ['sols']
# False
#  fertiles.
# ['fertiles.']
# False
# L.
# False
#
# False
# Mm.
# False
#  Cèdres de Barouk
# False
#  (Mt),
# False
#  Jab. Barouk
# False
#  (Hartm,
# False
#  Np), Khan Sannine (Mt, Pb),
# False
#  Hadeth,
# False
# Hasroun
# False
#  (Bl),
# False
#  Cèdres
# False
#  (Bl,
# False
#  Pr, Sam, Mt, Pb).
# False
#  Me.
# False
#  'Ayyoun Ourgouch (Mt).
# False
#  Hem.
# False
#  Hermon
# False
#  (Gaill).
# False
# Aire géogr. — Var.
# False
#  orientale :
# False
#  Grèce, Crète, Turquie, Arménie, Iraq, Iran, Syrie, Liban. L'espèce;
# False
# Europe moyenne et méridionale, Afrique du Nord.
# False
# HERNIARIA L. — Herbes cespiteuses, annuelles ou vivaces, parfois sous-
# description
# 7 32 0 0 HERNIARIA L. — Herbes cespiteuses, annuelles ou vivaces, parfois sous- Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# frutescentes, à rameaux couchés et feuilles supérieures souvent alternes. Fleurs très
# description
# 8 32 0 0 frutescentes, à rameaux couchés et feuilles supérieures souvent alternes. Fleurs très Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# petites. Calice à 4 ou 5 sépales piano-concaves. Pétales filiformes. Étamines 5,4 ou
# description
# 8 32 1 0 petites. Calice à 4 ou 5 sépales piano-concaves. Pétales filiformes. Étamines 5,4 ou Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# 2. Styles 2, libres.
# description
# 8 32 2 0 2. Styles 2, libres. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Plantes à 5 sépales
# False
# Espèces annuelles
# False
# Calices glabres, très petits
# False
#
# False
# : ;
# False
# H.
# False
#  glabra
# False
#  L.
# False
# Calices hirsutes, mais à
# False
#  pilosité
# False
#  peu dense, ainsi que les feuilles
# False
# ;
# False
#
# False
# H. hirsuta
# False
#  L.
# False
# Calices et feuilles à pilosité dense
# False
# H. cinerea
# False
#  Lam.
# False
#  et D. C
# False
# Espèce vivace, à calices hirsutes, et tiges légèrement ligneuses à la base
# False
# H.
# False
#  incana
# False
#  Lam.
# False
# Plantes à 4 sépales, inégaux
# False
# Sépales très inégaux, les deux intérieurs 4 fois plus courts que les deux autres. Tige
# False
# peu lignifiée
# False
#
# False
# H.
# False
#  hemistemon
# False
#  J. Gay.
# False
# Sépales extérieurs plus larges, mais non plus longs que les intérieurs. Souche fortement
# False
# ligneuse
# False
#
# False
# H. arabica
# False
#  Hand.-Mazz.
# False
# Herniaria hirsuta
# Herniaria hirsuta
# False
#  L.
# False
#  (PI.
# False
#  CLV, n. 5). —
# False
#  ®.
# False
#  Tiges couchées, pouvant
# False
# atteindre 20 cm. ou plus, à rameaux souvent peu serrés, garnies de poils courts
# False
# ainsi que les feuilles, celles-ci souvent peu hispides à la face supérieure, ciliées à la
# False
# marge. Fleurs sessiles en têtes serrées, à l'aisselle des feuilles des ramules. Calices
# False
# à 5 sépales, couverts de poils courts, sauf à l'extrémité, munie d'une ou plusieurs
# False
# soies plus longues.
# False
# Floraison: mars-juin. Terrains vagues, pâturages. Moins abondante que
# l ['mars-juin.', 'Terrains', 'vagues,', 'pâturages.', 'Moins', 'abondante', 'que']
# m ['mars', 'juin.']
# False
#  H. cinerea,
# ['H.', 'cinerea,']
# False
#  sans être
# ['sans', 'être']
# False
# exceptionnellement rare.
# ['exceptionnellement', 'rare.']
# False
# L.
# False
#
# False
# Ct.
# False
#  Beyrouth et environs, notamment sables sous les Pins (Bl, Vt, P, Mt).
# False
#  Mi.
# False
#  Sous Beit
# False
# Méri
# False
#  (Mt).
# False
#  Mm.
# False
#  'Aïn Zehalta (P). . ' .
# False
# S.
# False
#
# False
# H.J.
# False
#  Vers le Pont Romain
# False
#  (Mt).
# False
# ;
# False
#  J.D.
# False
#  Tell Qpuleib (Mt).
# False
# Aire géogr. — Europe, Asie antérieure et centrale, Afrique du Nord et du
# False
#  Sud.
# False
# Herniaria cinerea
# Herniaria cinerea
# False
#  Lam. et D.C. —
# False
#  H. hirsuta
# False
#  L., var.
# False
#  cinerea
# False
#  (Lam. et D.C.)
# False
# Lor. et Bar.
# False
#  (PI.
# False
#  CLV, n. 4). —
# False
#  ©.
# False
#  Espèce ordinairement tenue aujourd'hui
# False
# comme non vraiment distincte
# False
#  de
# False
#  la précédente, qui, à en juger par les récoltes
# False
# libano-syriennes, s'en laisse cependant bien discerner, en colonies non mêlées. Plante
# False
# petite, 5-15 mm., à tiges couchées, entièrement recouverte, tiges et feuilles, de poils
# False
# 454
# False
# NOUVELLE FLORE
# False
# raides, donnant à l'ensemble une teinte cendrée. Feuilles
# False
#  oblongues-linéaires,
# False
#  sub-
# False
# aiguës. Fleurs à l'aisselle de toutes les paires de feuilles en glomérules de 7-10 fleurs
# False
# très serrées. Calice à 5 sépales, oblong, densément couvert sur toute sa surface de
# False
# poils de même longueur. Styles courts, distincts.
# False
# Floraison: mars-mai. Lieux
# l ['mars-mai.', 'Lieux']
# m ['mars', 'mai.']
# False
#  secs.
# ['secs.']
# False
# L.
# False
#  Ct.
# False
#  Beyrouth, rare (Vt,
# False
#  Bl,
# False
#  Mt), Saïda
# False
#  (Bl).
# False
#  Mi.
# False
#  Qrayé (Np).
# False
#  Met.
# False
#  'Anjar (Mt).
# False
# S.
# False
#  Sy.
# False
#  Chinchar-Qpsseir (Wall), entre Jebrine et Tiyara à l'est d'Alep (Hd-Mz),
# False
#  Alep
# False
#  (Hkn,
# False
# Mt, JL),
# False
#  Homs
# False
#  (P, Bl), Tell Bouada (Bl).
# False
#  Haur.
# False
#  Khabab (Mt), route de
# False
#  Qneitra
# False
#  (Pb).
# False
#  J.D.
# False
#  Soueida
# False
# (Mt), Kafer, Chahba (Pb).
# False
#  Dam.
# False
#  Kissoué (Mt), Damas
# False
#  (Gaill).
# False
#  A.L.
# False
#  Yabroud, Qprnet Mass'adi
# False
# (Pb).
# False
#  St.
# False
#  Dmeir
# False
#  (Pb),
# False
#  Jabal-el-Qprn
# False
#  (Dinsm),
# False
#  15 km. NW. de
# False
#  'Aïn-el-Beida
# False
#  (Sam), Forkhlos
# False
# (Wall), T 4,
# False
#  Qaryatein
# False
#  (Mt), Khanaser (P).
# False
# Aire géogr. — Canaries, tour de la Méditerranée, Asie antérieure.
# False
# Herniaria glabra L.
# Herniaria glabra L.
# False
#  ssp.
# False
#  microcarpos
# False
#  (Presl)
# False
#  Herm.
# False
#  —
# False
#  H. microcarpos
# False
#  Presl
# False
# (PI.
# False
#  CLV, n. 6). — (X). Plante glabre, sauf, occasionnellement, quelques poils
# False
# très peu nombreux à la marge de certaines feuilles. Tiges très rameuses, 5-15 cm.,
# False
# à ramules très courts. Fleurs sessiles en têtes serrées, à l'aisselle des feuilles des ramules.
# False
# Calices à 5 sépales glabres, ovales, non dépassés par les fruits. (La ssp.
# False
#  typica
# False
#  a des
# False
# ramules plus longs et des fruits dépassant le calice.)
# False
# Les spécimens libanais paraissent tous annuels, non pérennants.
# False
# Floraison: mars-juillet. Surtout
# l ['mars-juillet.', 'Surtout']
# m ['mars', 'juillet.']
# False
#  sols
# ['sols']
# False
#  peu calcaires en altitude.
# ['peu', 'calcaires', 'en', 'altitude.']
# False
# L.
# False
#  Ct.
# False
#  Beyrouth (Bl), Lit du Nahr Beyrouth (Mt), Tripoli (Bl).
# False
#  Mi.
# False
#  Rayfoun
# False
#  (Sam).
# False
#  Mm.
# False
# Au-dessus de Niha (P), Jab. Kneissé (Mt), Est du Col du Baidar (Pb), Mdeireje (Np), Hadeth,
# False
# Qannoubine, Ehden (Bl), Col de
# False
#  Zahlé
# False
#  (Pb),
# False
#  Me.
# False
#  Jab. Sannine (Pb).
# False
#  Met.
# False
#  Ta'naïl
# False
#  (Mt).
# False
# Aire géogr. — Ssp.
# False
#  microcarpos :
# False
#  Méditerranée, Asie antérieure. Ssp.
# False
#  typica :
# False
#  Europe surtout Nord,
# False
# Sibérie.
# False
# Herniaria incana
# Herniaria incana
# False
#  Lam. —
# False
#  H. macrocarpa
# False
#  Sibth. et Sm.,
# False
#  H.
# False
#  densiflora
# False
#  Williams
# False
# (PI.
# False
#  CLV, n. 7). —
# False
#  2|.
# False
#  Plante
# False
#  veloutée-canescente,
# False
#  à tiges dures et plus ou moins
# False
# ligneuses à la base, étalées au
# False
#  sol,
# False
#  longues, rameuses, pouvant atteindre 30 cm. de
# False
# long, vert clair ou un peu rougeâtres.
# False
#  Feuilles
# False
#  oblongues, canescentes ou vertes,
# False
# plus ou moins densément hispides, à poils courts. Stipules courtes, tronquées, connées
# False
# à la base des paires de feuilles. Fleurs en glomérules de 3-6, densément groupés sur
# False
# les dernières ramifications, en grappes un peu feuillées. Calice à 5 sépales oblongs-
# False
# ovales, hirsutes, un peu accrescents. Stigmates subsessiles.
# False
# Floraison:
# l []
# False
#  mai-juillet.
# ['mai-juillet.']
# m ['mai', 'juillet.']
# False
#  Pâturages, boisements dégradés, etc.
# ['Pâturages,', 'boisements', 'dégradés,', 'etc.']
# False
# L.
# False
#  Mi.
# False
#  Chemlan
# False
#  (P), entre Ghazir et Qala'at Fakhra (Vt).
# False
#  Mm.
# False
#  Dahr-el-Baidar
# False
#  (Wall),
# False
# Jab. Barouk (P), Jab. Kneissé (Np), Hadeth (Bl, Sam, Mt), Hasroun, Bcharré, Qannoubine, Afqa
# False
# (Bl), Cèdres (Pb), Ehden (Mt).
# False
#  Ve.
# False
#  Hazerta (Mt).
# False
#  Herm.
# False
#  Rachaya (Aar).
# False
# S.
# False
#  A.L.
# False
#  Anti-Liban entre Rachaya et Damas (Boiss).
# False
#  Herm.
# False
#  Mejdel-ech-Chams
# False
#  à Badr (Aar),
# False
# au-dessus de 'Arné (Pb).
# False
#  J.D.
# False
#  Chahba (Pb).
# False
# Aire géogr. — Europe méridionale, Afrique du Nord,
# False
#  Ethiopie,
# False
#  Asie antérieure.
# False
# Herniaria densiflora
# False
#  Williams. Ce binôme énigmatique a été créé à partir d'une
# False
#  Herniaria
# False
#  récoltée
# False
# par POST et conservée au British Museum. L'étiquette porte: «Plantae libanoticae 1877. N° 484.
# False
# Foot of Lebanon and Syrie ». Le spécimen lui-même ne diffère en rien de
# False
#  Herniaria incana
# False
#  telle
# False
# qu'on la récolte dans nos contrées.
# False
# Herniaria arabica
# Herniaria arabica
# False
#  Hand. - Mazz.
# False
#  (PI.
# False
#  CLV, n. 8). —
# False
#  S.
# False
#  Souche ligneuse,
# False
# assez épaisse. Base des tiges lignifiée, 10-40 cm., couchée ou ascendante. Feuilles
# False
# oblongues-elliptiques,
# False
#  courtes, très densément villeuses, à courtes stipules rougeâtres,
# False
# ciliées. Fleurs très densément serrées le long des ramules, en grappes presque nues.
# False
# '
# False
#
# False
# NOUVELLE FLORE
# False
# 455
# False
# Sépales
# False
#  ovales-orbiculaires,
# False
#  les deux extérieurs plus larges mais non ou à peine plus
# False
# longs que les intérieurs. 4 rudiments de pétales filiformes. 4 étamines à anthères
# False
# jaunâtres.
# False
# Floraison:
# l []
# False
#  avril-juin.
# ['avril-juin.']
# m ['avril', 'juin.']
# False
#  Déserts et salines.
# ['Déserts', 'et', 'salines.']
# False
# S.
# False
#  Dam.
# False
#  Bahret Hijjané (Pb).
# False
#  St.
# False
#  Qaryatein, Palmyre (Mt, Pb).
# False
# Aire géogr. — Iraq, désert de Syrie.
# False
# Espèce apparemment confondue par plusieurs avec
# False
#  hemistemon,
# False
#  seule mentionnée dans les Flores
# False
# précédentes. Elle rappelle
# False
#  fruticosa
# False
#  L. d'Espagne et
# False
#  fontanesii
# False
#  J. Gay de Méditerranée orientale et
# False
# d'Egypte.
# False
#  La description qu'en donne F. HERMANN — « Uebersicht
# False
#  iiber
# False
#  die Herniaria-Arten des
# False
# Berliner Herbars» (Fedde, Rep. XLIV, 1937), suivie par RECHINGER dans sa Flora
# False
#  of
# False
#  Lowland
# False
# Iraq, attribue à cette espèce des sépales internes moitié plus courts que les externes, ce
# False
#  qui
# False
#  e se vé-
# False
# rifie pas rigoureusement sur mes exemplaires de provenance syrienne.
# False
# Herniaria hemistemon
# Herniaria hemistemon
# False
#  J. Gay
# False
#  (PI.
# False
#  CLV, n. 9). —
# False
#  ¾,
# False
#  3. Base de la tige
# False
# légèrement lignifiée, mais racine d'ordinaire peu épaisse. Tige 5-20 cm., brièvement
# False
# veloutée, fragile, couchée, très rameuse. Feuilles oblongues, atténuées en pétioles, à
# False
# stipules pourprées. Fleurs sessiles, hermaphrodites, serrées en glomérules formant des
# False
# épis. Sépales très inégaux, les deux extérieurs herbacés, charnus, 4 fois plus longs que
# False
# les deux autres, ceux-ci membraneux. 2 étamines. 2 styles longs, libres dès la base.
# False
# Floraison:
# l []
# False
#  mai-juin.
# ['mai-juin.']
# m ['mai', 'juin.']
# False
#  Déserts.
# ['Déserts.']
# False
# S.
# False
#  St.
# False
#  Jab. Dmeir (Pb), Qaryatein (Pb, Mt), Jouaïf, Jouaïf à Arak, Nord de T 3 (Pb), 15 km.
# False
# NW. de 'Aïn Beida (Wall), Palmyre (Sam),
# False
#  Baghouse"(Du
# False
#  Mesnil du Buisson).
# False
# Aire géogr. — De Biskra au Golfe Persique.
# False
# PARONYCHIA Adanson. — Herbes à tiges couchées, à feuilles opposées, à
# description
# 8 27 1 0 PARONYCHIA Adanson. — Herbes à tiges couchées, à feuilles opposées, à Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# fleurs généralement noyées dans leurs bractées, celles-ci scarieuses et très amples.
# description
# 9 27 0 0 fleurs généralement noyées dans leurs bractées, celles-ci scarieuses et très amples. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Calice à 5 sépales
# description
# 9 27 1 0 Calice à 5 sépales Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
#  piano-concaves
# description
# 9 27 1 1  piano-concaves Font: 'Times-Roman' (serifed, proportional), size 11, color #000000
# False
#  ou cucullés au sommet. Pétales filiformes. Étamines
# description
# 9 27 1 2  ou cucullés au sommet. Pétales filiformes. Étamines Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# 5 ou 3, insérées à la gorge du calice.
# description
# 9 27 2 0 5 ou 3, insérées à la gorge du calice. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Plantes vivaces
# False
# Sépales non cucullés et aristés au sommet
# False
# Sépales égaux, oblongs, un peu concaves, obtus
# False
#
# False
# P. chionaea
# False
#  Boiss.
# False
# Sépales inégaux
# False
# Sépales oblongs-lancéolés, peu inégaux, courts, 2 mm. ou un peu plus. Feuilles
# False
# serrées et plus ou moins couvertes par les bractées. Têtes pauciflores, ou groupées
# False
# P.
# False
#  kurdica
# False
#  Boiss.
# False
# Sépales linéaires, 3-4 mm., un peu innerviés, inégaux. Feuilles en partie du
# False
# moins ovales et espacées. Têtes pluriflores, terminales
# False
# P. macrosepala
# False
#  Boiss.
# False
# Sépales cucullés au sommet, d'où part une arête droite, horizontale
# False
# P. argentea
# False
#  Lam.
# False
# Plantes annuelles
# False
# Bractées égalant ou dépassant les fleurs. Calice à sépales obovés et aristés
# False
# P. arabica
# False
#  (L.) D.C.
# False
# Bractées très réduites, ne cachant nullement les fleurs. Calice à sépales
# False
#  spatules
# False
#  et aristés
# False
# P. echinata
# False
#  Lam.
# False
# Paronychia chionaea
# Paronychia chionaea
# False
#  Boiss. —
# False
#  Par. capitala
# False
#  Koch, non L.
# False
#  (PI.
# False
#  CLVI,
# False
#  n. 1).
# False
# —
# False
#  ¾..
# False
#  Plante parfois
# False
#  sous-frutescente
# False
#  à la base. Rameaux couchés ou ascendants,
# False
# pouvant atteindre 15 cm. Feuilles ovales ou oblongues, d'ordinaire serrées, subca-
# False
# rénées, obtuses, à pubescence apprimée, à stipules hyalines égalant la feuille. Brac-
# False
# tées ovales, amples, aiguës ou obtuses, mucronulées. Sépales égaux, villeux, oblongs,
# False
# obtus, un peu concaves.
# False
# 456
# False
# NOUVELLE FLORE
# False
# Floraison: juin-juillet. Lieux boisés.
# l ['juin-juillet.', 'Lieux', 'boisés.']
# m ['juin', 'juillet.']
# False
# S.
# False
#  Mm.
# False
#  Slenfé (JL, Pb, Mt), Col de Nébi Younès (Sam).
# False
#  NLatt.
# False
#  'Aïn
# False
#  Haramiyé
# False
#  (Mt).
# False
# Aire
# False
#  géogr.
# False
#  — Turquie,
# False
#  Amanus.
# False
# Paronychia kurdica
# Paronychia kurdica
# False
#  Boiss.
# False
#  (PL
# False
#  CLVI,
# False
#  n. 2). —
# False
#  2j_.
# False
#  Base souvent durcie.
# False
# Tiges de 5 à 10 cm. Rameaux tomenteux, couchés ou ascendants. Feuilles
# False
#  tomen-
# False
# teuses, oblongues-linéaires, obtuses. Bractées amples, oblongues ou ovales, acumi-
# False
# nées, à base souvent oblique. Calice à sépales courts, oblongs-lancéolés,
# False
#  hispides,
# False
# 2 mm., ou un peu plus. Têtes
# False
#  pauciflores,
# False
#  nombreuses, non groupées.
# False
# Floraison : mars-juin. Rochers et terrains pierreux.
# False
# S.
# False
#  Sy.
# False
#  Alep
# False
#  (Hkn, Mt), Khirbet
# False
#  Farès
# False
#  (Mt), Khan
# False
#  'Assal
# False
#  (Wall), Ouroum-es-Soughra à
# False
# Terib, Khan Cheikhoun à Ma'arat-en-No'man (Sam), Eriha (Pb).
# False
#  St.
# False
#  Qaryatein (Mt), Jab. Dmeir
# False
# (Pb), Jab. Abiad
# False
#  (Bl).
# False
#  A.L.
# False
#  Jab.
# False
#  Halimé
# False
#  (Pb),
# False
#  Mnine-Saïdnaya
# False
#  (Sam), Yabroud (Mt, Pb),
# False
# Ma'loula (Pb).
# False
#  H.J.
# False
#  Ghara (Hd-Mz), Jab.
# False
#  'Abd-el-'Aziz
# False
#  (Mt).
# False
# Aire géogr. — Arménie, Kurdistan, Géorgie, Iraq, Iran, Syrie.
# False
# Paronychia
# Paronychia
# False
#  macrosepala
# False
#  Boiss. (PL CLVI, n. 3). —
# False
#  2J..
# False
#  Plante pubes-
# False
# cente, à rameaux ascendants, plus ou moins densément
# False
#  feuilles,
# False
#  à feuilles oblongues-
# False
# obtuses. Bractées ovales, à base oblique, acuminées. Calices à pubescence apprimée,
# False
# à sépales lancéolés-linéaires, faiblement mais nettement innervés, 3-4 mm., émer-
# False
# geant parfois au-dessus des bractées. Têtes
# False
#  multiflores,
# False
#  fortement groupées.
# False
# Floraison: mai-juin. Rochers et lieux pierreux.
# l ['mai-juin.', 'Rochers', 'et', 'lieux', 'pierreux.']
# m ['mai', 'juin.']
# False
# L.
# False
#  Ct.
# False
#  Beyrouth, avril 1884 (P).
# False
#  Ct. ou ML?
# False
#  De
# False
#  Buachi
# False
#  à Haïrouna, vers Tripoli, 1880 (Bl).
# False
# S.
# False
#  Dam.
# False
#  Jab. Qasyoun
# False
#  (Bnm,
# False
#  Mt), Berzé
# False
#  (Mt).
# False
#  St.
# False
#  Palmyre (Mt).
# False
# Aire géogr. — Méditerranée orientale, Asie
# False
#  antérieure.
# False
# Selon A.
# False
#  O.
# False
#  Chater (Flora europaea I, p. 150), cette espèce ne serait pas clairement discernable
# False
# de
# False
#  P. capitala
# False
#  (L.)
# False
#  Lam.
# False
# Paronychia argentea
# Paronychia argentea
# False
#  Lam. —
# False
#  Illecebrum paronychia
# False
#  L. (PL CLVI, n. 4).
# False
#  —-
# False
# 21. Tiges couchées, pouvant atteindre 50 cm., glabres ainsi que les feuilles, celles-ci
# False
# parfois pourvues de
# False
#
# False
# ipules
# False
#  très
# False
#  développées^
# False
#  scarieuses, les dépassant presque
# False
# (var.
# False
#  scariosissima
# False
#  Post),
# False
#  obovées-oblongues,
# False
#  aiguës. Capitules très denses, latéraux
# False
# et
# False
#  terminaux.
# False
#  Bractées ovales-aiguës, beaucoup plus longues que les fleurs. Calices
# False
# à sépales courts, scarieux à la marge, cucullés au sommet d'où part une arête droite,
# False
# souvent au moins horizontale.
# False
# Floraison : mars-mai. Terrains divers, fréquente.
# False
#  ;
# False
# L.
# False
#  Ct.
# False
#  Saïda (Bl), Beyrouth et environs (Vt, P, Mt), Tripoli (Bl, Pb).
# False
#  Mi.
# False
#  'Abey (P), Ghazir
# False
# (Vt), Broummana (Leatherdale), Rayfoun (Sam). Douma (P).
# False
#  Mm.
# False
#  Cèdres de Hadeth, Qannou-
# False
# bine, Roueissat (Bl).
# False
#  'Akkar.
# False
#  Tlail
# False
#  (Pb).
# False
#  Sud.
# False
#  Qala'at ech-Chekif (Pb), Marjayyoun (Mt).
# False
#  Met.
# False
# Chtaura (P), Qabbélias (Bl),
# False
#  Zahlé
# False
#  (Vt), N. de Rayak (Mt).
# False
#  Hem.
# False
#  Fraïdiss, vers Hasbaya (Mt).
# False
# S.
# False
#  Ct.
# False
#  Tartous (Pb).
# False
#  Mi.
# False
#  Bhamra (Har).
# False
#  NLatt.
# False
#  Kessab (Pb).
# False
#  Sy.
# False
#  Alep (Hkn), 'Afrine (Har),
# False
# Horns (P, Pb), Hama (Har).
# False
#  Dam.
# False
#  Jab. Qasyoun (Pb),
# False
#  Sahl-es-Sahra
# False
#  (Wall).
# False
#  St.
# False
#  Hassiyé (Pb).
# False
# Aire géogr. — Tour de la Méditerranée.
# False
# Paronychia arabica
# Paronychia arabica
# False
#  (L.) D.C. —
# False
#  Illecebrum arabicum
# False
#  L. (PL CLVI, n. 5).
# False
# — 2). Plante pubérulente, à tiges couchées, lâchement feuillées, pouvant atteindre
# False
# 25 cm. Feuilles oblongues-linéaires, glabres ou un peu ciliées, mucronées-aristées,
# False
# à stipules membraneuses, hyalines. Têtes nombreuses, pauciflores, latérales et ter-
# False
# minales. Bractées
# False
#  oblongues-lancéolées,
# False
#  acuminées, égalant ou dépassant les fleurs.
# False
# Calices à tube poilu, à sépales obovés, scarieux-marginés, terminés par une arête
# False
# égale à leur longueur.
# False
# y
# False
#  •
# False
# NOUVELLE FLORE
# False
# 457
# False
# Floraison: printemps. Rochers.
# l ['printemps.', 'Rochers.']
# False
# S.
# False
#  Dam.
# False
#  Jab. Qasyoun (Sam).
# False
#  J.D.
# False
#  Tell Chihane (Mt).
# False
# Aire géogr. —
# False
#  Egypte,
# False
#  Palestine,
# False
#  Iraq.
# False
# Paronychia echinata
# Paronychia echinata
# False
#  Lam.
# False
#  (PI.
# False
#  CLVI,
# False
#  n. 6). — ®. Plante rameuse, cou-
# False
# chée ou ascendante, atteignant à peine 10 cm. Tige, rameaux et feuilles brièvement
# False
# pubescents,
# False
#  jaune-verdâtre,
# False
#  parfois lavés de pourpre. Stipules et bractées hyalines,
# False
# mais très courtes. Feuilles
# False
#  ovale-elliptiques,
# False
#  3-6 mm. de long. Calice nullement
# False
# caché par les bractées, à tube un peu poilu à la base, vert ou pourpré, à sépales
# False
# spatules
# False
#  longuement prolongés en une arête triangulaire à la base, membraneuse,
# False
# étalée.
# False
# Floraison: février-mai. Grès humides.
# l ['février-mai.', 'Grès', 'humides.']
# m ['février', 'mai.']
# False
# L.
# False
#  Mi.
# False
#  Sous Beit
# False
#  Méri
# False
#  (Pr, Vt, Mt, Np), Qrayé (Np).
# False
#  Mm.
# False
#  'Aïn Zehalta
# False
#  (Bnm).
# False
# Aire géogr. — Ile Madère, Canaries, Afrique du Nord, Espagne, France et Italie méridionale,
# False
# Corse, Crète, Ile de Mélos.
# False
# POLYCARPON
# False
#  L. — Herbes ou sous-arbrisseaux à calice pentamère, pourvu
# False
# de sépales carénés, étroitement
# False
#  scârieux
# False
#  à la marge,
# False
#  cucullés
# False
#  à l'apex. Pétales 5,
# False
# obovés ou oblongs. Étamines 3-5, insérées sur le disque autour du périgyne. Capsule
# False
# à 3 valves. Graines courbées au dos, rectilignes à la face ventrale.
# False
# Feuilles ovales, peu ou pas charnues, stipules
# False
#  acuminées
# False
#  et sépales mucronés. Habitat étendu
# False
# P. tetraphyllum
# False
#  L.
# False
# Feuilles ovales à linéaires, charnues. Stipules non acuminées. Sépales obtus, un peu cucullés.
# False
# Sables littoraux
# False
# P.
# False
#  succulentum
# False
#  (Del.) J. Gay.
# False
# Polycarpon tetraphyllum
# Polycarpon tetraphyllum
# False
#  L.
# False
#  (PI.
# False
#  CLVI, n. 7). — ®. Plante glabre, à
# False
# tiges diffuses, très rameuses, ramifiées à plusieurs reprises, pouvant atteindre 20 cm.
# False
# Feuilles caulinaires par 4, inégales, celles des rameaux opposées, par 2, spatulées, de
# False
# dimensions très variables, à stipules scarieuses longuement acuminées. Fleurs en
# False
# cymes, tantôt serrées, tantôt espacées. Bractées scarieuses, aiguës. Calice à 5 sépales
# False
# ovales, mucronés. Étamines 3. Pétales blancs,
# False
#
# False
# à des
# False
#  sépales. Graines tuberculées.
# False
# Faciès très variable suivant les habitats. Les milieux rudéraux fournissent des
# False
# pieds d'un vert foncé, à partie végétative bien développée. Ailleurs à la côte, la
# False
# couleur des feuilles est plus
# False
#  claire
# False
#  et l'inflorescence plus serrée. En altitude, la
# False
# plante, plus réduite, n'a que des tiges et des feuilles très courtes, et n'est plus guère
# False
# qu'une inflorescence aplatie au
# False
#  sol.
# False
# Floraison: février à septembre suivant l'altitude. Rochers littoraux à montagnes, croissant en
# l ['février', 'à', 'septembre', 'suivant', "l'altitude.", 'Rochers', 'littoraux', 'à', 'montagnes,', 'croissant', 'en']
# False
# terrains vagues comme dans les boisements. Très commune.
# ['terrains', 'vagues', 'comme', 'dans', 'les', 'boisements.', 'Très', 'commune.']
# False
# L.
# False
#  Ct.
# False
#  Saïda (Mt), Beyrouth
# False
#  (Bl,
# False
#  Vt,
# False
#  P,
# False
#  Np, Mt, Pb), Tripoli (Bl, P), Ras Jedra (Sam).
# False
# Mi.
# False
#  Sous Beit Méri (Mt),
# False
#  Bzoummar
# False
#  (Bl).
# False
#  Mm.
# False
#  Col de
# False
#  Zahlé
# False
#  (Mt), 'Aïn Sindiané (Bl).
# False
# S.
# False
#  Mi.
# False
#  Bhamra, 'Aïn Halakim (Har).
# False
#  Sud.
# False
#  Hammé
# False
#  (Pb).
# False
#  Dam.
# False
#  Damas (Pb).
# False
# Aire géogr. — Subcosmique.
# False
# Polycarpon alsinifolium
# False
#  (Biv.) D.C. — Se distingue de la précédente par une
# False
# taille plus grande, et des étamines au nombre de 5. Espèce croissant sur les bords
# False
# de la Méditerranée, surtout,
# False
#  semble-t-il,
# False
#  en Occident. Signalée en
# False
#  Egypte,
# False
#  elle y
# False
# serait rare. Il ne semble pas qu'elle ait été trouvée jusqu'ici sur la côte libanaise
# False
# et syrienne.
# False
# 458
# False
# NOUVELLE FLORE
# False
# Polycarpon
# False
#  succulentum
# False
#  (Del.) J. Gay. —•
# False
#  Alsine succulenta
# False
#  J. Gay
# False
#  (PI.
# False
# CLVJ, n. 8). —
# False
#  ©.
# False
#  Tiges couchées, 5-10 cm. de long, rameuses. Feuilles par 4
# False
# ou opposées, à stipules entièrement scarieuses, aiguës mais non longuement acumi-
# False
# nées, oblongues ou linéaires, un peu charnues. Inflorescence tantôt lâche, tantôt
# False
# dense, à bractées scarieuses, aiguës. Calice à 5 sépales un peu charnus, obtus, légè-
# False
# rement cucullés. Pétales blancs
# False
#  égalant
# False
#  les sépales. 5 étamines.
# False
# Floraison: janvier-mars. Sables littoraux.
# l ['janvier-mars.', 'Sables', 'littoraux.']
# m ['janvier', 'mars.']
# False
# L.
# False
#  Ctlitt.
# False
#  Sables au sud de Beyrouth
# False
#  (Bl,
# False
#  Vt, Mt, Np, Sam, Pb), Khaldé (P).
# False
# Aire géogr. —
# False
#  Egypte,
# False
#  Palestine, Liban.
# False
# ROBBAIREA Boiss. — Herbes ressemblant aux
# description
# 3 23 3 0 ROBBAIREA Boiss. — Herbes ressemblant aux Font: 'Times-Roman' (serifed, proportional), size 10.8539, color #000000
# False
#  Polycarpon,
# description
# 3 23 3 1  Polycarpon, Font: 'Times-Italic' (italic, serifed, proportional), size 10.8539, color #000000
# False
#  à calice de 5 sé-
# description
# 3 23 3 2  à calice de 5 sé- Font: 'Times-Roman' (serifed, proportional), size 10.8539, color #000000
# False
# pales piano-concaves, étroitement scarieux à la marge, à 5 pétales onguiculés.
# description
# 4 23 0 0 pales piano-concaves, étroitement scarieux à la marge, à 5 pétales onguiculés. Font: 'Times-Roman' (serifed, proportional), size 10.8539, color #000000
# False
# 5 étamines soudées en anneau autour du périgyne. Capsule trivalve.
# False
# Robbairea delileana
# False
#  Milne-Redh.
# False
#  —
# False
#  R. prostrata
# False
#  (Forsk.) Boiss. pr. p.
# False
# (PI.
# False
#  CLV,
# False
#  n. 10). —• ®,
# False
#  2J..
# False
#  Plante glabre, à nombreuses tiges filiformes, couchées,
# False
# ramassées-dressées, 10-30 cm. Feuilles oblongues ou linéaires, étroites, souvent
# False
# fanées à la fin de l'anthèse. Stipules et bractées scarieuses, mais herbacées à la base
# False
# et sur une bande médiane étroite, courtes,
# False
#  triangulaires.
# False
#  Fleurs en
# False
#  cymes
# False
#  générale-
# False
# ment assez lâches, fastigiés. Sépales glabres, très obtus. Pétales
# False
#  roses,
# False
#  égalant les
# False
# sépales.
# False
# Var.
# False
#  major
# False
#  (Asch. et Schw.) V. Tâckh. — Vivace à rameaux de 10-30 cm.
# False
# Var.
# False
#  minor
# False
#  (Asch. et Schw.) V.
# False
#  Tăckh.
# False
#  — Annuelle
# False
#  à rameaux de 3-10 cm.
# False
# Floraison: mars-mai. Régions arides.
# l ['mars-mai.', 'Régions', 'arides.']
# m ['mars', 'mai.']
# False
# S.
# False
#  St.
# False
#  Zélaf
# False
#  (Pb). Spécimen à inflorescence relativement dense, paraissant provenir d'un pied
# False
# annuel.
# False
# Aire géogr. — Afrique du Nord,
# False
#  Egypte,
# False
#  Nubie, Palestine sud, Jordanie, Iraq.
# False
# SPERGULARIA (Pers.) J. et C.
# False
#  Presl
# False
#  —
# False
#  Arenaria
# False
#  sect.
# False
#  Spergularia
# False
#  Pers. —
# False
# Plantes annuelles ou vivaces, à feuilles opposées, filiformes,
# False
#  urî
# False
#  peu charnues, stipulées,
# False
# à pédicelles fructifères réfractés. 5 sépales scarieux à la marge. 5 pétales entiers,
# False
# roses,
# False
#  insérés au bas du calice. Étamines 2-3 ou 5-10 insérées sur un anneau du
# False
# périgyne. Capsule à 3 valves, rarement 5. Graines piriformes ou lenticulaires, mar-
# False
# ginées ou aptères.
# False
# Genre de classement rendu difficile par l'affintité des espèces et plus encore par
# False
# le passé confus de leur nomenclature.
# False
# Plante nettement pérennante, à racine épaisse, tiges charnues, rougeâtres, capsule dépassant
# False
# beaucoup le calice, et graines lenticulaires, toutes ailées
# False
# S. media
# False
#  (L.) Presl.
# False
# Plante rappelant la précédente, moins forte, moins charnue, souvent annuelle, à capsule dépas-
# False
# sant peu le calice, et graines ordinairement les unes aptères, les autres ailées, lenticulées, rare-
# False
# ment toutes aptères
# False
# S.
# False
#  marina
# False
#  (L.)
# False
#  Griseb.
# False
# Plantes à graines toutes aptères, à capsules ne dépassant guère le calice. Calice court, 2-3 mm.
# False
# Inflorescence feuillée, souvent glanduleuse. Pédicelles plus courts que la capsule. Graine
# False
# piriforme, lisse. Étamines 7-10
# False
# S. bocconii
# False
#  (Sol.
# False
#  es Scheele)
# False
#  Fouc.
# False
#  ex Mer.
# False
# Inflorescence nue au sommet, à fleurs plus petites. Feuilles fines, peu charnues. Pédicelles
# False
# bien plus longs que les capsules. Étamines 2, parfois 3.
# False
# S. diandra
# False
#  Guss.
# False
# NOUVELLE FLORE
# False
# 459
# False
# Spergularia diandra
# False
#  (Guss.) Boiss. —
# False
#  Arenaria diandra
# False
#  Guss.,
# False
#  Arenaria salsuginea
# False
# Bunge'(CLVII,
# False
#  n. 1). —
# False
#  ®.
# False
#  Plante ordinairement glabre, sauf quelques feuilles
# False
# glanduleuses vers le sommet, à tiges dressées ou ascendantes, 10-15 cm. de haut.
# False
# Feuilles
# False
#  filiformes,
# False
#  minces, mucronées, un peu charnues. Stipules scarieuses, trian-
# False
# gulaires. Cymes non feuillées, à pédicelles filiformes, minces, glabres ou glanduleux,
# False
# généralement beaucoup plus longs que le calice. Bractées courtes, à carène ordinai-
# False
# rement herbacée. Étamines 2, parfois 3. Graines obovées-triangulaires, noires à
# False
# maturité, lisses ou verruqueuses.
# False
# Floraison:
# l []
# False
#  février-mai.
# ['février-mai.']
# m ['février', 'mai.']
# False
#  Régions sèches.
# ['Régions', 'sèches.']
# False
# S.
# False
#  Sy.
# False
#  Alep
# False
#  (Hkn), Sebkhat
# False
#  Halab
# False
#  (P), Khan Chair (Wall).
# False
#  Dam.
# False
#  Jab. Qasyoun (Mt),
# False
# Ghoslaniyé
# False
#  (Dlb,
# False
#  Pb).
# False
#  H.J.
# False
#  'Aïn Safra à
# False
#  PW.
# False
#  de
# False
#  Ras-el-'Aïn,
# False
#  Hassetché (Mt), entre Tibné et Deir-
# False
# ez-Zor (Hd-Mz).
# False
#  Haur.
# False
#  Dera'a (Mt).
# False
#  St.
# False
#  Meskène (Wall), Reddé (Mt), Abou Hareira (Hd-Mz),
# False
# 15 km. N. de 'Aïn Beida (Sam), Qaryatein (Mt, Pb), 'Adra (Hafstr),
# False
#  Dmeir
# False
#  (Pb), Tell Bouada (Bl),
# False
# Palmyre (Bl, P, Sam, Mt, Pb).
# False
# Aire géogr. — Espagne, France
# False
#  mér.,
# False
#  Sicile, Afrique du Nord,
# False
#  Egypte,
# False
#  Ethiopie,
# False
#  Palestine et
# False
# TransJordanie,
# False
#  Iraq, Caucase, Iran, Afghanistan, Turquie.
# False
# Spergularia media
# False
#  (L.) C.
# False
#  Presl
# False
#  —
# False
#  A. media
# False
#  L.,
# False
#  Sp. marginala
# False
#  (D.C.) Kitt.,
# False
# A. marginata
# False
#  D.C.,
# False
#  Spergula
# False
#  marginata
# False
#  (D.C.)
# False
#  Murb.
# False
#  (PI.
# False
#  CLVII,
# False
#  n. 3). —
# False
#  2J..
# False
#  Racine
# False
# épaisse. Tiges couchées ou ascendantes, 10-25 cm. de long, glabres ou légèrement
# False
# glanduleuses-pubescentes, charnues, rougeâtres. Stipules courtes, triangulaires,
# False
# entièrement scarieuses. Feuilles un peu charnues, linéaires, atteignant 3 cm. de long.
# False
# Cymes axillaires ou terminales, feuillées, un peu lâches. Calice un peu charnu à
# False
# sépales largement scarieux, 5-6 mm. de long. Pétales égalant le calice. Étamines 5-10.
# False
# Capsule 10 mm., dépassant beaucoup le calice. Graines lenticulaires, toutes ailées.
# False
# Floraison: mars-mai. Halophile.
# l ['mars-mai.', 'Halophile.']
# m ['mars', 'mai.']
# False
# L.
# False
#  Ctlitt.
# False
#  Beyrouth, autrefois, sur le bord de la mer (Bl, Mt).
# False
# S.
# False
#  Dam.
# False
#  Lagunes salées à l'est de la Ghouta (P, Pb, Lys).
# False
# Aire géogr. — Subcosmique.
# False
# Spergularia marina
# False
#  (L.) Griseb. —
# False
#  Arenaria rubra
# False
#  L., var.
# False
#  marina
# False
#  L., Sp.
# False
# salina
# False
#  J. et C. Presl, Sp.
# False
#  media
# False
#  (Wahl.)
# False
#  Boiss., non
# False
#  media
# False
#  (L.) C. Presl.
# False
#  (PI.
# False
#  CLVII,
# False
# n. 4). —
# False
#  ©,
# False
#  2J..
# False
#  Racines plus ou moins ligneuses. Tiges couchées ou ascendantes,
# False
# glabres ou pubescentes-papilleuses à la base, glanduleuses au sommet, d'épaisseur
# False
# variable, mais toujours moins fortes que dans l'espèce précédente, 10-20 cm. de
# False
# long. Stipules et feuilles comme dans l'espèce précédente. Inflorescence surtout ter-
# False
# minale, en grappes mêlées de feuilles très courtes, plus ou moins denses. Calice 3-
# False
# 5 mm. Capsule 6-7 mm. dépassant légèrement le calice. Graines lisses, obovales,
# False
# comprimées, la plupart, très rarement toutes, aptères, quelques-unes, parfois un
# False
# grand nombre, ailées (var.
# False
#  heterosperma
# False
#  Fenzl).
# False
# Espèce polymorphe, toujours reconnaissable à ses graines lenticulaires, presque
# False
# toujours dimorphes.
# False
# Floraison: mars-mai. Moins halophile que la précédente.
# l ['mars-mai.', 'Moins', 'halophile', 'que', 'la', 'précédente.']
# m ['mars', 'mai.']
# False
# Forme sans graines ailées:
# ['Forme', 'sans', 'graines', 'ailées:']
# False
# S.
# False
#  H.J.
# False
#  Lac Khatouniyé (Mt, Pb).
# False
#  St.
# False
#  Source d'Arak (Pb).
# False
# Forme à graines ailées:
# False
# L.
# False
#  Ctlitt.
# False
#  Tyr (Mt, Pb), Beyrouth (P, Mt, Np).
# False
#  Sud.
# False
#  Şarada
# False
#  (P).
# False
# S.
# False
#  A.L.
# False
#  Bloudane (P).
# False
#  Sy.
# False
#  Lac
# False
#  Jabboul (Mt).
# False
#  Dam.
# False
#  Damas (Pb).
# False
#  St.
# False
#  Qaryatein (P, Mt),
# False
# Palmyre (Mt), Meyyadine à Salihiyé (Hd-Mz).
# False
#  Haur.
# False
#  Mzerib (Mt).
# False
# Aire géogr. — Europe, Sibérie, Méditerrané, Asie antérieure.
# False
# 460
# False
# NOUVELLE FLORE
# False
# Spergularia
# False
#  bocconii
# False
#  (Sol.
# False
#  ex Scheele)
# False
#  FouC.
# False
#  ex Mer. —
# False
#  Arenaria
# False
#  bocconii
# False
#  Soleirol
# False
# 1825, Sp.
# False
#  rubra
# False
#  L., var.
# False
#  atheniensis
# False
#  Heldr.
# False
#  et
# False
#  Sart.,
# False
#  Sp.
# False
#  atheniensis
# False
#  (Heldr.
# False
#  et Sart.)
# False
# Asch. et Schw. (PL
# False
#  CLVII,
# False
#  n. 2). — ®,
# False
#  ¾..
# False
#  Plante glabre ou quelque peu pubes-
# False
# cente-glanduleuse
# False
#  dans l'inflorescence. Tige très rameuse, en général relativement
# False
# fine, jusqu'à 20 cm. Stipules courtes, triangulaires, non acuminées ou laciniées au
# False
# sommet. Feuilles linéaires glabres. Inflorescence généralement serrée, à pédicelles
# False
# plus courts que la capsule, feuillée. Graines piriformes brunes, toujours lisses.
# False
# Floraison: janvier-mai. Terrains vagues.
# l ['janvier-mai.', 'Terrains', 'vagues.']
# m ['janvier', 'mai.']
# False
# L.
# False
#  Ct.
# False
#  Tyr (Mt, Pb), Aouza'i (Pb), Beyrouth (P, Vt, Mt, Np, Pb),
# False
#  Nahr-el-Kelb
# False
#  (Mt, Pb),
# False
# Enfé (Pb), Tripoli
# False
#  (Bl).
# False
#  Mi.
# False
#  Kfar
# False
#  Chima
# False
#  (Mt, Pb).
# False
#  'Akkàr.
# False
#  Mengès (Mt).
# False
# S.
# False
#  Dam.
# False
#  Damas
# False
#  (Bl,
# False
#  Pb).
# False
#  Ctlitt.
# False
#  Ram Laha
# False
#  (Mt).
# False
#  H.J.
# False
#  40 km. sud de Cheddadé (Pb).
# False
# Sud.
# False
#  Hammé
# False
#  (Pb).
# False
# Aire géogr. — Subcosmique.
# False
# SPERGULA L. — Herbes annuelles à feuilles filiformes très fines, fasciculées
# description
# 8 22 0 0 SPERGULA L. — Herbes annuelles à feuilles filiformes très fines, fasciculées Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# en pseudo-verticilles brièvement stipités. Calice à 5 sépales un peu charnus, 5 pétales
# description
# 9 22 0 0 en pseudo-verticilles brièvement stipités. Calice à 5 sépales un peu charnus, 5 pétales Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# entiers, 5-10 étamines. Graines lenticulaires, marginées ou ailées.
# description
# 9 22 1 0 entiers, 5-10 étamines. Graines lenticulaires, marginées ou ailées. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Graine subglobuleuse, à marge un peu dilatée. 5 styles
# False
# S. arvensis
# False
#  L.
# False
# Graine largement ailée. 3 styles
# False
# S.fallax
# False
#  (Lowe) E.H.L. Krause.
# False
# Spergula arvensis
# Spergula arvensis
# False
#  L.
# False
#  (PI.
# False
#  CLVII, n. 5). — ©. Tiges couchées ou ascen-
# False
# dantes, peu rigides, longues de 10 à 30 cm. ou plus, légèrement papilleuses. Feuilles
# False
# molles, creusées d'un sillon dans leur longueur, fasciculées en grand nombre, vingt
# False
# ou plus, pubescentes, à très petites stipules.
# False
#  Cymes
# False
#  lâches, portés par de longs pédon-
# False
# cules pubescents, au sommet des tiges et des rameaux. Calice à sépales ovales-
# False
# oblongs, obtus. Pétales blancs, ovales, obtus, un peu plus courts ou un peu plus
# False
# longs que les sépales, finement plurinerviés, glabres. Étamines 5-10, égalant
# False
#  \
# False
#  des
# False
# pétales. Styles 5, courts et
# False
#  récurvés.
# False
#  Capsule ovoïde, jaunâtre, dépassant le calice,
# False
# à 5 valves entières. Graines subglobuleuses, noirâtres, ceintes d'une carène très
# False
# saillante, formant souvent une aile très étroite, couvertes de papilles claviformes.
# False
# Floraison: janvier-avril. Sables et grès humides.
# l ['janvier-avril.', 'Sables', 'et', 'grès', 'humides.']
# m ['janvier', 'avril.']
# False
# L.
# False
#  Ct.
# False
#  Sables de Beyrouth (Bl, Vt), Tripoli (P,
# False
#  Bl).
# False
#  Mi.
# False
#  Bouchriyé (Mt), sous Beit
# False
#  Méri
# False
#  (P),
# False
# 'Aïn Besabba (Mt), Bikfaya (Bl),
# False
#  Broummana
# False
#  (Mt).
# False
#  Met.
# False
#  Ebel-es-Saki
# False
#  (P).
# False
# Aire géogr. — Subcosmique.
# False
# Spergula fallax
# Spergula fallax
# False
#  (Lowe) E.H. Krause
# False
#  —
# False
#  S.fiaccida
# False
#  (Roxb.) Asch.
# False
#  (PI.
# False
#  CLVII,
# False
# n. 6). —
# False
#  Q.
# False
#  Plante glaucescente, glabre. Tige couchée ou ascendante, 10-15 cm.
# False
# Feuilles non sillonnées, fasciculées par 10 ou moins, à stipules très réduites. Cymes
# False
# à pédoncules et pédicelles glabres, lisses, assez lâches. Sépales glabres, verts, à marge
# False
# ...
# False
#  Egypte,
# False
#  Asie antérieure jusqu'à l'Inde.
# False
# NOUVELLE FLORE
# False
# 461
# False
# Sous-famille des ALSINOIDEAE
# False
# Feuille habituellement sans stipules. Sépales libres. Corolle presque toujours
# False
# présente.
# False
# BUFFONIA
# False
#  L. — Herbes annuelles ou vivaces, d'aspect jonciforme, parfois
# False
# sous-frutescentes
# False
#  à la base, à feuilles subulées, dilatées à la base, connées, serrées
# False
# sur le rameau, à fleurs en cymes spiciformes ou paniculées. Calice scarieux, de 4
# False
# sépales à marge membraneuse, à pétales entiers ou bidentés, 4 ou 8 étamines insérées
# False
# sur le disque périgyne, parfois glandulifères. Styles 2. Ovaire à 2-4-10 ovules. Cap-
# False
# sule lenticulaire, bivalve. Graines ordinairement 2, ayant souvent à la base la forme
# False
# d'un fer à cheval.
# False
# Plante annuelle, à tige fine, et cymes très étroitement dressées. Graine fortement tuberculée
# False
# B.
# False
#  paniculate
# False
#  Dubois.
# False
# Plante vivace, glaucescente. Graine lisse ou presque
# False
# B. ephedrina
# False
#  Sam.
# False
# Buffonia
# Buffonia
# False
#  paniculata
# False
#  Dubois —
# False
#  B.
# False
#  macrosperma
# False
#  J. Gay,
# False
#  B. tenuifolia
# False
#  Vill.,
# False
# non L.
# False
#  (PI.
# False
#  CLVIII, n. 1). —
# False
#  ©.
# False
#  Tiges rigides, 20-40 cm. ou plus, isolées ou fas-
# False
# ciculées au collet, simples ou parfois pourvues d'un ou deux rameaux dressés, courts,
# False
# rigides, pubérulents ou glabres. Feuilles connées à la base en une courte gaine mem-
# False
# braneuse, filiformes-subulées, apprimées le long de la tige, vite marcescentes. Inflo-
# False
# rescence en
# False
#  cymes
# False
#  dressées étroitement sur de courts rameaux le long de la partie
# False
# supérieure de la tige. Sépales lancéolés,
# False
#  acuminés,
# False
#  à 5 nervures distinctes. Graines
# False
# 2 mm., fortement tuberculées.
# False
# Floraison: mai-septembre. Lieux
# l ['mai-septembre.', 'Lieux']
# m ['mai', 'septembre.']
# False
#  secs.
# ['secs.']
# False
#  Pâturages dégradés.
# ['Pâturages', 'dégradés.']
# False
# L.
# False
#  Mm.
# False
#  Dimane, Mar
# False
#  Elias
# False
#  (Bl).
# False
#  Met.
# False
#  Zahlé,
# False
#  'Amiq,
# False
#  Deir-el-Ahmar
# False
#  (Mt).
# False
#  Sy.
# False
#  Entre
# False
#  Rayak
# False
# et Baalbeck, Baalbeck (Mt).
# False
#  St.
# False
#  Qa'a
# False
#  (Mt).
# False
#  Hem.
# False
#  Cheba'a
# False
#  (P, sous
# False
#  B. tenuifolia
# False
#  L. et sous
# False
#  B. virgata
# False
# Boiss.), vers Rachaya (Mt).
# False
# S.
# False
#  Sy.
# False
#  Eriha-Idlib
# False
#  (Pb).
# False
#  A.L.
# False
#  Jab. Ma'loula, Yabroud, Madaya, Saïdnaya, Houreiré (Pb).
# False
# J.D.
# False
#  Kafer (Pb), Tell Chihane (Mt).
# False
# Aire géogr. —• Tour de la Méditerranée, Crimée.
# False
# Buffonia ephedrina
# Buffonia ephedrina
# False
#  Sam.
# False
#  (PI.
# False
#  CLVIII, n. 2). —
# False
#  ¾..
# False
#  Plante suffrutescente
# False
# à la base, 10-20 cm. ou plus, à rameaux rigides, glaucescents, simples ou peu ra-
# False
# meux,
# False
#  à entrenœuds d'environ 2 cm. de long, très finement pubérulents à la base,
# False
# glabres plus haut. Feuilles soudées en gaines de 3-4 mm. de long,
# False
#  trinerviées.
# False
#  Inflo-
# False
# rescence
# False
#  racémiforme
# False
#  à rameaux très apprimés contre l'axe, occupant la moitié
# False
# supérieure des rameaux. Pédicelles épais, rigides, pubérulents. Sépales aigus, rigides,
# False
# 7-nerviés, largement
# False
#  marginés-scarieux,
# False
#  les extérieurs longs de 4 mm., à marge
# False
# scarieuse densément fimbriée, les intérieurs 5 mm., entiers. Pétales deux fois plus
# False
# courts, blancs. Styles beaucoup plus longs que l'ovaire. Graine brune, 3 mm. de
# False
# long sur 2 mm. de large, lisse ou presque.
# False
# Floraison: juin-septembre. Lieux
# l ['juin-septembre.', 'Lieux']
# m ['juin', 'septembre.']
# False
#  secs.
# ['secs.']
# False
# L.
# False
#  St.
# False
#  Qamou'at Hermel
# False
#  (P sous
# False
#  B.
# False
#  kotschyana
# False
#  Boiss.), Qa'a et sources de
# False
#  l'Oronte
# False
#  (Mt).
# False
# S.
# False
#  Dam.
# False
#  Sahl-es-Sahra
# False
#  (Sam, récolte-type), Raboué (Pb).
# False
#  St.
# False
#  Jab. Abou
# False
#  Qpsh
# False
#  (Gb sous
# False
# B.
# False
#  multiceps
# False
#  Decne), Forkhlos (Mt),
# False
#  Palmyre
# False
#  (Mt, Pb).
# False
#  H.J.
# False
#  Jab.
# False
#  'Abd-el-'Aziz,
# False
#  E. de Derbassié (Pb).
# False
# Aire géogr. — Liban, Syrie,
# False
#  TransJordanie,
# False
#  Iraq.
# False
# 462
# False
#
# False
# NOUVELLE FLORE
# False
# SAGINA L. — Herbes cespiteuses annuelles ou vivaces, à fleurs blanches, à
# description
# 1 25 0 0 SAGINA L. — Herbes cespiteuses annuelles ou vivaces, à fleurs blanches, à Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# feuilles subulées, connées à la base en une gaine. Calice à 4 ou 5 sépales. Pétales
# description
# 2 25 0 0 feuilles subulées, connées à la base en une gaine. Calice à 4 ou 5 sépales. Pétales Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# absents ou 4-5, entiers ou rétus. Étamines 4-10. Ovaire multiovulé. Capsule à 4-5
# description
# 2 25 1 0 absents ou 4-5, entiers ou rétus. Étamines 4-10. Ovaire multiovulé. Capsule à 4-5 Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# valves. Graines réniformes.
# description
# 2 25 2 0 valves. Graines réniformes. Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
# False
# Plante vivace à fleurs
# False
#  pentamères
# False
#  et pétales présents
# False
# S.
# False
#  libanotica
# False
#  Rech. f.
# False
# Plantes annuelles à 4 sépales
# False
# Feuilles mucronées ou un peu aristées. Sépales relativement étroits, ovales-lancéolés
# False
# S.
# False
#  apetala
# False
#  L.
# False
# Feuilles un peu charnues, obtuses ou à peine mucronées. Sépales plus larges
# False
# S. maritima
# False
#  G. Don.
# False
# Sagina libanotica
# Sagina libanotica
# False
#  Rech. f., Plantae novae syriacae,
# False
#  Rel.
# False
#  Sam.
# False
#  Ill,
# False
#  Ark.
# False
#  for
# False
# Bot., Ser. 2, Bd 1, n. 14, 1951, p. 508. —
# False
#  2J..
# False
#  Plante de 2 cm. de haut à feuilles
# False
# basales en rosette et tiges décombantes, non radicantes, nombreuses. Plante glabre
# False
# sauf les pédicelles et les sépales poilus-glanduleux. Tiges florifères de 1 -2 cm. de
# False
# long, ascendantes, uniflores ou biflores. Feuilles des rosettes linéaires-subulées. Fleurs
# False
# pentamères. Calice 3 mm. de long. Sépales largement ovales-elliptiques, obtus, étroi-
# False
# tement marginés-scarieux. Pétales lancéolés, obtus, égalant ou dépassant les sépales.
# False
# Étamines 10. Capsule ovée-conique.
# False
# L.
# False
#  Ve.
# False
#  'Aïnata,
# False
#  dans une bande herbue le long de canaux d'irrigation, 30 mai 1932 (Sam).
# False
# Neba' 'Amr au-dessus de 'Aïnata (Schweinfurth, août 1880, classé
# False
#  S. procumbens
# False
#  L. dans l'Herbier
# False
# Boissier).
# False
# Aire
# False
#  géogr.
# False
#  — Endémique.
# False
# Sagina apetala
# Sagina apetala
# False
#  L.
# False
#  (PI.
# False
#  CLVIII, n. 3). —
# False
#  ®.
# False
#  Plante généralement très
# False
# petite. Tiges dressées, rameuses dès la base, un peu pubérulentes, 3-7 cm. Feuilles
# False
# subulées-aristées, souvent ciliées à la base. Pédoncules dressés après l'anthèse. Calice
# False
# à 4 sépales ovales, obtus, les 2 extérieurs brièvement mucronés. Pétales rudimen-
# False
# taires et caducs ou nuls. Capsule dépassant les sépales.
# False
# Floraison:
# l []
# False
#  février-mai.
# ['février-mai.']
# m ['février', 'mai.']
# False
#  Abords des maison, chemins, sables.
# ['Abords', 'des', 'maison,', 'chemins,', 'sables.']
# False
# L.
# False
#  Ct.
# False
#  Saïda
# False
#  (Bl),
# False
#  Beyrouth (Pr, Vt,
# False
#  Mt),
# False
#  Fouar
# False
#  (Mt),
# False
#  Tripoli
# False
#  (Bl).
# False
#  Mi.
# False
#  Sous Beit
# False
#  Méri,
# False
# Mayrouba
# False
#  (Mt).
# False
#  'Akkar.
# False
#  Menges (Mt).
# False
# S.
# False
#  Haur.
# False
#  Qneitra (Pb).
# False
# Aire géogr. — Canaries, Méditerranée, Asie antérieure.
# False
# Sagina maritima
# Sagina maritima
# False
#  G. Don.
# False
#  (PI.
# False
#  CLVIII, n. 4). — ®. Plante glabre. Tiges
# False
# étalées-redressées, 2-7 cm. Feuilles obtuses. 4 sépales ovales,' plus larges que chez
# False
# apetala.
# False
#  Pétales courts ou absents.
# False
# Floraison:
# l []
# False
#  février-juin.
# ['février-juin.']
# m ['février', 'juin.']
# False
#  Sables et rochers littoraux et salines.
# ['Sables', 'et', 'rochers', 'littoraux', 'et', 'salines.']
# False
# L.
# False
#  Ctlitt.
# False
#  Beyrouth, Jounié (Mt).
# False
# S.
# False
#  Sy.
# False
#  Lacjabboul
# False
#  (Mt).
# False
# Aire géogr. — Bords de la Méditerranée et de l'Océan.
# False
# MINUARTIA L. 1753 —
# False
#  Alsine
# False
#  Scop. 1772. — Plantes annuelles ou sous-
# False
# arbrisseaux à fleurs blanches, parfois
# False
#  roses.
# False
#  Calice à 5 sépales et corolle à 5 pétales
# False
# (4 rarement hors de nos contrées). Étamines 10 ou moins nombreuses, insérées sur
# False
# des glandes du périgyne. Styles 3. Ovaire souvent multiovulé. Capsule trivalve.
# False
# Graines réniformes, un peu comprimées latéralement, sans ariile.
#    Family                                   GenusDescription        Genus  \
# 0       0  PTERANTHUS Forsk. — Herbe annuelle, charnue, à...            0
# 1       0                                                  0   Pteranthus
# 2       0  SCLERANTHUS L. — Herbes de petite taille, à fe...            0
# 3       0                                                  0  Scleranthus
# 4       0                                                  0  Scleranthus
# 5       0                                                  0     Habrosia
# 6       0  CORRIGIOLA L. — Herbes annuelles ou vivaces à ...            0
# 7       0                                                  0   Gorrigiola
# 8       0  TELEPHIUM L. — Herbes un peu charnues, à feuil...            0
# 9       0                                                  0    Telephium
# 10      0  HERNIARIA L. — Herbes cespiteuses, annuelles o...            0
# 11      0                                                  0    Herniaria
# 12      0                                                  0    Herniaria
# 13      0                                                  0    Herniaria
# 14      0                                                  0    Herniaria
# 15      0                                                  0    Herniaria
# 16      0                                                  0    Herniaria
# 17      0  PARONYCHIA Adanson. — Herbes à tiges couchées,...            0
# 18      0                                                  0   Paronychia
# 19      0                                                  0   Paronychia
# 20      0                                                  0   Paronychia
# 21      0                                                  0   Paronychia
# 22      0                                                  0   Paronychia
# 23      0                                                  0   Paronychia
# 24      0                                                  0   Polycarpon
# 25      0  ROBBAIREA Boiss. — Herbes ressemblant aux Poly...            0
# 26      0  SPERGULA L. — Herbes annuelles à feuilles fili...            0
# 27      0                                                  0     Spergula
# 28      0                                                  0     Spergula
# 29      0                                                  0     Buffonia
# 30      0                                                  0     Buffonia
# 31      0  SAGINA L. — Herbes cespiteuses annuelles ou vi...            0
# 32      0                                                  0       Sagina
# 33      0                                                  0       Sagina
# 34      0                                                  0       Sagina
#
#           epithet author syn. Plate description FloraisonStart FloraisonEnd  \
# 0               0      0    0     0           0              0            0
# 1      dichotomus      0    0     0           0           mars         mai.
# 2               0      0    0     0           0              0            0
# 3      orientalis      0    0     0           0           mars        juin.
# 4        collinus      0    0     0           0           mars         mai.
# 5    spinuliflora      0    0     0           0           mars       avril.
# 6               0      0    0     0           0              0            0
# 7      littoralis      0    0     0           0           mars         mai.
# 8               0      0    0     0           0              0            0
# 9    imperati L.,      0    0     0           0           juin     juillet.
# 10              0      0    0     0           0              0            0
# 11        hirsuta      0    0     0           0           mars        juin.
# 12        cinerea      0    0     0           0           mars         mai.
# 13         glabra      0    0     0           0           mars     juillet.
# 14         incana      0    0     0           0            mai     juillet.
# 15        arabica      0    0     0           0          avril        juin.
# 16     hemistemon      0    0     0           0            mai        juin.
# 17              0      0    0     0           0              0            0
# 18       chionaea      0    0     0           0           juin     juillet.
# 19        kurdica      0    0     0           0              0            0
# 20    macrosepala      0    0     0           0            mai        juin.
# 21       argentea      0    0     0           0              0            0
# 22        arabica      0    0     0           0              0            0
# 23       echinata      0    0     0           0        février         mai.
# 24   tetraphyllum      0    0     0           0        janvier        mars.
# 25              0      0    0     0           0        janvier         mai.
# 26              0      0    0     0           0              0            0
# 27       arvensis      0    0     0           0        janvier       avril.
# 28         fallax      0    0     0           0           mars         mai.
# 29     paniculata      0    0     0           0            mai   septembre.
# 30      ephedrina      0    0     0           0           juin   septembre.
# 31              0      0    0     0           0              0            0
# 32     libanotica      0    0     0           0              0            0
# 33        apetala      0    0     0           0        février         mai.
# 34       maritima      0    0     0           0        février        juin.
#
#         FloraisonNotes L. S. Aire géogr. Notes
# 0                    0  0  0           0     0
# 1              Régions  0  0           0     0
# 2                    0  0  0           0     0
# 3                 Grès  0  0           0     0
# 4              Régions  0  0           0     0
# 5              Régions  0  0           0     0
# 6                    0  0  0           0     0
# 7                Lieux  0  0           0     0
# 8                    0  0  0           0     0
# 9            fertiles.  0  0           0     0
# 10                   0  0  0           0     0
# 11  exceptionnellement  0  0           0     0
# 12               secs.  0  0           0     0
# 13                 peu  0  0           0     0
# 14          Pâturages,  0  0           0     0
# 15             Déserts  0  0           0     0
# 16            Déserts.  0  0           0     0
# 17                   0  0  0           0     0
# 18               Lieux  0  0           0     0
# 19                   0  0  0           0     0
# 20             Rochers  0  0           0     0
# 21                   0  0  0           0     0
# 22          printemps.  0  0           0     0
# 23                Grès  0  0           0     0
# 24              Sables  0  0           0     0
# 25            Terrains  0  0           0     0
# 26                   0  0  0           0     0
# 27              Sables  0  0           0     0
# 28             Régions  0  0           0     0
# 29           Pâturages  0  0           0     0
# 30               secs.  0  0           0     0
# 31                   0  0  0           0     0
# 32                   0  0  0           0     0
# 33              Abords  0  0           0     0
# 34              Sables  0  0           0     0

# %%
frame['FloraisonNotes']
# Out:
# 0                      0
# 1                Régions
# 2                      0
# 3                   Grès
# 4                Régions
# 5                Régions
# 6                      0
# 7                  Lieux
# 8                      0
# 9              fertiles.
# 10                     0
# 11    exceptionnellement
# 12                 secs.
# 13                   peu
# 14            Pâturages,
# 15               Déserts
# 16              Déserts.
# 17                     0
# 18                 Lieux
# 19                     0
# 20               Rochers
# 21                     0
# 22            printemps.
# 23                  Grès
# 24                Sables
# 25              Terrains
# 26                     0
# 27                Sables
# 28               Régions
# 29             Pâturages
# 30                 secs.
# 31                     0
# 32                     0
# 33                Abords
# 34                Sables
# Name: FloraisonNotes, dtype: object

# %%
frame.to_csv("loc.csv")

# %%
pd.DataFrame(arr).head()
# Out:
#        0           1            2                         3
# 0  genus      Urtica  membranacea  page 450 of document.pdf
# 1  genus      Urtica   pilulifera  page 450 of document.pdf
# 2  genus      Urtica       dioica  page 450 of document.pdf
# 3  genus      Urtica     fragilis  page 451 of document.pdf
# 4  genus  Parietaria      judaica  page 452 of document.pdf

# %%
genus_descrip_frame = pd.DataFrame(arr, columns = ["a", "b", "c", "d"])

# %%
genus_descrip_frame
# Out:
#          a           b             c                         d
# 0    genus      Urtica   membranacea  page 450 of document.pdf
# 1    genus      Urtica    pilulifera  page 450 of document.pdf
# 2    genus      Urtica        dioica  page 450 of document.pdf
# 3    genus      Urtica      fragilis  page 451 of document.pdf
# 4    genus  Parietaria       judaica  page 452 of document.pdf
# ..     ...         ...           ...                       ...
# 344  genus    Dianthus    micranthus  page 603 of document.pdf
# 345  genus    Dianthus  pachypetalus  page 603 of document.pdf
# 346  genus    Dianthus     libanotis  page 604 of document.pdf
# 347  genus    Dianthus      crinitus  page 604 of document.pdf
# 348  genus    Dianthus    orientalis  page 604 of document.pdf
#
# [349 rows x 4 columns]

# %%
genus_descrip_frame.iloc[-1]["a"] = "hi"

# %%
genus_descrip_frame.iloc[[-1]]
# Out:
#       a         b            c                         d
# 348  hi  Dianthus   orientalis  page 604 of document.pdf

# %%
genus_descrip_frame.to_csv("genus5.csv")

# %%
frame
# Out:
# Empty DataFrame
# Columns: [text, font, size, style, color, flags]
# Index: []

# %%
frame.to_excel('analyzed.xlsx', index = False, header=True)

# %%
"""
print(s['text'], "***",s['font'], "***", s['size'], "***", s['style'], "***", s['color'], "***", s['flags'],"********************************************************")


#family
CARYOPHYLLACEAE *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

15 18 0 0 CARYOPHYLLACEAE Font: 'Times-Roman' (serifed, proportional), size 10.9449, color #000000
Plantes herbacées ou sous-frutescentes. Feuilles simples, opposées, décussées, *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

très rarement alternes. Fleurs habituellement en cymes bipares, actinomorphes, le *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

plus souvent hermaphrodites, parfois polygames, plus rarement dioïques. Périanthe *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

simple ou double, les pétales étant alors d'origine staminale. Calice libre ou *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

 gamo- *** Times-Roman *** 10.91801929473877 *** serifed, proportional *** 0 *** 4 ********************************************************

phylle. Corolle souvent onguiculée, toujours libre, et complétée parfois par des *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

ligules, constituant une couronne. Fruit en capsule s'ouvrant habituellement au *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

sommet, exceptionnellement une baie.  *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

— *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************



#other info
NOUVELLE FLORE  *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

451 *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

Sous-famille des *** Times-Italic *** 10.94486141204834 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

 PARONYCHIOIDEAE *** Times-Italic *** 11.0 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

Feuilles habituellement stipulées. Sépales libres ou faiblement concrescents. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

Corolle le plus souvent absente. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

PTERANTHUS Forsk. — Herbe annuelle, charnue, à feuilles opposées, fas- *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

ciculifères, ce qui les rend pseudo-verticillées. Cymes *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

 biflores *** Times-Roman *** 11.0 *** serifed, proportional *** 0 *** 4 ********************************************************

 portés par un pédon- *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

cule commun accrescent, large, oblong, aplati et tombant avec lui. Fleurs sessiles, *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

latérales. Calice 4-partite à sépales oblongs-linéaires, prolongés par un appendice *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

vertical scarieux-marginé. 4 étamines. Pas de corolle. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************






#important info
Pteranthus *** Times-Bold *** 10.94486141204834 *** serifed, proportional, bold *** 0 *** 20 ********************************************************

 dichotomus *** Times-Bold *** 11.0 *** serifed, proportional, bold *** 0 *** 20 ********************************************************

 Forsk. — *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

 P. echinatus *** Times-Italic *** 10.94486141204834 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

 Desf. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

 (PI. *** Times-Roman *** 10.891444206237793 *** serifed, proportional *** 0 *** 4 ********************************************************

 CLV, n. 1). — *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

0. Tige très rameuse à la base, couchée ou ascendante, 10-40 cm. triangulaires, *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

plus ou moins dentées, opposées et fasciculifères, les feuilles des fascicules plus courtes *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

et plus fines. Pédoncules floraux aux aisselles des feuilles supérieures, papilleux, *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

hirsutes, d'abord cylindriques, mais se développant rapidement en une sorte de *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

raquette ovale, atténuée à la base. Fleurs sessiles, à 4 sépales, prolongés par un *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

appendice scarieux, lui-même terminé par une courte épine, et entourées de rameaux *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

stériles armés de plusieurs épines, les égalant sans les dépasser. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************

Floraison: mars-mai. Régions arides. *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

S. *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

  *** Times-Italic *** 8.954887390136719 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

St. *** Times-Italic *** 8.954887390136719 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

 Palmyre *** Times-Roman *** 9.0 *** serifed, proportional *** 0 *** 4 ********************************************************

 (Sam, Mt, Pb), Palmyre à Arak, *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

 Bir-al-'Alaniyé *** Times-Roman *** 9.0 *** serifed, proportional *** 0 *** 4 ********************************************************

 (Pb), *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

 Jabal-et-Tenf *** Times-Roman *** 9.0 *** serifed, proportional *** 0 *** 4 ********************************************************

 (Bb). *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

Sud. *** Times-Italic *** 8.954887390136719 *** italic, serifed, proportional *** 0 *** 6 ********************************************************

 Hammé *** Times-Roman *** 9.0 *** serifed, proportional *** 0 *** 4 ********************************************************

 (Pb). *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

Aire géogr. —• Afrique du Nord, *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

 Egypte, *** Times-Roman *** 8.953801155090332 *** serifed, proportional *** 0 *** 4 ********************************************************

 Ethiopie, *** Times-Roman *** 8.961397171020508 *** serifed, proportional *** 0 *** 4 ********************************************************

 Chypre, Palestine sud, *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

 TransJordanie, *** Times-Roman *** 8.976929664611816 *** serifed, proportional *** 0 *** 4 ********************************************************

 Syrie, *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************

Iraq, Iran, Géorgie. *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************
"""
# Out:
# '\nprint(s[\'text\'], "***",s[\'font\'], "***", s[\'size\'], "***", s[\'style\'], "***", s[\'color\'], "***", s[\'flags\'],"********************************************************")\n\n\n#family\nCARYOPHYLLACEAE *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n15 18 0 0 CARYOPHYLLACEAE Font: \'Times-Roman\' (serifed, proportional), size 10.9449, color #000000\nPlantes herbacées ou sous-frutescentes. Feuilles simples, opposées, décussées, *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\ntrès rarement alternes. Fleurs habituellement en cymes bipares, actinomorphes, le *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nplus souvent hermaphrodites, parfois polygames, plus rarement dioïques. Périanthe *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nsimple ou double, les pétales étant alors d\'origine staminale. Calice libre ou *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n gamo- *** Times-Roman *** 10.91801929473877 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nphylle. Corolle souvent onguiculée, toujours libre, et complétée parfois par des *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nligules, constituant une couronne. Fruit en capsule s\'ouvrant habituellement au *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nsommet, exceptionnellement une baie.  *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n— *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n\n\n#other info\nNOUVELLE FLORE  *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n451 *** Times-Roman *** 8.954887390136719 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nSous-famille des *** Times-Italic *** 10.94486141204834 *** italic, serifed, proportional *** 0 *** 6 ********************************************************\n\n PARONYCHIOIDEAE *** Times-Italic *** 11.0 *** italic, serifed, proportional *** 0 *** 6 ********************************************************\n\nFeuilles habituellement stipulées. Sépales libres ou faiblement concrescents. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nCorolle le plus souvent absente. *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nPTERANTHUS Forsk. — Herbe annuelle, charnue, à feuilles opposées, fas- *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\nciculifères, ce qui les rend pseudo-verticillées. Cymes *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n biflores *** Times-Roman *** 11.0 *** serifed, proportional *** 0 *** 4 ********************************************************\n\n portés par un pédon- *** Times-Roman *** 10.94486141204834 *** serifed, proportional *** 0 *** 4 ********************************************************\n\ncule commun accrescent, large, oblong, aplati et tombant avec lui. Fleurs sessiles, *** Times-Roman  ...

# %%
col1 = {"CARYOPHYLLACEAE", "Times-Roman", "10.94486141204834", "serifed, proportional", "0", "4"}
col2 = {"Pteranthus", "Times-Bold", "10.94486141204834", "serifed, proportional, bold", "0", "20"}
col3 = {"dichotomus", "Times-Bold", "11.0", "serifed, proportional, bold", "0", "20"}
col4 = {"Forsk.", "Times-Roman", "10.94486141204834", "serifed, proportional", "0", "4"}
col5 = {"P. echinatus", "Times-Italic", "10.94486141204834", "italic, serifed, proportional", "0", "6"}
col6 = {"Desf.", "Times-Roman", "10.94486141204834", "serifed, proportional", "0", "4"}
col7 = {"(PI.", "Times-Roman", "10.891444206237793", "serifed, proportional"}

# %%
# #simplify
# page = next(p)
# # read page text as a dictionary, suppressing extra spaces in CJK fonts
# blocks = page.getText("dict", flags=11)["blocks"]
# for x,b in enumerate(blocks):  # iterate through the text blocks
#     for y,l in enumerate(b["lines"]):  # iterate through the text lines
#         for z,s in enumerate(l["spans"]):  # iterate through the text spans
#             s["style"] = flags_decomposer(s["flags"])  # readable font flags
#             face = Face(s["font"], s["size"], s["color"], s["flags"])
#             print(s['text'], "***********************************************************")
#             if isfamily(s["text"], face) and len(l["spans"]) == 1:
#                 item['Family'] = s["text"]
#                 print(x, len(blocks), y, z, s["text"], face)
#                 break
#             if not item['Family']:
#                 break
#             if s['font'] == 'Times-Bold':
#                 item['Genus'], *item['epithet'] = s["text"].split(' ')
#                 item['epithet'] = item['epithet'][0] if item['epithet'] else l["spans"][1]["text"]
#                 currsize = s['size']
# #                print(x, len(blocks), y, z, s["text"], font_properties)
#                 print(x, len(blocks), y, len(b["lines"]), z, s["text"], face)
# #                 nn, xx, yy, zz, tt = next(floraison(page, x))
# #                 item['Floraison'] = tt
# #                 for q in range(x, max(x+15, len(blocks))):
# #                     for ll in blocks[q]["lines"]:
# #                         s = ll["spans"][0]
# #                         text, *rest = s['text'].split(' ')
# #                         if text == "Floraison:":
# #                             face = Face(s["font"], s["size"], s["color"], s["flags"])
# #                             print(face, s['text'])
# #                             for ss in ll["spans"]:
# #                                 #print(ss['text'], end=" ")
# #                                 pass
#                 from pprint import pprint
#                 print(x, len(blocks), y, z, pprint(item))
#                 #print([a["text"] for a in l["spans"]])
#                 print(); print(); 
#                 break
#             elif item['Genus'] and (not item['author']) and (s['font'] == 'Times-Roman'):
#                 item['author'] = s["text"]
#                 print(x, len(blocks), y, len(b["lines"]), z, s["text"], face)
#                 print(item)
#                 break
# Out:
# NOUVELLE FLORE  ***********************************************************
# 451 ***********************************************************
# Sous-famille des ***********************************************************
#  PARONYCHIOIDEAE ***********************************************************
# Feuilles habituellement stipulées. Sépales libres ou faiblement concrescents. ***********************************************************
# Corolle le plus souvent absente. ***********************************************************
# PTERANTHUS Forsk. — Herbe annuelle, charnue, à feuilles opposées, fas- ***********************************************************
# ciculifères, ce qui les rend pseudo-verticillées. Cymes ***********************************************************
#  biflores ***********************************************************
#  portés par un pédon- ***********************************************************
# cule commun accrescent, large, oblong, aplati et tombant avec lui. Fleurs sessiles, ***********************************************************
# latérales. Calice 4-partite à sépales oblongs-linéaires, prolongés par un appendice ***********************************************************
# vertical scarieux-marginé. 4 étamines. Pas de corolle. ***********************************************************
# Pteranthus ***********************************************************
# 6 28 0 1 0 Pteranthus Font: 'Times-Bold' (serifed, proportional, bold), size 10.9449, color #000000
# {'Aire géogr.': None,
#  'Family': 'CARYOPHYLLACEAE',
#  'Floraison': None,
#  'Genus': 'Pteranthus',
#  'L.': None,
#  'Notes': None,
#  'Plate': None,
#  'S.': None,
#  'author': '450 ',
#  'description': None,
#  'epithet': ' dichotomus',
#  'syn.': None}
# 6 28 0 0 None
#
#
# 0. Tige très rameuse à la base, couchée ou ascendante, 10-40 cm. triangulaires, ***********************************************************
# plus ou moins dentées, opposées et fasciculifères, les feuilles des fascicules plus courtes ***********************************************************
# et plus fines. Pédoncules floraux aux aisselles des feuilles supérieures, papilleux, ***********************************************************
# hirsutes, d'abord cylindriques, mais se développant rapidement en une sorte de ***********************************************************
# raquette ovale, atténuée à la base. Fleurs sessiles, à 4 sépales, prolongés par un ***********************************************************
# appendice scarieux, lui-même terminé par une courte épine, et entourées de rameaux ***********************************************************
# stériles armés de plusieurs épines, les égalant sans les dépasser. ***********************************************************
# Floraison: mars-mai. Régions arides. ***********************************************************
# S. ***********************************************************
#   ***********************************************************
# St. ***********************************************************
#  Palmyre ***********************************************************
#  (Sam, Mt, Pb), Palmyre à Arak, ***********************************************************
#  Bir-al-'Alaniyé ***********************************************************
#  (Pb), ***********************************************************
#  Jabal-et-Tenf ***********************************************************
#  (Bb). ***********************************************************
# Sud. ***********************************************************
#  Hammé ***********************************************************
#  (Pb). ***********************************************************
# Aire géogr. —• Afrique du Nord, ***********************************************************
#  Egypte, ***********************************************************
#  Ethiopie, ***********************************************************
#  Chypre, Palestine sud, ***********************************************************
#  TransJordanie, ***********************************************************
#  Syrie, ***********************************************************
# Iraq, Iran, Géorgie. ***********************************************************
# SCLERANTHUS L. — Herbes de petite taille, à feuilles linéaires-sétacées. ***********************************************************
# Calice à tube urcéolé, à la fin durci. 5 sépales mutiques. Pétales filiformes, parfois ***********************************************************
# avortés. Étamines 5. Ovaire libre. Styles 2, distincts. ***********************************************************
# Calice de très petite taille, 2 mm. seulement à sépales courts et un peu marginés ***********************************************************
# S. ***********************************************************
#  collinus ***********************************************************
#  Hornung ***********************************************************
# Calice de 4 mm. ou davantage à sépales verts, égalant ou dépassant la longueur du tube ***********************************************************
# Sépales tous droits ***********************************************************
#   ***********************************************************
# S. ***********************************************************
#  annuus ***********************************************************
#  L. ***********************************************************
# Sépales tous fortement courbés et uncinés ***********************************************************
#   ***********************************************************
# S. ***********************************************************
#  uncinatus ***********************************************************
#  Schur. ***********************************************************
# Sépales les uns droits les autres recourbés, sur les mêmes fruits ***********************************************************
# S. orientalis ***********************************************************
#  Rôssler. ***********************************************************
# Scleranthus ***********************************************************
# 21 28 0 1 0 Scleranthus Font: 'Times-Bold' (serifed, proportional, bold), size 11, color #000000
# {'Aire géogr.': None,
#  'Family': 'CARYOPHYLLACEAE',
#  'Floraison': None,
#  'Genus': 'Scleranthus',
#  'L.': None,
#  'Notes': None,
#  'Plate': None,
#  'S.': None,
#  'author': '450 ',
#  'description': None,
#  'epithet': ' orientalis',
#  'syn.': None}
# 21 28 0 0 None
#
#
# CLIV, ***********************************************************
#  n. 8). — ®. Plante annuelle, 1,3 à 20 cm. de haut, non glanduleuse. Tiges ***********************************************************
# décombantes, ascendantes ou dressées au sommet, à pilosité uniforme. ***********************************************************
#  Entrenceuds ***********************************************************
# longs de 0,5 à 4 cm. de long. Feuilles opposées ***********************************************************
#   ***********************************************************
# à ***********************************************************
#  5 cm. de long, subulées, poilues ***********************************************************
# vers la base et brièvement connées par leurs gaines. Glomérules de l'inflorescence ***********************************************************
# en ***********************************************************
#  cyme ***********************************************************
#  rameuse ou très courte. Fleurs plus ou moins sessiles. Tépales 5, lancéolés, ***********************************************************
# aigus, étroitement marginés seulement vers la base, les uns rectilignes, les autres ***********************************************************
# uncinés-recourbés ***********************************************************
#  sur le même fruit. Étamines 5 à 2. Staminodes présents. Ovaire ***********************************************************
# à 2 stigmates, enfermé dans le réceptacle induré. Faux fruit, mûr, mesurant 3,2 à ***********************************************************
# 5,3 mm. Tépales étalés ou dressés ou connivents. ***********************************************************
# Floraison: mars-juin. Grès et terrains non calcaires, légèrement hygrophile. ***********************************************************
# L. ***********************************************************
#   ***********************************************************
# Mi. ***********************************************************
#  Bikfaya, Mayrouba (Mt), ***********************************************************
#  Neba'-l-Bata, ***********************************************************
#  au-dessus de ***********************************************************
#  Jbail ***********************************************************
#  (Bl). ***********************************************************
#  Mm. ***********************************************************
#  Khan Sannine, ***********************************************************
# Falougha (Mt), Col de ***********************************************************
#  Zahlé ***********************************************************
#  (Bl, Th, Mt, Pb). ***********************************************************
#  Ve. ***********************************************************
#  Jabal-ech-Cha'arra ***********************************************************
#  (Mt). ***********************************************************
# S. ***********************************************************
#   ***********************************************************
# Mi. ***********************************************************
#  'Aïn ***********************************************************
#  Halakim (Har). ***********************************************************
#  A.L. ***********************************************************
#  Jabal ***********************************************************
#  Gharbi (Pr). ***********************************************************
# Aire géogr. — ***********************************************************
#  Erythrée, ***********************************************************
#  Ethiopie, ***********************************************************
#  Liban, Syrie, Caucase, Iraq, Iran. ***********************************************************

# %%
search = ((x, doc.searchPageFor(x, "Floraison", 100, False)) for x in range(516,520))

# %%
next(search)
# Out:
# (516,
#  [Rect(42.0, 69.48302459716797, 77.89947509765625, 81.48902130126953),
#   Rect(42.0, 324.6029968261719, 78.0272445678711, 336.6089782714844)])

# %%
p = (doc[x] for x in range(516,520))

# %%
page = next(p)
rects = page.searchFor("Floraison")
rects[0]
# Out:
# Rect(42.0, 69.48302459716797, 77.89947509765625, 81.48902130126953)

# %%
page.getTextBlocks()
# Out:
# [(177.83999633789062,
#   18.363027572631836,
#   409.36810302734375,
#   30.36902618408203,
#   'NOUVELLE FLORE  439',
#   0,
#   0),
#  (24.0,
#   40.73700714111328,
#   409.758544921875,
#   67.1710205078125,
#   'centes. Sépales linéaires, spatules, denticulés, lacérés. Staminodes plus courts que\nleur partie soudée. Fruit un peu accrescent, à la fin glabre.',
#   1,
#   0),
#  (42.0,
#   69.48302459716797,
#   409.81085205078125,
#   94.92902374267578,
#   'Floraison: automne.\nS. St. Entre Alep et Bagdad (Oliv), Palmyre (Mt, Zoh, Pb), Deir-ez-Zor (Gb), entre Mey-',
#   2,
#   0),
#  (23.760000228881836,
#   92.52300262451172,
#   409.95843505859375,
#   114.12897491455078,
#   'yadine et Salihiyé (Hd-Mz), W. de Deir-ez-Zor, entre Abou Kemal et Meyyadine (Pb), entre\nSoukhné et Deir-ez-Zor (Dlb).',
#   3,
#   0),
#  (41.52000045776367,
#   116.0429916381836,
#   154.27919006347656,
#   128.0489959716797,
#   'Aire géogr. — Syrie et Iraq.',
#   4,
#   0),
#  (45.84000015258789,
#   134.33700561523438,
#   409.8203430175781,
#   149.01101684570312,
#   'HALOGETON C.A. Mey. — Arbrisseaux ou plantes annuelles, à feuilles',
#   5,
#   0),
#  (24.479999542236328,
#   146.09698486328125,
#   409.7297668457031,
#   196.05099487304688,
#   'charnues. Fleurs polygames par avortement, agglomérées aux aisselles et envelop-\npées par une laine dense, celle du milieu sans bractéole, les autres à 2 ou 3 bractéoles.\nSépales 5, dont 2 ou 3 portant au dos une bosse ou une aile. Étamines 5, rarement\n2 ou 3. Ovaire ové. Stigmates filiformes au nombre de 2.',
#   6,
#   0),
#  (45.36000061035156,
#   202.49697875976562,
#   409.4846496582031,
#   217.83099365234375,
#   'Halogeton alopecuroides (Del.) Moq. — Anabasis alopecuroides Del. (PI.',
#   7,
#   0),
#  (24.0,
#   214.01699829101562,
#   409.8216247558594,
#   320.85101318359375,
#   "CXLIX, n. 3). — 3. Sous-arbrisseau peu élevé, 15-25 cm., très rameux, à rameaux\nallongés, étalés ou recourbés, blancs. Feuilles alternes, distantes ou rapprochées,\nsemi-cylindriques, planes à la face supérieure, courtes, munies ou non d'une pointe\nterminale fine, caduque, laissant après sa chute un mucron très court. Aisselles den-\nsément laineuses. Fleurs constituant dans ces aisselles des glomérules sphériques,\nmêlés de bractéoles orbiculaires-ovées. Sépales au moment de l'anthèse hyalins\nérodés-denticulés au sommet. Sépales fructifères tous ou seulement deux d'entre eux\ndotés au-dessus de leur milieu d'ailes en éventail, souvent inégales. Étamines et\nstaminodes 5.",
#   8,
#   0),
#  (42.0,
#   324.6029968261719,
#   410.1195373535156,
#   349.3289794921875,
#   'Floraison: été.\nS. Dam. 5 km. est de Dmeir (Pb). St. Oasis de Bardi (Pb), 80 km. est de Damas, 30 km.',
#   9,
#   0),
#  (24.239999771118164,
#   346.9230041503906,
#   190.75485229492188,
#   358.9289855957031,
#   'W. de Qaryatein, Ouadi Rijal (Eig, Zoh).',
#   10,
#   0),
#  (41.7599983215332,
#   359.64300537109375,
#   356.59259033203125,
#   371.64898681640625,
#   'Aire géogr. — Sahara, Egypte, Palestine mér., TransJordanie, Arabie séoudite.',
#   11,
#   0),
#  (164.16000366210938,
#   390.656982421875,
#   267.8347473144531,
#   405.33099365234375,
#   'AMARANTHACEAE',
#   12,
#   0),
#  (45.84000015258789,
#   412.0169982910156,
#   409.82049560546875,
#   426.6910095214844,
#   'Herbes ou sous-arbrisseaux à feuilles sans stipules, à fleurs munies de trois',
#   13,
#   0),
#  (24.719999313354492,
#   423.7769775390625,
#   410.0606689453125,
#   438.45098876953125,
#   'bractées (une bractée et deux bractéoles), rarement de deux seulement.  Fleurs',
#   14,
#   0),
#  (24.239999771118164,
#   435.5369873046875,
#   409.9990539550781,
#   497.2510070800781,
#   "hermaphrodites, rarement polygames ou monoïques. Périanthe scarieux, 3-5-partite.\nÉtamines 3-5, opposées aux sépales, complétées parfois par des staminodes. Ovaire\nuniloculaire ou pluriovulé. Style simple ou à plusieurs stigmates. Fruit monosperme\nou polysperme, souvent en forme d'utricule indéhiscent ou déhiscent par une fente\nlatérale. Graines le plus souvent verticales, à tégument coriace.",
#   15,
#   0),
#  (46.31999969482422,
#   503.697021484375,
#   410.0920104980469,
#   518.3710327148438,
#   'Celosia cris tata L. — (J). Herbe glabre, verte, pouvant atteindre et dépasser',
#   16,
#   0),
#  (24.479999542236328,
#   515.2169799804688,
#   410.2384033203125,
#   575.9710083007812,
#   'un mètre. Fleurs dépassant leurs bractées, 5-8 mm. de long, colorées, ainsi que leurs\nbractées et leurs bractéoles, en rouge pourpre, rouge écarlate, jaune, orangé, blanc.\nCultivée sous deux formes, la forme normale fastigiée, et plus souvent sous une\nforme fasciée, à inflorescence en large crête ondulée, crispée ou sinuée. Fréquente\ndans les jardins, généralement en teinte pourpre.',
#   17,
#   0),
#  (42.47999954223633,
#   578.0430297851562,
#   263.95428466796875,
#   603.0089721679688,
#   'Occasionnellement échappée de culture, non naturalisée.\nOrigine inconnue.',
#   18,
#   0)]

# %%
d = iter(doc)

# %%
next(d).getTextBlocks()
# Out:
# [(110.87999725341797,
#   124.28401184082031,
#   344.0527648925781,
#   140.29200744628906,
#   'AUTRES OUVRAGES DU MÊME AUTEUR',
#   0,
#   0),
#  (59.040000915527344,
#   183.02999877929688,
#   419.97821044921875,
#   196.3699951171875,
#   'La végétation arborescente des Pays du Levant, dans : Publications techniques et',
#   1,
#   0),
#  (35.52000045776367,
#   195.89700317382812,
#   370.8548889160156,
#   210.57101440429688,
#   "scientifiques de l'École Française d'Ingénieurs de Beyrouth, n° 13, 1947.",
#   2,
#   0),
#  (59.279998779296875,
#   218.07000732421875,
#   420.3532409667969,
#   231.41000366210938,
#   "Contribution à l'étude de la flore syrienne et libanaise. Série de courts mémoires",
#   3,
#   0),
#  (35.52000045776367,
#   231.177001953125,
#   408.53289794921875,
#   245.85101318359375,
#   'insérés dans : Bulletin de la Société Botanique de France, depuis 1952, tome 98.',
#   4,
#   0),
#  (59.279998779296875,
#   252.5369873046875,
#   420.21917724609375,
#   267.21099853515625,
#   'La Flore du Djebel Druze. Université Saint-Joseph, Beyrouth, 1952. En dépôt',
#   5,
#   0),
#  (35.52000045776367,
#   266.4570007324219,
#   419.48846435546875,
#   295.0509948730469,
#   'à Paris chez Paul Lechevalier (Librairie scientifique de Jacques Lechevalier),\n18, rue des Écoles, Paris, 5e.',
#   6,
#   0)]

# %%
doc[621].getTextBlocks()
# Out:
# [(47.040000915527344,
#   32.29714584350586,
#   278.7561340332031,
#   47.56802749633789,
#   '546\nNOUVELLE FLORE',
#   0,
#   0),
#  (58.79999923706055,
#   59.93598556518555,
#   143.0931396484375,
#   290.4889831542969,
#   'gussonii Pari.\nhordeaceus L.\nintermedius Guss.\njaponicus Thunb.\nlanceolatus Roth\nmacrpstachys Desf.\nmadritensis L.\nmaximus Desf.\nmollis L.\noxyphlaeus Payne\npalaestinus Melderis\npatulus Mert. et Koch\npinnatus L.\nramosus L.\nrigens L.\nrigidus Roth\nrubens L.\nscoparius L.\nsquarrosus L.\nsterilis L.\nsyriacus Boiss. et Bl.\ntectorum L.\ntomentellus Boiss.\nvillosus Forsk.',
#   1,
#   0),
#  (45.119998931884766,
#   287.843017578125,
#   174.9159393310547,
#   310.16900634765625,
#   "Broussonetia papyrifera (L.) L'Hér.\nBuffonia",
#   2,
#   0),
#  (58.31999969482422,
#   307.0429992675781,
#   130.1332550048828,
#   376.8479919433594,
#   'ephedrina Sam.\nkotschyana Boiss.\nmacrospermaj. Gay\nmulticeps Decne\npaniculata Dubois\ntenuifolia Vill.\nvirgata Boiss.',
#   3,
#   0),
#  (44.400001525878906,
#   375.2959899902344,
#   140.96258544921875,
#   406.16900634765625,
#   'Bulbillaria gageoides Zucc.\nBUTOMACEAE\nButomus',
#   4,
#   0),
#  (57.84000015258789,
#   403.28302001953125,
#   111.75315856933594,
#   415.28900146484375,
#   'umbellatus L.',
#   5,
#   0),
#  (130.55999755859375,
#   424.88299560546875,
#   136.50296020507812,
#   436.88897705078125,
#   'C',
#   6,
#   0),
#  (44.63999938964844,
#   435.2030029296875,
#   98.74201202392578,
#   447.208984375,
#   'Calamagrostis',
#   7,
#   0),
#  (57.36000061035156,
#   445.52301025390625,
#   189.03184509277344,
#   476.489013671875,
#   'epigeios (L.) Roth\nlittorea (Schrad.) D.C.\npseudophragmites (Hall Fil.) Kœl.',
#   8,
#   0),
#  (44.400001525878906,
#   474.322998046875,
#   89.093994140625,
#   486.3289794921875,
#   'Calligonum',
#   9,
#   0),
#  (57.599998474121094,
#   483.4429931640625,
#   164.2140655517578,
#   505.04901123046875,
#   "comosum L'Hér.\ntetrapterum Jaub. et Spach",
#   10,
#   0),
#  (44.15999984741211,
#   503.12298583984375,
#   79.33964538574219,
#   515.1289672851562,
#   'Cannabis',
#   11,
#   0),
#  (57.36000061035156,
#   511.76300048828125,
#   90.87151336669922,
#   523.7689819335938,
#   'sativa L.',
#   12,
#   0),
#  (44.15999984741211,
#   521.3629760742188,
#   66.56568145751953,
#   533.3689575195312,
#   'Carex',
#   13,
#   0),
#  (56.63999938964844,
#   532.2559814453125,
#   124.95293426513672,
#   619.7689819335938,
#   'acuta L.\nacutiformis Ehrh.\nbanatica Heuff.\nbuekii Wimm.\ncontigua Hoppe\ndistans L.\ndiversicolor Druce\ndivisa Huds.\ndivulsa Stokes',
#   14,
#   0),
#  (214.0800018310547,
#   59.60301971435547,
#   227.34642028808594,
#   80.48902130126953,
#   '123\n129',
#   15,
#   0),
#  (194.63999938964844,
#   77.36302947998047,
#   226.8273162841797,
#   108.56897735595703,
#   '120, 128\n120, 129\n119, 126',
#   16,
#   0),
#  (213.60000610351562,
#   106.64299774169922,
#   226.3650665283203,
#   118.64899444580078,
#   '126',
#   17,
#   0),
#  (194.39999389648438,
#   116.24297332763672,
#   225.73451232910156,
#   128.2489776611328,
#   '119, 122',
#   18,
#   0),
#  (213.36000061035156,
#   125.84300994873047,
#   226.52345275878906,
#   156.56898498535156,
#   '123\n129\n126',
#   19,
#   0),
#  (194.39999389648438,
#   154.1630096435547,
#   226.34730529785156,
#   166.1690216064453,
#   '120, 128',
#   20,
#   0),
#  (213.1199951171875,
#   163.7629852294922,
#   226.3888397216797,
#   204.5690155029297,
#   '129\n131\n132\n123',
#   21,
#   0),
#  (193.44000244140625,
#   202.1630096435547,
#   231.8883514404297,
#   281.3689880371094,
#   '119, 123\n119, 124\n119, 125\n120, 127\n119, 122\n119, 120\n119, 121c\n119, 121',
#   22,
#   0),
#  (210.72000122070312,
#   278.4830017089844,
#   225.66641235351562,
#   386.968994140625,
#   '123\n371\n461\n461\n461\n461\n461\n461\n461\n461\n226',
#   23,
#   0),
#  (215.52000427246094,
#   384.0830078125,
#   224.3201141357422,
#   415.28900146484375,
#   '31\n31\n31',
#   24,
#   0),
#  (215.0399932861328,
#   435.9230041503906,
#   224.32266235351562,
#   476.489013671875,
#   '69\n69\n69\n69',
#   25,
#   0),
#  (209.75999450683594,
#   474.322998046875,
#   223.71546936035156,
#   543.448974609375,
#   '406\n407\n407\n377\n377\n172\n179',
#   26,
#   0),
#  (191.52000427246094,
#   541.0430297851562,
#   223.08714294433594,
#   553.0490112304688,
#   '174, 181',
#   27,
#   0),
#  (210.47999572753906,
#   550.6430053710938,
#   223.26882934570312,
#   562.6489868164062,
#   '179',
#   28,
#   0),
#  (191.27999877929688,
#   560.0029907226562,
#   223.1025848388672,
#   572.0089721679688,
#   '173, 179',
#   29,
#   0),
#  (210.24000549316406,
#   569.843017578125,
#   223.16346740722656,
#   581.8489990234375,
#   '176',
#   30,
#   0),
#  (191.0399932861328,
#   579.4429931640625,
#   222.84671020507812,
#   591.448974609375,
#   '174, 181',
#   31,
#   0),
#  (210.0,
#   589.0430297851562,
#   222.8719940185547,
#   601.0490112304688,
#   '178',
#   32,
#   0),
#  (190.55999755859375,
#   598.6430053710938,
#   222.82846069335938,
#   620.0089721679688,
#   '172, 174\n173, 175',
#   33,
#   0),
#  (263.5199890136719,
#   59.60301971435547,
#   362.5534973144531,
#   357.4079895019531,
#   'echinata Murr.\nechinata Desf.\nextensa Good.\nflacca Schreb.\nglauca Scop.\ngracilis Curt.\ngynobasis Vill.\nhalleriana Asso\nhispida Willd.\nleporina L.\nmaxima Scop.\nmediterranea Clarke\nmuricata L.\nnemorosa Rebent.\notrubae Podp.\npachystylisj. Gay\npairaei F. Schultz\npallescens L.\npaludosa Good.\npendula Huds.\nphyllostachys C. A. Mey.\npseudocyperus L.\npubescens Poir.\nremota L.\nriparia Gurt.\nrufa (L.) Simonk\nsilvatica Huds.\nstellulata Good.\nstenophylla Wahlenb.\nsubvùlpina Senay\nvulpina L.',
#   34,
#   0),
#  (250.55999755859375,
#   357.87200927734375,
#   284.33599853515625,
#   367.6400146484375,
#   'Caroxylon',
#   35,
#   0),
#  (263.2799987792969,
#   365.843017578125,
#   358.7127685546875,
#   387.4490051269531,
#   'articulatum (Cav.) Moqu.\nsalicomicum Moqu.',
#   36,
#   0),
#  (250.32000732421875,
#   385.0429992675781,
#   284.6839599609375,
#   397.0489807128906,
#   'Carpinus',
#   37,
#   0),
#  (263.5199890136719,
#   394.40301513671875,
#   320.79351806640625,
#   416.2489929199219,
#   'duinensis Scop.\norientalis Mill.',
#   38,
#   0),
#  (250.0800018310547,
#   415.8559875488281,
#   368.7249450683594,
#   457.52899169921875,
#   'Carpobrotus edulis (L.) N. E. Br.\nCARYOPHYLLACEAE\nCastanea sativa L.\nCatabrosa',
#   39,
#   0),
#  (263.0400085449219,
#   454.64300537109375,
#   354.39373779296875,
#   476.2489929199219,
#   'aquatica (L.) Beauv.\nhumilis (M. Bieb.) Trin.',
#   40,
#   0),
#  (249.83999633789062,
#   474.322998046875,
#   296.5728759765625,
#   486.3289794921875,
#   'Catapodium',
#   41,
#   0),
#  (262.79998779296875,
#   483.4429931640625,
#   353.7076416015625,
#   504.5689697265625,
#   'loliaceum (Huds.) Link\nrigidum (L.) C. Hubb.',
#   42,
#   0),
#  (249.60000610351562,
#   504.0409851074219,
#   281.10906982421875,
#   515.0299682617188,
#   'Caulinia',
#   43,
#   0),
#  (260.6400146484375,
#   511.52301025390625,
#   340.9518127441406,
#   533.3689575195312,
#   'fragilis Willd.\ngraminea (Del.) Batt.',
#   44,
#   0),
#  (249.36000061035156,
#   531.6830444335938,
#   275.7702331542969,
#   543.6890258789062,
#   'Cedrus',
#   45,
#   0),
#  (262.32000732421875,
#   541.2830200195312,
#   320.3157653808594,
#   572.2080078125,
#   'libanensis Juss.\nlibani A. Rich.\nlibanotica Link',
#   46,
#   0),
#  (248.8800048828125,
#   571.135986328125,
#   312.08172607421875,
#   591.448974609375,
#   'Celosia çristata L.\nCeltis',
#   47,
#   0),
#  (262.0799865722656,
#   589.2830200195312,
#   328.95751953125,
#   610.6489868164062,
#   'australis L.\ntournefortii Lam.',
#   48,
#   0),
#  (248.63999938964844,
#   608.2429809570312,
#   284.0602722167969,
#   620.2489624023438,
#   'Cenchrus',
#   49,
#   0),
#  (419.0400085449219,
#   59.60301971435547,
#   431.75360107421875,
#   80.48902130126953,
#   '176\n178',
#   50,
#   0),
#  (399.1199951171875,
#   77.84300994873047,
#   431.36126708984375,
#   99.44898223876953,
#   '173, 180\n173, 178',
#   51,
#   0),
#  (418.55999755859375,
#   97.04302215576172,
#   431.4319763183594,
#   109.04901885986328,
#   '178',
#   52,
#   0),
#  (399.1199951171875,
#   106.64299774169922,
#   430.9425354003906,
#   118.64899444580078,
#   '173, 179',
#   53,
#   0),
#  (418.32000732421875,
#   116.24297332763672,
#   430.9623107910156,
#   128.2489776611328,
#   '177',
#   54,
#   0),
#  (399.1199951171875,
#   125.84300994873047,
#   431.072998046875,
#   156.8090362548828,
#   '173, 177\n173, 178\n173, 176',
#   55,
#   0),
#  (418.0799865722656,
#   154.6429901123047,
#   430.82720947265625,
#   176.00901794433594,
#   '180\n178',
#   56,
#   0),
#  (398.8800048828125,
#   173.6029815673828,
#   430.4272766113281,
#   185.60899353027344,
#   '175, 176',
#   57,
#   0),
#  (417.6000061035156,
#   183.20298767089844,
#   430.52545166015625,
#   195.20899963378906,
#   '175',
#   58,
#   0),
#  (398.6400146484375,
#   192.80299377441406,
#   430.19390869140625,
#   204.8090057373047,
#   '173, 175',
#   59,
#   0),
#  (417.6000061035156,
#   202.4029998779297,
#   430.4700012207031,
#   214.4090118408203,
#   '174',
#   60,
#   0),
#  (398.3999938964844,
#   212.0030059814453,
#   429.94708251953125,
#   233.36900329589844,
#   '173, 176\n173, 177',
#   61,
#   0),
#  (417.1199951171875,
#   230.96299743652344,
#   429.9028625488281,
#   242.96900939941406,
#   '181',
#   62,
#   0),
#  (398.1600036621094,
#   240.56300354003906,
#   429.9215393066406,
#   271.76898193359375,
#   '173, 180\n173, 177\n174, 181',
#   63,
#   0),
#  (416.8800048828125,
#   269.3630065917969,
#   429.6687927246094,
#   290.72900390625,
#   '169\n177',
#   64,
#   0),
#  (397.9200134277344,
#   288.322998046875,
#   429.01446533203125,
#   300.3289794921875,
#   '174, 182',
#   65,
#   0),
#  (416.6400146484375,
#   298.16302490234375,
#   429.4288024902344,
#   319.52899169921875,
#   '179\n180',
#   66,
#   0),
#  (397.44000244140625,
#   317.1230163574219,
#   429.2268981933594,
#   338.72900390625,
#   '173, 176\n172, 174',
#   67,
#   0),
#  (416.3999938964844,
#   336.322998046875,
#   429.5360107421875,
#   357.9289855957031,
#   '175\n175',
#   68,
#   0),
#  (414.7200012207031,
#   366.0830078125,
#   428.7570495605469,
#   572.489013671875,
#   '426\n426\n356\n356\n356\n448\n450\n357\n94\n94\n95\n116\n117\n117\n24\n24\n24\n15\n15\n15\n15',
#   69,
#   0),
#  (414.239990234375,
#   570.0830078125,
#   427.8207702636719,
#   620.489013671875,
#   '439\n369\n369\n370\n39',
#   70,
#   0)]

# %%
doc[621].getText()
# Out:
# "546\nNOUVELLE FLORE\ngussonii Pari.\nhordeaceus L.\nintermedius Guss.\njaponicus Thunb.\nlanceolatus Roth\nmacrpstachys Desf.\nmadritensis L.\nmaximus Desf.\nmollis L.\noxyphlaeus Payne\npalaestinus Melderis\npatulus Mert. et Koch\npinnatus L.\nramosus L.\nrigens L.\nrigidus Roth\nrubens L.\nscoparius L.\nsquarrosus L.\nsterilis L.\nsyriacus Boiss. et Bl.\ntectorum L.\ntomentellus Boiss.\nvillosus Forsk.\nBroussonetia papyrifera (L.) L'Hér.\nBuffonia\nephedrina Sam.\nkotschyana Boiss.\nmacrospermaj. Gay\nmulticeps Decne\npaniculata Dubois\ntenuifolia Vill.\nvirgata Boiss.\nBulbillaria gageoides Zucc.\nBUTOMACEAE\nButomus\numbellatus L.\nC\nCalamagrostis\nepigeios (L.) Roth\nlittorea (Schrad.) D.C.\npseudophragmites (Hall Fil.) Kœl.\nCalligonum\ncomosum L'Hér.\ntetrapterum Jaub. et Spach\nCannabis\nsativa L.\nCarex\nacuta L.\nacutiformis Ehrh.\nbanatica Heuff.\nbuekii Wimm.\ncontigua Hoppe\ndistans L.\ndiversicolor Druce\ndivisa Huds.\ndivulsa Stokes\n123\n129\n120, 128\n120, 129\n119, 126\n126\n119, 122\n123\n129\n126\n120, 128\n129\n131\n132\n123\n119, 123\n119, 124\n119, 125\n120, 127\n119, 122\n119, 120\n119, 121c\n119, 121\n123\n371\n461\n461\n461\n461\n461\n461\n461\n461\n226\n31\n31\n31\n69\n69\n69\n69\n406\n407\n407\n377\n377\n172\n179\n174, 181\n179\n173, 179\n176\n174, 181\n178\n172, 174\n173, 175\nechinata Murr.\nechinata Desf.\nextensa Good.\nflacca Schreb.\nglauca Scop.\ngracilis Curt.\ngynobasis Vill.\nhalleriana Asso\nhispida Willd.\nleporina L.\nmaxima Scop.\nmediterranea Clarke\nmuricata L.\nnemorosa Rebent.\notrubae Podp.\npachystylisj. Gay\npairaei F. Schultz\npallescens L.\npaludosa Good.\npendula Huds.\nphyllostachys C. A. Mey.\npseudocyperus L.\npubescens Poir.\nremota L.\nriparia Gurt.\nrufa (L.) Simonk\nsilvatica Huds.\nstellulata Good.\nstenophylla Wahlenb.\nsubvùlpina Senay\nvulpina L.\nCaroxylon\narticulatum (Cav.) Moqu.\nsalicomicum Moqu.\nCarpinus\nduinensis Scop.\norientalis Mill.\nCarpobrotus edulis (L.) N. E. Br.\nCARYOPHYLLACEAE\nCastanea sativa L.\nCatabrosa\naquatica (L.) Beauv.\nhumilis (M. Bieb.) Trin.\nCatapodium\nloliaceum (Huds.) Link\nrigidum (L.) C. Hubb.\nCaulinia\nfragilis Willd.\ngraminea (Del.) Batt.\nCedrus\nlibanensis Juss.\nlibani A. Rich.\nlibanotica Link\nCelosia çristata L.\nCeltis\naustralis L.\ntournefortii Lam.\nCenchrus\n176\n178\n173, 180\n173, 178\n178\n173, 179\n177\n173, 177\n173, 178\n173, 176\n180\n178\n175, 176\n175\n173, 175\n174\n173, 176\n173, 177\n181\n173, 180\n173, 177\n174, 181\n169\n177\n174, 182\n179\n180\n173, 176\n172, 174\n175\n175\n426\n426\n356\n356\n356\n448\n450\n357\n94\n94\n95\n116\n117\n117\n24\n24\n24\n15\n15\n15\n15\n439\n369\n369\n370\n39\n"

# %%
page.getFontList()
# Out:
# [(48515, 'n/a', 'Type1', 'Times-Roman', 'F0', 'WinAnsiEncoding'),
#  (48516, 'n/a', 'Type1', 'Times-Italic', 'F1', 'WinAnsiEncoding'),
#  (48584, 'pfa', 'Type1', 'OYLUZG+Times-Roman', 'F12', 'WinAnsiEncoding'),
#  (48575, 'pfa', 'Type1', 'RCBBCE+Times-Italic', 'F13', 'WinAnsiEncoding'),
#  (48535, 'n/a', 'Type1', 'Times-Bold', 'F2', 'WinAnsiEncoding'),
#  (48526, 'pfa', 'Type1', 'QKXTUK+Times-Roman', 'F24', 'WinAnsiEncoding'),
#  (48517, 'pfa', 'Type1', 'KLTUIO+Times-Italic', 'F25', 'WinAnsiEncoding'),
#  (48566, 'pfa', 'Type1', 'XTFERS+Times-Bold', 'F26', 'WinAnsiEncoding'),
#  (48603, 'pfa', 'Type1', 'TCNEMC+Times-BoldItalic', 'F27', 'WinAnsiEncoding'),
#  (48537, 'pfa', 'Type1', 'ETVWNV+Times-Roman', 'F28', 'WinAnsiEncoding'),
#  (48546, 'pfa', 'Type1', 'CPDYZV+Times-Italic', 'F29', 'WinAnsiEncoding'),
#  (48565, 'n/a', 'Type1', 'Times-BoldItalic', 'F3', 'WinAnsiEncoding'),
#  (48556, 'pfa', 'Type1', 'VHVHMH+Times-Bold', 'F30', 'WinAnsiEncoding'),
#  (48593, 'n/a', 'Type1', 'Helvetica', 'F4', 'WinAnsiEncoding'),
#  (48594, 'pfa', 'Type1', 'RXDRFC+Helvetica', 'F48', 'WinAnsiEncoding'),
#  (48612, 'pfa', 'Type1', 'HFJIZK+Helvetica', 'F52', 'WinAnsiEncoding'),
#  (48555, 'n/a', 'Type1', 'Helvetica-Bold', 'F6', 'WinAnsiEncoding'),
#  (48536, 'n/a', 'Type1', 'Courier', 'F8', 'WinAnsiEncoding')]

# %%
import pandas as pd
df = pd.DataFrame(columns = columns)
df

# %%
df = pd.read_excel('text_to_spreadsheet_template.xlsx')
